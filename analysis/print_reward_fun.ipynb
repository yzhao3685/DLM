# %%
import requests
import datetime
import pytz


url = "https://logs.betterstack.com/api/v1/query"
headers = {
    "Authorization": "Bearer 2oqgnLmr2d6QaNyEzS4FCv96",
}

def get_data(params):
    i = 2
    params = {**params, "batch": 1000}
    print('Getting page 1')
    response = requests.get(url, headers=headers, params=params).json()
    # add pagination
    ret = response['data']
    while response['pagination']['next'] and response['data']:
        next_url = response['pagination']['next']
        print('Getting page', i)
        response = requests.get(next_url, headers=headers).json()
        ret.extend(response['data'])
        i += 1
    return ret
# https://github.com/teamcore-harvard/dlm/commit/cc9da46ffc2096d28f79a3b9098c6f12683aede1
data = get_data({"from": datetime.datetime(2024, 2, 21, 17, 16, 0, tzinfo=pytz.timezone('EST')).isoformat(),
                 "to": datetime.datetime(2024, 2, 21, 19, 48, 0, tzinfo=pytz.timezone('EST')).isoformat()})


print(len(data))
# Out:
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# 4836

# %%
finished = []
for d in data:
    if 'Finished' in d['message'] and 'job!' in d['message']:
        finished.append(int(d['message'].split(' ')[1]))

# %%
len(finished)
# Out:
# 960

# %%
data[-1]
# Out:
# {'dt': '2024-02-21 22:17:10.144393',
#  '_dt': '1708553830144393',
#  '_insert_index': 117000008,
#  'json': '{"context":{"runtime":{"file":"gemini.py","function":"main","line":326,"logger_name":"__main__","thread_id":140449561284992,"thread_name":"MainThread"},"system":{"pid":83,"process_name":"MainProcess"}},"dt":"2024-02-21T22:17:10.144393+00:00","extra":{},"filename":"gemini.py","level":"info","message":"START:60, END:120","severity":2}',
#  '_app': 'reward_learning',
#  '_source_id': '682629',
#  'level': 'info',
#  'message': 'START:60, END:120'}

# %%
len(data)
# Out:
# 4836

# %%
from collections import defaultdict
import json

fin = []
failed = []
results = {}
rls = defaultdict(dict)

for i in data:
    if 'Finished' in i['message']:
        try:
            fin.append(int(i['message'].split(' ')[1]))
        except ValueError:
            # print(i['message'])
            continue
    elif 'Failed' in i['message']:
        try:
            failed.append(int(i["message"].split(" ")[1]))
        except ValueError:
            print(i["message"])
    elif 'Config' in i['message']:
        # reward_from='llm'
        msg =(i['message'].split('Rewards: '))
        reward_list = eval(msg[1])
        cfg = msg[0]
        # print(cfg)
        if 'chain_of_thought=True' in cfg:
            idx = int((cfg.split('. Config:')[0][len('Task: '):]))
            seed = int(cfg.split('seed=')[1][:1])
            # rls[idx][seed] = reward_list[1] #!!
            rls[idx][seed] = reward_list[0]
            
    elif len([rm for rm in ['START', 'Config', 'Upload folder did not work'] if rm in i['message']]):
        continue
    else:
        try:
            results[i['message']] = json.loads(i['json'])['message_json']
        except KeyError:
            continue
            # print(i['message'])
print('Failed: ', failed)
print('Number Results: ', len(results))
print(f'Finished jobs:', len(fin))
# Out:
# Failed:  []
# Number Results:  3348
# Finished jobs: 960

# %%
from dataclasses import dataclass
keys = list(results.keys())
@dataclass
class HyperParameters:
    # alphabetical
    _1_llm_reward: str
    _2_arm_budget: int
    _3_cot: bool
    _4_seeds: int
    _5_task_indices: int
    _6_n_epochs: int
    _stage: int
    _iteration: int



def get_vars(key):
    try:
        _, time, _, cot, seed, n_epochs, _, task, stage, iteration, _, reward_type, arms, budget, optin = key.split('_')
    except ValueError as e:
        print(key.split('_'))
        raise e
    cot = eval(cot[3:])
    budget = int(budget[1:])
    arms = int(arms[1:])
    seed = int(seed[4:])
    stage = int(stage.split('=')[1])
    task = int(task.split('=')[1])
    iteration = int(iteration.split('=')[1].split('//')[0])

    return HyperParameters(reward_type, arms, cot, seed, task, n_epochs, stage, iteration)


hparams = [get_vars(k) for k in keys]

import numpy as np
import pandas as pd
import math
from collections import defaultdict
BY_SEED = True


def print_results(num_arms,BY_SEED):
    np.set_printoptions(precision=1)
    res = defaultdict(list)
    for hparam, key in zip(hparams, keys):
        if hparam._2_arm_budget == num_arms:
            if BY_SEED:
                res[f"nocall_{hparam._5_task_indices}_{hparam._4_seeds}"].extend(results[key]["No Calls"]["all"])
                res[f"random_{hparam._5_task_indices}_{hparam._4_seeds}"].extend(results[key]["RandomDS"]['all'])
            else:
                res[f"nocall_{hparam._5_task_indices}"].extend(results[key]["No Calls"]["all"])
                res[f"random_{hparam._5_task_indices}"].extend(results[key]["RandomDS"]['all'])

            ret = results[key]["PreFeRMAB"]
            
            if BY_SEED:
                k = f"{hparam._1_llm_reward[3:]}_{hparam._5_task_indices}_{hparam._4_seeds}"
            else:
                k = f"{hparam._1_llm_reward[3:]}_{hparam._5_task_indices}"
            if hparam._1_llm_reward != "REWllm" and hparam._3_cot:        
                res[k].extend(ret['all'])
                continue

            # ignore zero shot for now
            if hparam._stage == 0 and hparam._iteration == 0:
                if hparam._3_cot:
                    res['zeroshot_'+k].extend(ret['all'])
                else:
                    res['COT_zeroshot_'+k].extend(ret['all'])
            if hparam._stage == 1 and hparam._iteration == 1:
                if hparam._3_cot:
                    res['COT_'+k].extend(ret['all'])
                else:
                    res[k].extend(ret['all'])
    print(res.keys())
    import math
    # z = ['lambda feature, state: state + if_(state) * SLIGHTLY_MODIFIER * if_(feature[2])',
    # 'lambda feature, state: state*.1 + if_(state) * SLIGHTLY_MODIFIER * if_(feature[39-1] or feature[40-1] or feature[41-1])',
    # 'lambda feature, state: state*.1 + if_(state) * SLIGHTLY_MODIFIER * if_(feature[8-1] and feature[17-1])',
    # 'lambda feature, state: state*.1 + if_(state) * SLIGHTLY_MODIFIER * if_(feature[14-1] and (feature[10-1] or feature[11-1])),']

    results_matrix = [[] for i in range(16)]
    std_matrix = [[] for i in range(16)]
    for i in range(24):
        for seed in range(10):
        # for seed in range(1):
            # for rew in ['nocall', 'random', 'base', 'COT_llm','COT_zeroshot_llm']:
            if BY_SEED:
                bval = np.array(res[f"base_{i}_{seed}"])
                # if bval.mean() + 2 * bval.std() > np.array(res[f"COT_llm_{i}_{seed}"]).mean():
                #     continue
                print('llm_rew:', rls[i][seed])
                # print('base_rew:',z[i] )
                
            for rew in ['random', 'base', 'COT_llm']:                
                if BY_SEED:
                    k = f"{rew}_{i}_{seed}"
                else:
                    k = f"{rew}_{i}"
                base_values = np.array(res[k])
                try:
                    # print(k, base_values)
                    q1_base, q3_base = np.percentile(base_values, [25, 75])
                    iqr_base_values = base_values[(base_values >= q1_base) & (base_values <= q3_base)]
                    task_base_iqr_mean = np.mean(iqr_base_values)

                    print(k, round(task_base_iqr_mean, 2), round(np.std(res[k]), 2))
                except:
                    print(k, 'missing')
            print()
            if not BY_SEED:
                break
    return res

res = print_results(48, BY_SEED=False)
print('\n\n')
res = print_results(48, BY_SEED=True)
# Out:
# dict_keys(['nocall_11', 'random_11', 'default_11', 'nocall_17', 'random_17', 'default_17', 'base_11', 'base_17', 'human_11', 'nocall_5', 'random_5', 'default_5', 'human_17', 'COT_llm_11', 'base_5', 'COT_llm_17', 'human_5', 'nocall_23', 'random_23', 'default_23', 'COT_llm_5', 'base_23', 'zeroshot_llm_11', 'zeroshot_llm_17', 'human_23', 'COT_zeroshot_default_5', 'COT_zeroshot_default_11', 'nocall_16', 'random_16', 'default_16', 'COT_zeroshot_base_5', 'nocall_10', 'random_10', 'default_10', 'COT_zeroshot_default_17', 'COT_llm_23', 'zeroshot_llm_5', 'COT_zeroshot_base_11', 'base_16', 'COT_zeroshot_human_5', 'base_10', 'COT_zeroshot_base_17', 'COT_zeroshot_human_11', 'nocall_4', 'random_4', 'default_4', 'COT_zeroshot_default_23', 'human_16', 'human_10', 'llm_5', 'COT_zeroshot_human_17', 'base_4', 'COT_zeroshot_base_23', 'llm_11', 'COT_llm_10', 'COT_llm_16', 'llm_17', 'zeroshot_llm_23', 'COT_zeroshot_human_23', 'human_4', 'nocall_22', 'random_22', 'default_22', 'llm_23', 'COT_llm_4', 'base_22', 'COT_zeroshot_llm_5', 'COT_zeroshot_llm_11', 'human_22', 'zeroshot_llm_10', 'COT_zeroshot_default_4', 'zeroshot_llm_16', 'COT_zeroshot_llm_17', 'COT_zeroshot_default_10', 'COT_llm_22', 'nocall_9', 'random_9', 'default_9', 'COT_zeroshot_base_4', 'COT_zeroshot_llm_23', 'COT_zeroshot_default_16', 'COT_zeroshot_base_10', 'nocall_15', 'random_15', 'default_15', 'zeroshot_llm_4', 'base_9', 'COT_zeroshot_human_4', 'COT_zeroshot_default_22', 'COT_zeroshot_base_16', 'base_15', 'COT_zeroshot_human_10', 'human_9', 'nocall_3', 'random_3', 'default_3', 'llm_4', 'COT_zeroshot_base_22', 'COT_zeroshot_human_16', 'human_15', 'llm_10', 'base_3', 'COT_llm_9', 'zeroshot_llm_22', 'COT_zeroshot_human_22', 'llm_16', 'COT_llm_15', 'human_3', 'nocall_21', 'random_21', 'default_21', 'llm_22', 'COT_llm_3', 'base_21', 'COT_zeroshot_llm_4', 'human_21', 'COT_zeroshot_llm_10', 'zeroshot_llm_9', 'COT_zeroshot_default_3', 'COT_zeroshot_llm_16', 'zeroshot_llm_15', 'COT_zeroshot_default_9', 'COT_llm_21', 'COT_zeroshot_base_3', 'nocall_8', 'random_8', 'default_8', 'COT_zeroshot_default_15', 'COT_zeroshot_llm_22', 'COT_zeroshot_base_9', 'zeroshot_llm_3', 'nocall_14', 'random_14', 'default_14', 'base_8', 'COT_zeroshot_human_3', 'COT_zeroshot_base_15', 'COT_zeroshot_default_21', 'COT_zeroshot_human_9', 'base_14', 'nocall_2', 'random_2', 'default_2', 'human_8', 'COT_zeroshot_human_15', 'llm_3', 'COT_zeroshot_base_21', 'llm_9', 'human_14', 'base_2', 'COT_llm_8', 'zeroshot_llm_21', 'llm_15', 'COT_zeroshot_human_21', 'human_2', 'COT_llm_14', 'llm_21', 'nocall_20', 'random_20', 'default_20', 'COT_llm_2', 'base_20', 'COT_zeroshot_llm_3', 'COT_zeroshot_llm_9', 'human_20', 'COT_zeroshot_llm_15', 'COT_zeroshot_default_2', 'zeroshot_llm_8', 'COT_zeroshot_default_8', 'COT_llm_20', 'COT_zeroshot_llm_21', 'COT_zeroshot_default_14', 'zeroshot_llm_14', 'COT_zeroshot_base_2', 'nocall_7', 'random_7', 'default_7', 'COT_zeroshot_base_8', 'zeroshot_llm_2', 'COT_zeroshot_base_14', 'COT_zeroshot_default_20', 'COT_zeroshot_human_2', 'nocall_13', 'random_13', 'default_13', 'base_7', 'COT_zeroshot_human_8', 'COT_zeroshot_human_14', 'COT_zeroshot_base_20', 'nocall_1', 'random_1', 'default_1', 'base_13', 'human_7', 'llm_2', 'llm_8', 'COT_zeroshot_human_20', 'llm_14', 'base_1', 'human_13', 'COT_llm_7', 'zeroshot_llm_20', 'llm_20', 'human_1', 'COT_llm_13', 'nocall_19', 'random_19', 'default_19', 'COT_llm_1', 'COT_zeroshot_llm_2', 'COT_zeroshot_llm_8', 'base_19', 'COT_zeroshot_llm_14', 'zeroshot_llm_7', 'COT_zeroshot_default_1', 'human_19', 'COT_zeroshot_default_7', 'COT_zeroshot_llm_20', 'COT_zeroshot_default_13', 'nocall_6', 'random_6', 'default_6', 'COT_zeroshot_base_1', 'zeroshot_llm_13', 'COT_llm_19', 'COT_zeroshot_base_7', 'COT_zeroshot_base_13', 'base_6', 'COT_zeroshot_default_19', 'COT_zeroshot_human_1', 'COT_zeroshot_human_7', 'zeroshot_llm_1', 'nocall_12', 'random_12', 'default_12', 'COT_zeroshot_human_13', 'human_6', 'COT_zeroshot_base_19', 'llm_1', 'base_12', 'llm_7', 'nocall_0', 'random_0', 'defau ...
# random_0 33.35 25.07
# base_0 37.12 33.1
# COT_llm_0 31.53 33.32
#
# random_1 407.91 77.62
# base_1 435.65 132.28
# COT_llm_1 446.57 129.11
#
# random_2 9.35 1.49
# base_2 10.76 2.51
# COT_llm_2 10.69 2.18
#
# random_3 1694.9 90.02
# base_3 2051.84 266.88
# COT_llm_3 2108.45 118.54
#
# random_4 99.19 68.25
# base_4 101.18 67.97
# COT_llm_4 115.67 92.48
#
# random_5 24.47 9.81
# base_5 26.9 9.67
# COT_llm_5 28.47 12.37
#
# random_6 650.43 96.64
# base_6 758.98 142.84
# COT_llm_6 760.26 139.67
#
# random_7 340.83 90.61
# base_7 393.28 109.65
# COT_llm_7 390.25 129.35
#
# random_8 15.62 15.11
# base_8 18.39 16.43
# COT_llm_8 18.34 15.26
#
# random_9 38.58 35.93
# base_9 42.3 37.92
# COT_llm_9 45.66 50.15
#
# random_10 218.01 76.36
# base_10 261.99 81.67
# COT_llm_10 248.03 90.5
#
# random_11 70.91 39.17
# base_11 81.5 42.32
# COT_llm_11 63.12 49.33
#
# random_12 207.19 67.19
# base_12 245.99 81.86
# COT_llm_12 240.64 63.47
#
# random_13 777.49 118.54
# base_13 918.09 198.56
# COT_llm_13 912.77 166.35
#
# random_14 73.12 45.11
# base_14 85.82 52.48
# COT_llm_14 83.96 50.95
#
# random_15 199.87 90.17
# base_15 243.65 108.52
# COT_llm_15 237.72 120.45
#
# random_16 240.94 73.63
# base_16 282.12 88.64
# COT_llm_16 278.97 74.42
#
# random_17 1017.87 119.35
# base_17 1176.85 206.35
# COT_llm_17 1088.46 176.22
#
# random_18 797.61 101.72
# base_18 931.32 179.35
# COT_llm_18 957.91 159.13
#
# random_19 430.88 79.33
# base_19 470.72 114.29
# COT_llm_19 495.57 102.52
#
# random_20 253.67 57.19
# base_20 279.48 81.87
# COT_llm_20 262.38 78.18
#
# random_21 87.11 64.69
# base_21 95.35 73.41
# COT_llm_21 99.04 68.63
#
# random_22 302.57 117.75
# base_22 340.74 133.62
# COT_llm_22 332.24 163.0
#
# random_23 1036.94 105.36
# base_23 1173.14 173.07
# COT_llm_23 1189.88 202.72
#
#
#
#
# dict_keys(['nocall_11_2', 'random_11_2', 'default_11_2', 'nocall_17_3', 'random_17_3', 'default_17_3', 'base_11_2', 'base_17_3', 'human_11_2', 'nocall_5_1', 'random_5_1', 'default_5_1', 'human_17_3', 'nocall_5_6', 'random_5_6', 'default_5_6', 'COT_llm_11_2', 'base_5_1', 'nocall_17_8', 'random_17_8', 'default_17_8', 'base_5_6', 'COT_llm_17_3', 'nocall_11_7', 'random_11_7', 'default_11_7', 'human_5_1', 'base_17_8', 'human_5_6', 'base_11_7', 'human_17_8', 'nocall_23_9', 'random_23_9', 'default_23_9', 'COT_llm_5_1', 'COT_llm_5_6', 'human_11_7', 'COT_llm_17_8', 'base_23_9', 'COT_llm_11_7', 'zeroshot_llm_11_2', 'zeroshot_llm_17_3', 'human_23_9', 'COT_zeroshot_default_5_1', 'COT_zeroshot_default_11_2', 'nocall_16_3', 'random_16_3', 'default_16_3', 'COT_zeroshot_base_5_1', 'nocall_23_4', 'random_23_4', 'default_23_4', 'nocall_10_2', 'random_10_2', 'default_10_2', 'COT_zeroshot_default_17_3', 'COT_llm_23_9', 'zeroshot_llm_5_6', 'COT_zeroshot_base_11_2', 'zeroshot_llm_5_1', 'base_16_3', 'COT_zeroshot_human_5_1', 'base_23_4', 'COT_zeroshot_default_17_8', 'base_10_2', 'COT_zeroshot_base_17_3', 'COT_zeroshot_human_11_2', 'nocall_4_6', 'random_4_6', 'default_4_6', 'COT_zeroshot_default_23_9', 'human_16_3', 'nocall_4_1', 'random_4_1', 'default_4_1', 'zeroshot_llm_17_8', 'human_10_2', 'human_23_4', 'COT_zeroshot_base_17_8', 'llm_5_1', 'COT_zeroshot_human_17_3', 'zeroshot_llm_11_7', 'base_4_6', 'COT_zeroshot_base_23_9', 'COT_zeroshot_default_23_4', 'llm_11_2', 'base_4_1', 'COT_zeroshot_human_17_8', 'nocall_16_8', 'random_16_8', 'default_16_8', 'COT_llm_10_2', 'COT_llm_16_3', 'COT_llm_23_4', 'COT_zeroshot_default_11_7', 'llm_17_3', 'nocall_10_7', 'random_10_7', 'default_10_7', 'zeroshot_llm_23_9', 'COT_zeroshot_human_23_9', 'human_4_6', 'COT_zeroshot_base_23_4', 'COT_zeroshot_default_5_6', 'human_4_1', 'base_16_8', 'llm_17_8', 'COT_zeroshot_base_11_7', 'base_10_7', 'nocall_22_9', 'random_22_9', 'default_22_9', 'COT_zeroshot_human_23_4', 'COT_zeroshot_base_5_6', 'llm_23_9', 'human_16_8', 'COT_llm_4_1', 'COT_llm_4_6', 'COT_zeroshot_human_11_7', 'human_10_7', 'base_22_9', 'COT_zeroshot_human_5_6', 'llm_23_4', 'COT_zeroshot_llm_5_1', 'COT_llm_16_8', 'llm_11_7', 'COT_llm_10_7', 'zeroshot_llm_23_4', 'COT_zeroshot_llm_11_2', 'human_22_9', 'zeroshot_llm_10_2', 'llm_5_6', 'COT_zeroshot_default_4_1', 'zeroshot_llm_16_3', 'COT_zeroshot_llm_17_3', 'COT_zeroshot_llm_17_8', 'COT_zeroshot_default_10_2', 'nocall_22_4', 'random_22_4', 'default_22_4', 'COT_llm_22_9', 'nocall_9_2', 'random_9_2', 'default_9_2', 'COT_zeroshot_base_4_1', 'COT_zeroshot_llm_23_9', 'COT_zeroshot_default_16_3', 'COT_zeroshot_default_16_8', 'COT_zeroshot_base_10_2', 'nocall_15_3', 'random_15_3', 'default_15_3', 'zeroshot_llm_4_1', 'base_22_4', 'base_9_2', 'COT_zeroshot_human_4_1', 'zeroshot_llm_4_6', 'COT_zeroshot_default_22_9', 'COT_zeroshot_llm_23_4', 'COT_zeroshot_base_16_3', 'COT_zeroshot_base_16_8', 'base_15_3', 'COT_zeroshot_human_10_2', 'human_22_4', 'zeroshot_llm_16_8', 'COT_zeroshot_llm_11_7', 'human_9_2', 'nocall_3_1', 'random_3_1', 'default_3_1', 'zeroshot_llm_10_7', 'llm_4_1', 'COT_zeroshot_llm_5_6', 'COT_zeroshot_base_22_9', 'COT_zeroshot_human_16_8', 'COT_zeroshot_human_16_3', 'nocall_3_6', 'random_3_6', 'default_3_6', 'human_15_3', 'COT_zeroshot_default_22_4', 'llm_10_2', 'COT_llm_22_4', 'nocall_15_8', 'random_15_8', 'default_15_8', 'COT_zeroshot_default_10_7', 'base_3_1', 'COT_llm_9_2', 'zeroshot_llm_22_9', 'nocall_9_7', 'random_9_7', 'default_9_7', 'COT_zeroshot_default_4_6', 'COT_zeroshot_human_22_9', 'llm_16_8', 'base_3_6', 'COT_zeroshot_base_22_4', 'llm_16_3', 'base_15_8', 'COT_llm_15_3', 'COT_zeroshot_base_10_7', 'human_3_1', 'base_9_7', 'nocall_21_9', 'random_21_9', 'default_21_9', 'COT_zeroshot_base_4_6', 'human_3_6', 'llm_22_9', 'COT_zeroshot_human_22_4', 'human_15_8', 'COT_zeroshot_human_10_7', 'COT_llm_3_1', 'human_9_7', 'base_21_9', 'COT_zeroshot_human_4_6', 'COT_llm_3_6', 'llm_22_4', 'COT_llm_15_8', 'COT_zeroshot_llm_4_1', 'llm_10_7', 'human_21_9', 'COT_llm_9_ ...
# llm_rew:  state * (agent_feats[10] and (agent_feats[11] or agent_feats[12]))
# random_0_0 49.92 13.16
# base_0_0 49.18 9.72
# COT_llm_0_0 48.85 10.51
#
# llm_rew:  state * (agent_feats[10] or agent_feats[11])
# random_0_1 52.16 15.83
# base_0_1 46.51 9.4
# COT_llm_0_1 45.51 8.21
#
# llm_rew:  state * agent_feats[10] * 0.5 + state * agent_feats[11]
# random_0_2 15.25 0.95
# base_0_2 20.19 0.87
# COT_llm_0_2 19.31 0.85
#
# llm_rew:  state * agent_feats[11]
# random_0_3 15.32 0.83
# base_0_3 18.99 1.12
# COT_llm_0_3 19.31 0.98
#
# llm_rew:  state * (agent_feats[11])
# random_0_4 15.2 0.83
# base_0_4 16.04 0.73
# COT_llm_0_4 18.98 0.87
#
# llm_rew:  state * (agent_feats[11])
# random_0_5 15.69 0.63
# base_0_5 19.11 0.81
# COT_llm_0_5 19.43 0.85
#
# llm_rew: (state * (agent_feats[10] or agent_feats[11])) * (agent_feats[1] or (agent_feats[1] and (agent_feats[6] >= 7 and agent_feats[6] <= 14)))
# random_0_6 86.95 20.39
# base_0_6 114.33 28.17
# COT_llm_0_6 116.68 27.74
#
# llm_rew:  state * 0.75**agent_feats[11]
# random_0_7 46.55 17.19
# base_0_7 64.14 19.5
# COT_llm_0_7 16.23 1.01
#
# llm_rew:  ((agent_feats[11] or agent_feats[10]) and state) * (1 - agent_feats[5]) + 1
# random_0_8 50.96 14.26
# base_0_8 62.5 24.15
# COT_llm_0_8 59.4 23.41
#
# llm_rew:  5*state + (agent_feats[10] and agent_feats[11]) * 10*state
# random_0_9 48.17 14.56
# base_0_9 44.9 9.44
# COT_llm_0_9 53.05 18.12
#
# llm_rew:  state * (100 * agent_feats[42]**2 - 100 * agent_feats[35])
# random_1_0 410.78 38.96
# base_1_0 373.79 31.05
# COT_llm_1_0 397.48 30.69
#
# llm_rew:  state * agent_feats[42] * agent_feats[37] * agent_feats[38] * agent_feats[39] * agent_feats[40] * agent_feats[41]
# random_1_1 364.26 44.35
# base_1_1 363.83 30.04
# COT_llm_1_1 364.92 32.01
#
# llm_rew: state * max(0, agent_feats[-1] - 0.875) * (agent_feats[35] or agent_feats[36] or agent_feats[37]) * (agent_feats[42] or agent_feats[41])
# random_1_2 282.28 30.24
# base_1_2 232.83 22.51
# COT_llm_1_2 260.17 20.42
#
# llm_rew:  1000 * state * agent_feats[36] * agent_feats[37] * agent_feats[38] * agent_feats[39] * agent_feats[40] * agent_feats[41] * agent_feats[42]
# random_1_3 459.58 44.33
# base_1_3 612.96 57.32
# COT_llm_1_3 535.58 53.63
#
# llm_rew:  100000 * state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# random_1_4 344.9 46.12
# base_1_4 345.71 43.77
# COT_llm_1_4 296.04 22.91
#
# llm_rew:  state * (agent_feats[37] and agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# random_1_5 452.44 45.5
# base_1_5 555.08 64.55
# COT_llm_1_5 528.12 53.97
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# random_1_6 415.86 47.86
# base_1_6 457.88 44.67
# COT_llm_1_6 523.75 51.69
#
# llm_rew:  (state * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])) + (state * (agent_feats[41] or agent_feats[42]) * 100)
# random_1_7 518.85 54.98
# base_1_7 606.62 61.31
# COT_llm_1_7 650.54 63.88
#
# llm_rew:  2 * state * agent_feats[42] - state * agent_feats[35]
# random_1_8 435.27 43.75
# base_1_8 530.67 68.3
# COT_llm_1_8 551.92 62.62
#
# llm_rew:  state*(1+(agent_feats[42]*(agent_feats[36]or agent_feats[37]or agent_feats[38]or agent_feats[39]or agent_feats[40]or agent_feats[41]))-(1+(agent_feats[42]*(agent_feats[35]))))
# random_1_9 383.12 37.33
# base_1_9 365.0 45.66
# COT_llm_1_9 377.29 35.92
#
# llm_rew: (state * agent_feats[12])
# random_2_0 6.61 0.62
# base_2_0 6.11 0.42
# COT_llm_2_0 6.53 0.46
#
# llm_rew: state * agent_feats[12]
# random_2_1 9.61 0.7
# base_2_1 8.32 0.55
# COT_llm_2_1 10.16 0.61
#
# llm_rew:  (state + agent_feats[12]) + (state and agent_feats[12])
# random_2_2 9.21 0.75
# base_2_2 12.18 0.78
# COT_llm_2_2 11.14 0.83
#
# llm_rew:  state * agent_feats[12]
# random_2_3 7.24 0.67
# base_2_3 9.32 0.98
# COT_llm_2_3 8.75 0.84
#
# llm_rew:  40 * state * agent_feats[12] + 1
# random_2_4 8.91 0.71
# base_2_4 10.86 0.69
# COT_llm_2_4 9.86 0.84
#
# llm_rew:  2 * state * agent_feats[12]
# random_2_5 10.68 0.57
# base_2_5 13.54 0.78
# COT_llm_2_5 12.82 0.78
#
# llm_rew:  state * agent_feats[12]
# random_2_6 10.05 0.71
# base_2_6 12.93 0.95
# COT_llm_2_6 11.75 0.91
#
# llm_rew:  state * (agent_feats[12])
# random_2_7 10.55 0.67
# base_2_7 12.93 0.77
# COT_llm_2_7 13.59 0.74
#
# llm_rew:  25*state*(agent_feats[6]*agent_feats[12])
# random_2_8 10.14 0.72
# base_2_8 11.42 0.73
# COT_llm_2_8 12.88 0.78
#
# llm_rew:  state * agent_feats[12]
# random_2_9 8.33 0.73
# base_2_9 8.05 0.67
# COT_llm_2_9 9.0 0.76
#
# llm_rew:  state * (agent_feats[2] > 0)
# random_3_0 1685.66 90.37
# base_3_0 1605.19 83.44
# COT_llm_3_0 2211.0 96.88
#
# llm_rew:  10 * state * (agent_feats[2] > 0)
# random_3_1 1698.98 93.83
# base_3_1 1533.58 73.99
# COT_llm_3_1 2070.54 89.0
#
# llm_rew:  state * (agent_feats[2] and agent_feats[4])
# random_3_2 1679.99 103.42
# base_3_2 2174.86 73.56
# COT_llm_3_2 2185.04 96.53
#
# llm_rew:  state * (agent_feats[2] or agent_feats[3])
# random_3_3 1684.52 90.16
# base_3_3 2159.67 104.36
# COT_llm_3_3 2002.0 122.14
#
# llm_rew:  state * agent_feats[2]
# random_3_4 1676.15 87.6
# base_3_4 2097.74 102.13
# COT_llm_3_4 2123.46 101.13
#
# llm_rew:  state * agent_feats[2]
# random_3_5 1727.29 70.12
# base_3_5 2137.52 100.43
# COT_llm_3_5 2144.08 80.1
#
# llm_rew:  state * agent_feats[2]
# random_3_6 1712.17 83.33
# base_3_6 2191.44 92.94
# COT_llm_3_6 2151.11 112.07
#
# llm_rew:  state * agent_feats[2]
# random_3_7 1693.36 77.68
# base_3_7 2152.62 78.59
# COT_llm_3_7 2113.22 95.79
#
# llm_rew:  state * agent_feats[2]
# random_3_8 1676.03 92.25
# base_3_8 2093.26 97.64
# COT_llm_3_8 2002.85 103.51
#
# llm_rew:  2 * state * (agent_feats[2] > 0)
# random_3_9 1681.21 91.72
# base_3_9 1662.52 80.98
# COT_llm_3_9 2094.12 90.22
#
# llm_rew:  state * (agent_feats[16] or agent_feats[17] or agent_feats[18])
# random_4_0 81.88 22.84
# base_4_0 47.65 11.73
# COT_llm_4_0 45.93 9.53
#
# llm_rew:  state*agent_feats[16] + 0.5*state*agent_feats[17] + 0.7*state*agent_feats[18] + 0.8*state*agent_feats[19] + state
# random_4_1 203.38 43.46
# base_4_1 144.03 17.81
# COT_llm_4_1 264.61 50.38
#
# llm_rew:  (state + (1 - agent_feats[16]) * 4) * 3
# random_4_2 15.26 0.96
# base_4_2 20.17 0.7
# COT_llm_4_2 20.06 0.75
#
# llm_rew:  (0.05 * state) * ((not agent_feats[16]) or (not agent_feats[17]) or (not agent_feats[18]) or (not agent_feats[19]) or (not agent_feats[20]) or (not agent_feats[21]) or (not agent_feats[22]))
# random_4_3 48.64 13.81
# base_4_3 64.92 19.2
# COT_llm_4_3 63.89 18.56
#
# llm_rew:  state * (2 + agent_feats[17*state] + agent_feats[18*state] + agent_feats[19*state] + agent_feats[20*state] + agent_feats[21*state] + agent_feats[22*state])
# random_4_4 43.33 17.42
# base_4_4 58.22 20.04
# COT_llm_4_4 58.55 19.21
#
# llm_rew:  state * (not agent_feats[16])
# random_4_5 148.01 28.96
# base_4_5 185.81 34.76
# COT_llm_4_5 188.4 37.73
#
# llm_rew:  state *  (1 + sum(agent_feats[16:23]))
# random_4_6 172.3 39.38
# base_4_6 157.17 33.1
# COT_llm_4_6 205.26 39.14
#
# llm_rew:  (state * 45) - (agent_feats[16] * 42) - (agent_feats[17] * 21) - (agent_feats[18] * 10) - (agent_feats[19] * 5)
# random_4_7 148.54 28.11
# base_4_7 208.59 42.2
# COT_llm_4_7 185.5 46.48
#
# llm_rew: (10 * state) * (1 - agent_feats[16] or 1 - agent_feats[17] or 1 - agent_feats[18] or 1 - agent_feats[19] or 1 - agent_feats[20] or 1 - agent_feats[21] or 1 - agent_feats[22])
# random_4_8 139.6 32.49
# base_4_8 139.45 30.66
# COT_llm_4_8 193.74 38.13
#
# llm_rew:  state * (17 * agent_feats[16] + 18 * agent_feats[17] + 21 * agent_feats[20] + 25 * agent_feats[22])
# random_4_9 47.79 16.37
# base_4_9 50.46 14.74
# COT_llm_4_9 18.24 0.82
#
# llm_rew:  (state * (agent_feats[7] or agent_feats[10])) * (state)
# random_5_0 35.77 4.6
# base_5_0 34.12 3.53
# COT_llm_5_0 42.27 5.79
#
# llm_rew:  10 * (state and (agent_feats[7] or agent_feats[11])) + state * (agent_feats[9] and agent_feats[10])
# random_5_1 32.12 4.49
# base_5_1 28.97 3.13
# COT_llm_5_1 32.0 3.19
#
# llm_rew:  state * (agent_feats[7] or agent_feats[11])
# random_5_2 15.74 3.49
# base_5_2 21.19 4.14
# COT_llm_5_2 16.0 2.04
#
# llm_rew:  state * (agent_feats[7] or agent_feats[11])
# random_5_3 32.15 4.24
# base_5_3 38.64 4.68
# COT_llm_5_3 44.12 4.76
#
# llm_rew:  state*(agent_feats[7] or agent_feats[11])
# random_5_4 31.32 4.37
# base_5_4 37.35 5.71
# COT_llm_5_4 35.7 5.93
#
# llm_rew:  (state * (agent_feats[11] or agent_feats[7])) and not state * (agent_feats[8] or agent_feats[9] or agent_feats[10])
# random_5_5 22.42 4.0
# base_5_5 21.38 3.93
# COT_llm_5_5 26.73 4.39
#
# llm_rew:  state * (agent_feats[7] or agent_feats[11])
# random_5_6 20.9 3.3
# base_5_6 25.48 3.93
# COT_llm_5_6 27.38 4.11
#
# llm_rew:  state * (agent_feats[7] or agent_feats[11])
# random_5_7 8.97 2.62
# base_5_7 10.81 2.01
# COT_llm_5_7 7.48 2.76
#
# llm_rew:  state * (agent_feats[7] or agent_feats[11])
# random_5_8 29.92 5.95
# base_5_8 29.1 4.76
# COT_llm_5_8 34.5 5.81
#
# llm_rew:  state * (agent_feats[7] or agent_feats[10])
# random_5_9 12.74 3.41
# base_5_9 13.52 2.75
# COT_llm_5_9 14.0 3.27
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_6_0 591.55 61.36
# base_6_0 558.69 43.91
# COT_llm_6_0 523.96 45.98
#
# llm_rew:  state * ((agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39]) and not(agent_feats[35]))
# random_6_1 756.43 58.37
# base_6_1 690.17 45.83
# COT_llm_6_1 725.47 50.45
#
# llm_rew:  5 * state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_6_2 655.45 55.85
# base_6_2 877.31 75.08
# COT_llm_6_2 887.93 79.51
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39])
# random_6_3 786.19 71.33
# base_6_3 1024.24 81.88
# COT_llm_6_3 939.63 83.79
#
# llm_rew:  state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_6_4 668.3 71.7
# base_6_4 827.05 87.63
# COT_llm_6_4 737.68 64.51
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_6_5 551.61 58.85
# base_6_5 747.17 66.34
# COT_llm_6_5 661.86 51.92
#
# llm_rew:  state * ((agent_feats[38] or agent_feats[39] or agent_feats[40]) and not(agent_feats[35] or agent_feats[36] or agent_feats[41] or agent_feats[42]))
# random_6_6 640.97 65.19
# base_6_6 825.01 66.46
# COT_llm_6_6 855.01 81.35
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39])
# random_6_7 561.68 57.38
# base_6_7 700.95 68.21
# COT_llm_6_7 706.71 53.73
#
# llm_rew:  state * ((agent_feats[37] or agent_feats[38]) and not (agent_feats[36] or agent_feats[42]))
# random_6_8 692.54 68.15
# base_6_8 795.81 82.43
# COT_llm_6_8 908.85 86.81
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_6_9 639.36 54.18
# base_6_9 640.6 53.63
# COT_llm_6_9 711.76 62.63
#
# llm_rew:  (state and not agent_feats[23]) * 1.0
# random_7_0 249.12 26.82
# base_7_0 246.8 22.11
# COT_llm_7_0 246.96 21.13
#
# llm_rew:  (state and (not agent_feats[23])) * 10
# random_7_1 486.16 45.63
# base_7_1 462.54 35.23
# COT_llm_7_1 400.28 31.43
#
# llm_rew:  (state*3) + 10*(agent_feats[23]==0)
# random_7_2 283.75 38.26
# base_7_2 286.21 28.53
# COT_llm_7_2 339.84 31.37
#
# llm_rew:  state * (not agent_feats[23])
# random_7_3 433.17 46.4
# base_7_3 551.96 60.51
# COT_llm_7_3 568.79 56.99
#
# llm_rew:  (1 - agent_feats[23]) + state
# random_7_4 282.43 33.83
# base_7_4 348.88 32.45
# COT_llm_7_4 265.08 29.47
#
# llm_rew:  state * (1 - agent_feats[23])
# random_7_5 449.16 48.23
# base_7_5 544.12 50.57
# COT_llm_7_5 555.62 45.44
#
# llm_rew:  state * (not agent_feats[23])
# random_7_6 361.78 38.77
# base_7_6 432.08 50.92
# COT_llm_7_6 479.2 57.5
#
# llm_rew:  state * (agent_feats[23] == 0)
# random_7_7 255.38 28.05
# base_7_7 334.21 29.19
# COT_llm_7_7 221.44 24.56
#
# llm_rew:  state * (not agent_feats[23])
# random_7_8 395.78 49.94
# base_7_8 479.33 58.19
# COT_llm_7_8 501.83 69.26
#
# llm_rew:  (state*3) + ( (agent_feats[23]==0) *2 )
# random_7_9 320.82 29.17
# base_7_9 325.96 36.61
# COT_llm_7_9 363.28 48.67
#
# llm_rew:  100 * state * (agent_feats[7] and ((agent_feats[16] or agent_feats[18] or agent_feats[20]) and agent_feats[35]))
# random_8_0 15.31 0.83
# base_8_0 14.68 0.69
# COT_llm_8_0 14.5 0.59
#
# llm_rew:  state * (agent_feats[35] and agent_feats[16])
# random_8_1 53.59 12.01
# base_8_1 46.72 11.29
# COT_llm_8_1 45.51 9.17
#
# llm_rew:  state * (agent_feats[35] and ((agent_feats[7] or agent_feats[8]) and agent_feats[16]))
# random_8_2 15.25 0.93
# base_8_2 18.87 0.93
# COT_llm_8_2 19.79 0.78
#
# llm_rew:  (state * (agent_feats[10] and agent_feats[16] and agent_feats[35])) + (state * (agent_feats[10] and agent_feats[17] and agent_feats[36])) + (state * (agent_feats[10] and agent_feats[18] and agent_feats[37]))
# random_8_3 15.33 0.81
# base_8_3 18.95 1.12
# COT_llm_8_3 18.27 1.2
#
# llm_rew:  state * ( agent_feats[2] * ( agent_feats[11] or agent_feats[12] or agent_feats[13] or agent_feats[14] or agent_feats[15] ) and agent_feats[35] )
# random_8_4 15.24 0.82
# base_8_4 18.13 0.92
# COT_llm_8_4 15.5 0.69
#
# llm_rew:  2*state*((agent_feats[9] or agent_feats[10]) and agent_feats[35] and (agent_feats[17] or agent_feats[18]))
# random_8_5 15.7 0.65
# base_8_5 18.51 0.79
# COT_llm_8_5 19.9 0.72
#
# llm_rew:  state * (agent_feats[35] and (agent_feats[9] or agent_feats[10] or agent_feats[11] or (agent_feats[16] or agent_feats[17] or agent_feats[18])))
# random_8_6 15.62 0.76
# base_8_6 19.49 1.09
# COT_llm_8_6 20.48 0.96
#
# llm_rew:  10 + (agent_feats[41] and (agent_feats[21] or agent_feats[22])) + (agent_feats[21] or agent_feats[22]) + (agent_feats[16] and agent_feats[35]) + (agent_feats[17] and agent_feats[35]) + (agent_feats[18] and agent_feats[35]) + (agent_feats[19] and agent_feats[35]) + (agent_feats[20] and agent_feats[35]) + (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22]) + (agent_feats[7] or agent_feats[8]) * 0.75
# random_8_7 15.41 0.7
# base_8_7 16.04 0.91
# COT_llm_8_7 15.67 0.7
#
# llm_rew:  state * (agent_feats[35] or (agent_feats[37] or agent_feats[21]) and (agent_feats[7] or agent_feats[8]))
# random_8_8 45.9 17.08
# base_8_8 52.8 21.65
# COT_llm_8_8 51.14 19.67
#
# llm_rew:  1.25 * ( 5.0 * agent_feats[16] + 0.5 * agent_feats[17] + (agent_feats[21] and (agent_feats[35] or agent_feats[36])) )
# random_8_9 15.31 0.83
# base_8_9 15.08 0.78
# COT_llm_8_9 14.94 0.83
#
# llm_rew:  state * (agent_feats[35] and agent_feats[36] and agent_feats[37] and agent_feats[38] and agent_feats[39] and agent_feats[40] and agent_feats[41] and agent_feats[42] and not agent_feats[24])
# random_9_0 15.3 0.83
# base_9_0 14.66 0.73
# COT_llm_9_0 14.55 0.74
#
# llm_rew:  state * (agent_feats[35] and agent_feats[36] and (1-agent_feats[23]) and (1-agent_feats[24]) and (1-agent_feats[25]))
# random_9_1 48.25 15.35
# base_9_1 45.38 9.62
# COT_llm_9_1 44.84 10.23
#
# llm_rew:  state * (agent_feats[23] or agent_feats[24] or agent_feats[25]) + (agent_feats[35] and not (agent_feats[23] or agent_feats[24] or agent_feats[25]))
# random_9_2 15.26 0.96
# base_9_2 19.91 0.85
# COT_llm_9_2 13.67 0.63
#
# llm_rew:  state * (agent_feats[42] and (not (agent_feats[23] or agent_feats[24] or agent_feats[25])))
# random_9_3 82.93 19.65
# base_9_3 102.87 25.37
# COT_llm_9_3 107.02 29.11
#
# llm_rew:  state * ((agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]) and not(agent_feats[23] or agent_feats[24] or agent_feats[25]))
# random_9_4 81.05 25.87
# base_9_4 55.47 15.73
# COT_llm_9_4 91.75 22.99
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]) * (1 - agent_feats[23])
# random_9_5 51.0 17.46
# base_9_5 58.08 16.82
# COT_llm_9_5 59.99 20.33
#
# llm_rew:  3 * state * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]) * (1 - agent_feats[23] and 1 - agent_feats[24] and 1 - agent_feats[25]) + 1
# random_9_6 52.04 17.45
# base_9_6 62.74 20.38
# COT_llm_9_6 57.79 21.62
#
# llm_rew: (state and (agent_feats[42] and (not agent_feats[23])))
# random_9_7 15.44 0.7
# base_9_7 20.02 0.75
# COT_llm_9_7 16.46 1.08
#
# llm_rew:  state * (agent_feats[24] or (agent_feats[25] and agent_feats[37]))
# random_9_8 113.39 22.36
# base_9_8 109.12 31.22
# COT_llm_9_8 148.37 42.95
#
# llm_rew:  state * (agent_feats[42] and not agent_feats[23] and not agent_feats[24] and not agent_feats[25])
# random_9_9 15.26 0.82
# base_9_9 15.38 0.8
# COT_llm_9_9 15.89 0.95
#
# llm_rew:  (agent_feats[32] or state * agent_feats[31])
# random_10_0 261.67 43.34
# base_10_0 257.35 29.66
# COT_llm_10_0 258.81 28.88
#
# llm_rew: state * (agent_feats[31] and agent_feats[32])
# random_10_1 293.24 48.15
# base_10_1 304.42 33.64
# COT_llm_10_1 303.01 30.53
#
# llm_rew:  state * 100 * agent_feats[31] * agent_feats[32]
# random_10_2 137.7 30.85
# base_10_2 203.8 35.55
# COT_llm_10_2 110.44 18.01
#
# llm_rew:  state * (agent_feats[31] and agent_feats[32])
# random_10_3 255.03 41.36
# base_10_3 339.5 49.11
# COT_llm_10_3 291.12 46.93
#
# llm_rew:  state * (agent_feats[31] and agent_feats[32])
# random_10_4 214.39 32.17
# base_10_4 256.65 43.39
# COT_llm_10_4 263.58 40.16
#
# llm_rew:  state * (agent_feats[31] and agent_feats[32])
# random_10_5 202.19 32.7
# base_10_5 285.4 45.91
# COT_llm_10_5 240.45 39.76
#
# llm_rew:  state * ((agent_feats[31] and agent_feats[32]) or (agent_feats[30] and agent_feats[32]) or (agent_feats[29] and agent_feats[32]))
# random_10_6 201.03 36.46
# base_10_6 259.08 44.6
# COT_llm_10_6 251.62 45.4
#
# llm_rew:  state * ((agent_feats[31] and state == 1) or (agent_feats[32] and agent_feats[31]))
# random_10_7 109.86 25.17
# base_10_7 153.85 33.37
# COT_llm_10_7 95.28 23.81
#
# llm_rew:  state * ((state == 1) and (agent_feats[31] or (agent_feats[32] and agent_feats[31])))
# random_10_8 343.17 46.36
# base_10_8 406.68 63.17
# COT_llm_10_8 373.68 58.48
#
# llm_rew:  (state * 5) + (agent_feats[28] and agent_feats[32])
# random_10_9 193.58 34.92
# base_10_9 189.67 33.46
# COT_llm_10_9 192.98 32.76
#
# llm_rew:  state * (agent_feats[2] + agent_feats[5]) / (agent_feats[2] or agent_feats[5])
# random_11_0 143.12 33.98
# base_11_0 147.94 27.01
# COT_llm_11_0 missing
#
# llm_rew:  (1 + agent_feats[2] - agent_feats[5]) * state
# random_11_1 81.55 18.9
# base_11_1 78.82 17.01
# COT_llm_11_1 109.5 27.87
#
# llm_rew:  20.0 +100.0 * (-(agent_feats[2] - agent_feats[5])**2)
# random_11_2 68.75 24.02
# base_11_2 116.82 28.15
# COT_llm_11_2 42.25 9.8
#
# llm_rew:  1 + (state * agent_feats[2]/agent_feats[5])
# random_11_3 84.96 19.22
# base_11_3 112.92 28.66
# COT_llm_11_3 missing
#
# llm_rew:  state * (agent_feats[2] / (agent_feats[2] + agent_feats[5]))
# random_11_4 81.57 20.11
# base_11_4 94.08 25.09
# COT_llm_11_4 missing
#
# llm_rew:  state * (agent_feats[2] - agent_feats[5])
# random_11_5 15.7 0.65
# base_11_5 19.44 0.83
# COT_llm_11_5 17.74 0.96
#
# llm_rew:  0.0001*state*(agent_feats[2]-agent_feats[5])*(50-agent_feats[2])
# random_11_6 100.3 28.87
# base_11_6 95.3 21.75
# COT_llm_11_6 145.43 29.41
#
# llm_rew:  100 + (0.2 * agent_feats[2]) + (0.4 * agent_feats[5]) - (0.1 * (agent_feats[2] - agent_feats[5]))
# random_11_7 72.55 21.04
# base_11_7 57.98 19.57
# COT_llm_11_7 100.88 23.1
#
# llm_rew:  (state * agent_feats[2] + 0.5 * state * agent_feats[5])
# random_11_8 50.09 14.8
# base_11_8 57.72 21.45
# COT_llm_11_8 58.58 18.79
#
# llm_rew:  50 * state + 1000 * (agent_feats[2] - agent_feats[5]) * (agent_feats[2] > 1 and agent_feats[5] < 5)
# random_11_9 45.39 18.49
# base_11_9 49.28 14.27
# COT_llm_11_9 18.7 0.82
#
# llm_rew:  state * (agent_feats[13] and agent_feats[9])
# random_12_0 278.92 43.78
# base_12_0 289.23 27.32
# COT_llm_12_0 241.57 29.78
#
# llm_rew:  2*state*agent_feats[13]*agent_feats[9]
# random_12_1 148.6 27.03
# base_12_1 139.36 21.6
# COT_llm_12_1 137.73 21.92
#
# llm_rew:  1 + 10*state + 20*(state and agent_feats[13] and (agent_feats[8] or agent_feats[9]))
# random_12_2 250.31 34.38
# base_12_2 364.81 47.92
# COT_llm_12_2 256.88 28.68
#
# llm_rew:  state * ((agent_feats[13] and agent_feats[9]))
# random_12_3 176.91 35.54
# base_12_3 248.95 36.82
# COT_llm_12_3 263.04 37.72
#
# llm_rew: (state and (16 and 18 and 30 and 32 and 42) and (agent_feats[13] and agent_feats[9]))
# random_12_4 171.58 32.77
# base_12_4 139.85 24.39
# COT_llm_12_4 226.44 38.59
#
# llm_rew:  state * (agent_feats[13] and agent_feats[8] and agent_feats[9])
# random_12_5 194.02 35.53
# base_12_5 241.08 39.56
# COT_llm_12_5 247.48 39.82
#
# llm_rew:  state * agent_feats[13] * (agent_feats[9] or agent_feats[10])
# random_12_6 117.34 24.89
# base_12_6 160.05 36.65
# COT_llm_12_6 156.82 38.2
#
# llm_rew:  state * (agent_feats[13] and agent_feats[12] and (agent_feats[9] or agent_feats[10]))
# random_12_7 260.41 41.92
# base_12_7 314.26 41.24
# COT_llm_12_7 255.38 45.36
#
# llm_rew:  state * (agent_feats[13] and agent_feats[9])
# random_12_8 213.76 36.96
# base_12_8 266.3 55.44
# COT_llm_12_8 259.6 51.91
#
# llm_rew:  state * (agent_feats[13] and agent_feats[9])
# random_12_9 298.14 44.15
# base_12_9 263.03 40.27
# COT_llm_12_9 321.27 53.54
#
# llm_rew: state * (agent_feats[26] or agent_feats[31])
# random_13_0 801.86 72.74
# base_13_0 765.09 60.42
# COT_llm_13_0 994.99 81.22
#
# llm_rew:  state + 0.01 * (agent_feats[26] or agent_feats[31])
# random_13_1 593.07 55.91
# base_13_1 523.16 42.12
# COT_llm_13_1 769.05 85.41
#
# llm_rew:  state * ((agent_feats[26] and agent_feats[31]) or (agent_feats[27] and agent_feats[30]) or (agent_feats[28] and agent_feats[29]))
# random_13_2 756.17 64.07
# base_13_2 913.1 70.51
# COT_llm_13_2 961.24 82.01
#
# llm_rew:  5*(state + (agent_feats[26] or agent_feats[31]))
# random_13_3 946.45 80.59
# base_13_3 1272.55 83.57
# COT_llm_13_3 1268.51 79.75
#
# llm_rew:  10 * state * agent_feats[26] + 10 * state * agent_feats[31]
# random_13_4 881.62 80.66
# base_13_4 1055.0 61.46
# COT_llm_13_4 988.53 84.55
#
# llm_rew:  state * (agent_feats[26] or agent_feats[31])
# random_13_5 695.95 53.25
# base_13_5 866.36 74.56
# COT_llm_13_5 824.96 70.7
#
# llm_rew:  state * ((agent_feats[26] or agent_feats[31]) and agent_feats[12])
# random_13_6 823.8 69.12
# base_13_6 1032.85 68.94
# COT_llm_13_6 838.78 49.49
#
# llm_rew:  state*agent_feats[26] + state*agent_feats[31]
# random_13_7 822.5 72.32
# base_13_7 973.88 69.61
# COT_llm_13_7 935.1 86.94
#
# llm_rew:  state * (agent_feats[26] or agent_feats[31])
# random_13_8 704.3 71.32
# base_13_8 888.7 83.26
# COT_llm_13_8 1000.61 94.56
#
# llm_rew:  state * (agent_feats[26] or agent_feats[31])
# random_13_9 757.71 67.41
# base_13_9 847.55 88.58
# COT_llm_13_9 727.39 49.07
#
# llm_rew:  state * (agent_feats[9] and (agent_feats[2] >= 4 or agent_feats[3] >= 3))
# random_14_0 129.38 31.44
# base_14_0 81.54 16.77
# COT_llm_14_0 78.82 13.5
#
# llm_rew:  1000 * state * ( (agent_feats[7] and agent_feats[2] >= 5) or (agent_feats[8] and agent_feats[2] >= 4) or (agent_feats[9] and agent_feats[2] >= 3) or (agent_feats[10] and agent_feats[2] >= 2) or (agent_feats[11] and agent_feats[2] >= 1) )
# random_14_1 50.58 17.94
# base_14_1 46.82 9.53
# COT_llm_14_1 46.29 9.5
#
# llm_rew:  100*(state * (agent_feats[7] or (agent_feats[8] and (agent_feats[2]>4))) + 1)
# random_14_2 50.04 17.56
# base_14_2 61.67 20.42
# COT_llm_14_2 60.05 18.71
#
# llm_rew:  ((agent_feats[9] and agent_feats[2] > 4) or (agent_feats[10] and agent_feats[2] > 3)) * state
# random_14_3 47.15 12.83
# base_14_3 64.41 17.84
# COT_llm_14_3 62.6 18.01
#
# llm_rew:  state * (((agent_feats[9] and agent_feats[1]) or agent_feats[10]) and agent_feats[2] > 5)
# random_14_4 76.14 23.47
# base_14_4 94.69 29.63
# COT_llm_14_4 96.16 26.93
#
# llm_rew:  0.6 * (agent_feats[7] and agent_feats[2] > 4) + 0.7 * (agent_feats[8] and agent_feats[2] > 4) + 0.8 * (agent_feats[9] and agent_feats[2] > 5) + 0.9 * (agent_feats[10] and agent_feats[2] > 5) + 0.1 * state
# random_14_5 106.73 27.56
# base_14_5 143.55 33.92
# COT_llm_14_5 152.71 35.4
#
# llm_rew:   state + (agent_feats[9] and (agent_feats[2] >= 5 or agent_feats[3] >= 5))
# random_14_6 49.79 13.22
# base_14_6 63.94 17.89
# COT_llm_14_6 63.94 17.86
#
# llm_rew:  5*state * (agent_feats[10] or (agent_feats[7] and agent_feats[2] >= 3))
# random_14_7 144.15 31.11
# base_14_7 195.22 37.79
# COT_llm_14_7 185.22 37.88
#
# llm_rew:  state * (state * (agent_feats[7] and agent_feats[2] >= 4) + state * (agent_feats[8] and agent_feats[2] >= 5) + state * (agent_feats[9] and agent_feats[2] >= 6) + state * (agent_feats[10] and agent_feats[2] >= 7) + state * (agent_feats[11] and agent_feats[2] >= 8))
# random_14_8 50.05 16.4
# base_14_8 63.28 24.14
# COT_llm_14_8 63.6 24.47
#
# llm_rew:  (15*state) + ((agent_feats[9] or agent_feats[10]) and (agent_feats[2] > 2))
# random_14_9 130.74 28.22
# base_14_9 147.07 24.58
# COT_llm_14_9 131.07 30.28
#
# llm_rew: 2 + state + agent_feats[7] - 2*agent_feats[12]
# random_15_0 109.02 24.73
# base_15_0 82.07 15.31
# COT_llm_15_0 116.26 18.97
#
# llm_rew:  state*(agent_feats[7] and agent_feats[16])
# random_15_1 342.89 44.93
# base_15_1 306.62 29.82
# COT_llm_15_1 341.33 36.31
#
# llm_rew:  state * (1.5*agent_feats[11] + (agent_feats[5] == 0))
# random_15_2 137.47 32.0
# base_15_2 198.94 36.01
# COT_llm_15_2 160.74 39.06
#
# llm_rew:  state * (agent_feats[21] and (agent_feats[5] or agent_feats[13]))
# random_15_3 297.0 43.94
# base_15_3 370.51 55.84
# COT_llm_15_3 415.67 52.32
#
# llm_rew:  state * ((not agent_feats[7]) or (agent_feats[12] and agent_feats[13]))
# random_15_4 126.13 29.87
# base_15_4 189.14 34.56
# COT_llm_15_4 146.53 28.43
#
# llm_rew: -state + ((state+agent_feats[33]+agent_feats[34]) * ((agent_feats[6] > 15) + (agent_feats[27] and agent_feats[13]) + (agent_feats[1] and not agent_feats[8]) + agent_feats[42]))
# random_15_5 308.25 44.14
# base_15_5 420.85 46.44
# COT_llm_15_5 402.35 43.71
#
# llm_rew:  state * ((agent_feats[8] or agent_feats[7]) and (agent_feats[11] or agent_feats[36]))
# random_15_6 223.95 33.95
# base_15_6 315.04 55.63
# COT_llm_15_6 304.03 56.88
#
# llm_rew:  state * ((agent_feats[0] <= 34) and (agent_feats[6] >= 10) and (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39]) and (not agent_feats[23]))
# random_15_7 123.47 24.77
# base_15_7 151.56 28.63
# COT_llm_15_7 84.7 18.64
#
# llm_rew:  3 * state * ((agent_feats[33] or agent_feats[34]) and (agent_feats[1] or agent_feats[2] or (agent_feats[4] and agent_feats[5])))
# random_15_8 252.42 43.67
# base_15_8 278.12 64.85
# COT_llm_15_8 305.06 58.64
#
# llm_rew:  state * (agent_feats[31] and agent_feats[32] or agent_feats[34] or agent_feats[35])
# random_15_9 184.09 32.37
# base_15_9 191.67 30.48
# COT_llm_15_9 186.05 25.95
#
# llm_rew:  state * 10 * ((agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19]) + 1)
# random_16_0 219.25 26.08
# base_16_0 212.25 16.47
# COT_llm_16_0 280.88 32.08
#
# llm_rew:  (state * (not agent_feats[16] or not agent_feats[17] or not agent_feats[18] or not agent_feats[19] or not agent_feats[20] or not agent_feats[21] or not agent_feats[22]))
# random_16_1 354.62 42.73
# base_16_1 337.68 26.53
# COT_llm_16_1 269.0 19.34
#
# llm_rew:  state * (10**5 - agent_feats[16])
# random_16_2 152.44 9.62
# base_16_2 202.72 7.92
# COT_llm_16_2 185.08 11.07
#
# llm_rew: state*(agent_feats[16]+agent_feats[17]+agent_feats[18]+agent_feats[19]+agent_feats[20]+agent_feats[21]+agent_feats[22])
# random_16_3 182.85 19.7
# base_16_3 239.83 24.5
# COT_llm_16_3 240.42 23.37
#
# llm_rew:  20 * (state and agent_feats[16]) + 10 * (state and agent_feats[17]) + 5 * (state and agent_feats[18])
# random_16_4 181.19 18.28
# base_16_4 221.36 22.66
# COT_llm_16_4 229.28 21.6
#
# llm_rew:  state * (agent_feats[16] or agent_feats[17])
# random_16_5 291.47 30.37
# base_16_5 364.46 40.99
# COT_llm_16_5 353.67 35.71
#
# llm_rew:  state*(16*agent_feats[16] + 17*agent_feats[17] + 2*agent_feats[18] + agent_feats[19] + agent_feats[20] + agent_feats[21] + agent_feats[22])
# random_16_6 335.42 34.72
# base_16_6 407.21 45.19
# COT_llm_16_6 418.29 52.5
#
# llm_rew:  500 * (1 - state) * agent_feats[16] + 10 * state
# random_16_7 292.53 29.71
# base_16_7 390.92 44.4
# COT_llm_16_7 329.88 34.62
#
# llm_rew:  state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22])
# random_16_8 281.1 34.82
# base_16_8 351.75 43.27
# COT_llm_16_8 329.67 38.04
#
# llm_rew:  2*state + 10*(agent_feats[16] or agent_feats[17])
# random_16_9 189.0 15.28
# base_16_9 183.64 16.67
# COT_llm_16_9 234.17 20.0
#
# llm_rew:  25 + state * agent_feats[35]
# random_17_0 1111.41 81.6
# base_17_0 1047.96 59.73
# COT_llm_17_0 1118.79 62.36
#
# llm_rew:  state * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_17_1 928.72 78.11
# base_17_1 787.92 51.44
# COT_llm_17_1 822.83 59.12
#
# llm_rew:  (5 - agent_feats[35] - agent_feats[36]) * state
# random_17_2 1029.96 89.4
# base_17_2 1249.04 85.33
# COT_llm_17_2 929.25 49.05
#
# llm_rew:  (agent_feats[37] or agent_feats[38]) * state
# random_17_3 881.2 72.5
# base_17_3 1197.67 75.52
# COT_llm_17_3 1101.96 81.76
#
# llm_rew:  state * (agent_feats[35] and agent_feats[36]) + state * (agent_feats[36] and agent_feats[37])
# random_17_4 975.39 66.64
# base_17_4 1134.92 79.51
# COT_llm_17_4 1156.83 95.16
#
# llm_rew:  (3 * state * agent_feats[35]) + (2 * state * agent_feats[36]) + state
# random_17_5 1203.96 64.48
# base_17_5 1480.58 80.24
# COT_llm_17_5 1410.88 89.37
#
# llm_rew:  state * (1/agent_feats[35])
# random_17_6 997.48 69.84
# base_17_6 1260.54 88.02
# COT_llm_17_6 1170.96 75.07
#
# llm_rew: state*(1.1 if agent_feats[35] or agent_feats[36] else agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# random_17_7 1120.79 74.34
# base_17_7 1361.5 96.92
# COT_llm_17_7 1001.83 46.96
#
# llm_rew:  state * (1-agent_feats[35])
# random_17_8 970.44 73.78
# base_17_8 1200.42 97.06
# COT_llm_17_8 1261.71 97.35
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# random_17_9 1023.41 77.43
# base_17_9 936.33 73.22
# COT_llm_17_9 1020.5 63.59
#
# llm_rew:  0.5*state + 0.5*((agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41]) and state)
# random_18_0 725.47 74.48
# base_18_0 634.75 44.72
# COT_llm_18_0 906.62 83.82
#
# llm_rew:  state * (agent_feats[35] or (agent_feats[36] and agent_feats[37]) or agent_feats[38] or agent_feats[39])
# random_18_1 882.64 70.01
# base_18_1 774.75 47.81
# COT_llm_18_1 811.96 46.47
#
# llm_rew:  state * (agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])
# random_18_2 811.15 69.02
# base_18_2 1061.52 81.7
# COT_llm_18_2 1129.17 76.97
#
# llm_rew:  (state and agent_feats[38]) or (state and agent_feats[39]) or (state and agent_feats[40]) or (state and agent_feats[41])
# random_18_3 921.8 77.08
# base_18_3 1251.79 95.37
# COT_llm_18_3 1120.12 81.34
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_18_4 810.03 75.27
# base_18_4 982.83 81.92
# COT_llm_18_4 965.67 83.52
#
# llm_rew:  state * agent_feats[37] * agent_feats[38] * agent_feats[39]
# random_18_5 690.43 61.41
# base_18_5 837.92 61.54
# COT_llm_18_5 779.5 67.91
#
# llm_rew:  1.5*state*agent_feats[38] + 1.5*state*agent_feats[39] + 1*state*(agent_feats[37] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# random_18_6 803.19 70.63
# base_18_6 988.12 84.47
# COT_llm_18_6 1154.0 89.02
#
# llm_rew:  state * (agent_feats[38] or agent_feats[39] or agent_feats[40])
# random_18_7 683.84 58.14
# base_18_7 849.69 65.78
# COT_llm_18_7 906.0 64.23
#
# llm_rew:  state * (agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])
# random_18_8 849.64 69.14
# base_18_8 1012.17 85.77
# COT_llm_18_8 1077.88 82.86
#
# llm_rew:  state * (agent_feats[37] or agent_feats[38] or agent_feats[39])
# random_18_9 795.28 61.34
# base_18_9 951.62 69.25
# COT_llm_18_9 785.33 67.75
#
# llm_rew:  state * (agent_feats[32] and (agent_feats[26] or agent_feats[27]))
# random_19_0 437.4 50.81
# base_19_0 413.04 29.86
# COT_llm_19_0 607.54 60.55
#
# llm_rew:  (state * (agent_feats[26] or agent_feats[32])) - (1 - state) * 10
# random_19_1 439.78 54.91
# base_19_1 388.12 34.58
# COT_llm_19_1 428.44 36.09
#
# llm_rew:  10 * (state and agent_feats[26] and agent_feats[32])
# random_19_2 303.62 29.05
# base_19_2 362.75 30.25
# COT_llm_19_2 272.2 22.88
#
# llm_rew:  5*state + 3*(agent_feats[32] and agent_feats[26])
# random_19_3 525.03 45.92
# base_19_3 567.38 58.07
# COT_llm_19_3 572.16 56.34
#
# llm_rew:  state * (agent_feats[32] and (agent_feats[26] or agent_feats[27]))
# random_19_4 401.79 50.19
# base_19_4 425.85 45.06
# COT_llm_19_4 532.56 61.98
#
# llm_rew: 5*state * (agent_feats[32] and agent_feats[26]) + 2*state * (agent_feats[32] and not agent_feats[26]) + state
# random_19_5 447.58 53.73
# base_19_5 556.79 52.98
# COT_llm_19_5 524.62 55.02
#
# llm_rew:  state * ((agent_feats[26] or agent_feats[27]) * agent_feats[32])
# random_19_6 432.71 43.63
# base_19_6 542.71 46.95
# COT_llm_19_6 548.67 47.71
#
# llm_rew:  state * (agent_feats[32] and agent_feats[26])
# random_19_7 543.77 53.2
# base_19_7 700.24 59.67
# COT_llm_19_7 464.0 28.17
#
# llm_rew:  state * (agent_feats[32] and agent_feats[26])
# random_19_8 412.3 44.2
# base_19_8 524.5 66.98
# COT_llm_19_8 474.16 56.36
#
# llm_rew:  1 + state + 0.1 * agent_feats[26] + 0.01 * agent_feats[32]
# random_19_9 389.76 37.28
# base_19_9 384.12 38.85
# COT_llm_19_9 460.46 58.5
#
# llm_rew:  state * ((agent_feats[31] and agent_feats[33]) or (agent_feats[32] and agent_feats[31]))
# random_20_0 225.52 24.25
# base_20_0 216.62 18.03
# COT_llm_20_0 180.76 13.11
#
# llm_rew:  state * (agent_feats[33] and (agent_feats[31] or agent_feats[32]))
# random_20_1 154.42 8.72
# base_20_1 137.87 6.72
# COT_llm_20_1 139.74 7.07
#
# llm_rew:  state * (agent_feats[31] == 1) * (agent_feats[33] == 1)
# random_20_2 246.81 29.72
# base_20_2 309.71 28.61
# COT_llm_20_2 229.29 21.54
#
# llm_rew:  state * (agent_feats[33] and agent_feats[31])
# random_20_3 257.07 23.99
# base_20_3 311.29 30.98
# COT_llm_20_3 305.58 29.89
#
# llm_rew:  2*state + 3*(agent_feats[33] and agent_feats[31])
# random_20_4 214.06 22.45
# base_20_4 217.88 19.45
# COT_llm_20_4 277.88 29.46
#
# llm_rew:  50 + state * (agent_feats[33] and agent_feats[31] + .1 * (agent_feats[21] or agent_feats[22]))
# random_20_5 330.1 32.65
# base_20_5 392.42 33.16
# COT_llm_20_5 270.16 23.39
#
# llm_rew:  state * agent_feats[33] * agent_feats[31]
# random_20_6 290.05 38.35
# base_20_6 282.25 33.01
# COT_llm_20_6 361.72 41.43
#
# llm_rew:  state * ((agent_feats[31] and agent_feats[33]) or agent_feats[31])
# random_20_7 248.87 31.52
# base_20_7 270.31 31.45
# COT_llm_20_7 269.42 30.57
#
# llm_rew:  state * int(agent_feats[33] and (agent_feats[31] or agent_feats[32]))
# random_20_8 315.42 36.63
# base_20_8 389.4 53.62
# COT_llm_20_8 380.44 49.84
#
# llm_rew: state * (agent_feats[33] and agent_feats[31])
# random_20_9 269.1 36.77
# base_20_9 267.12 28.34
# COT_llm_20_9 228.24 23.97
#
# llm_rew: state * (agent_feats[32] and agent_feats[27])
# random_21_0 79.61 20.39
# base_21_0 83.53 14.93
# COT_llm_21_0 49.4 11.89
#
# llm_rew:  1 + state + 10 * (agent_feats[32] and agent_feats[27])
# random_21_1 165.14 37.89
# base_21_1 111.97 19.87
# COT_llm_21_1 174.48 24.39
#
# llm_rew:  state * (agent_feats[27] and agent_feats[32])
# random_21_2 171.09 35.01
# base_21_2 194.19 41.37
# COT_llm_21_2 179.9 19.06
#
# llm_rew:  state * (agent_feats[27] or agent_feats[32])
# random_21_3 15.37 0.82
# base_21_3 19.42 0.94
# COT_llm_21_3 19.06 1.17
#
# llm_rew:  state * (agent_feats[27] and agent_feats[32])
# random_21_4 47.61 16.11
# base_21_4 50.9 15.99
# COT_llm_21_4 56.65 19.96
#
# llm_rew: state * (agent_feats[27] and agent_feats[32])
# random_21_5 114.27 26.5
# base_21_5 153.44 32.71
# COT_llm_21_5 157.86 34.51
#
# llm_rew:  state * agent_feats[32] * agent_feats[27]
# random_21_6 43.47 19.58
# base_21_6 60.48 17.71
# COT_llm_21_6 65.4 20.64
#
# llm_rew:  state * (agent_feats[32] and agent_feats[27])
# random_21_7 174.08 36.42
# base_21_7 233.7 41.13
# COT_llm_21_7 192.85 29.27
#
# llm_rew:  state * ((agent_feats[27] and agent_feats[32]) or (agent_feats[27] and not agent_feats[32]))
# random_21_8 15.16 0.82
# base_21_8 18.78 1.06
# COT_llm_21_8 18.3 0.94
#
# llm_rew:  state * (agent_feats[32] and agent_feats[27])
# random_21_9 109.38 26.78
# base_21_9 121.26 23.44
# COT_llm_21_9 110.2 18.68
#
# llm_rew:  state * (agent_feats[28] or (agent_feats[32] and agent_feats[28]))
# random_22_0 321.75 47.02
# base_22_0 306.85 35.39
# COT_llm_22_0 358.03 41.7
#
# llm_rew:  state*(agent_feats[32] and (agent_feats[28] or agent_feats[29] or agent_feats[30] or agent_feats[31]))
# random_22_1 173.92 42.44
# base_22_1 175.55 19.61
# COT_llm_22_1 174.2 20.07
#
# llm_rew: state * (agent_feats[32] and agent_feats[28])
# random_22_2 405.73 54.04
# base_22_2 481.41 61.14
# COT_llm_22_2 464.09 57.58
#
# llm_rew: state * (agent_feats[32] and agent_feats[28] and agent_feats[10]) * (1 + agent_feats[0] + agent_feats[1])
# random_22_3 388.76 49.21
# base_22_3 526.01 58.97
# COT_llm_22_3 526.59 63.18
#
# llm_rew:  state * 2 * agent_feats[32] * agent_feats[28]
# random_22_4 503.31 51.41
# base_22_4 574.93 66.37
# COT_llm_22_4 660.71 77.89
#
# llm_rew:  state * (agent_feats[32] and agent_feats[28])
# random_22_5 272.11 41.76
# base_22_5 402.58 52.97
# COT_llm_22_5 290.84 40.41
#
# llm_rew:  state * ((agent_feats[28] or (agent_feats[32] and agent_feats[28])) or (not agent_feats[32]))
# random_22_6 186.96 34.01
# base_22_6 242.55 37.9
# COT_llm_22_6 152.25 26.31
#
# llm_rew:  state * (agent_feats[32] and agent_feats[28] and (agent_feats[7] or agent_feats[8] or agent_feats[9] or agent_feats[10]))
# random_22_7 194.22 43.63
# base_22_7 243.7 46.24
# COT_llm_22_7 230.65 43.28
#
# llm_rew:  state * (agent_feats[32] and agent_feats[28])
# random_22_8 254.39 41.44
# base_22_8 299.75 51.42
# COT_llm_22_8 246.74 46.8
#
# llm_rew:  state * (agent_feats[32] and agent_feats[28])
# random_22_9 413.96 58.5
# base_22_9 329.56 34.18
# COT_llm_22_9 418.81 52.11
#
# llm_rew: (state and agent_feats[32] and (not agent_feats[21])) * 1.5
# random_23_0 1067.33 71.43
# base_23_0 1018.89 60.99
# COT_llm_23_0 1439.92 90.31
#
# llm_rew:  2*state*(agent_feats[32] and not agent_feats[21])
# random_23_1 1057.97 68.32
# base_23_1 943.27 57.66
# COT_llm_23_1 913.81 51.16
#
# llm_rew:  state * (agent_feats[32] and agent_feats[17])
# random_23_2 1022.83 86.01
# base_23_2 1279.33 83.26
# COT_llm_23_2 910.89 50.97
#
# llm_rew:  (agent_feats[32] and (not agent_feats[21])) * state
# random_23_3 1170.07 82.81
# base_23_3 1425.84 105.6
# COT_llm_23_3 1376.22 104.08
#
# llm_rew:  state * ((agent_feats[32] + 1) * (agent_feats[22] and not agent_feats[21] and not agent_feats[20] and not agent_feats[19] and not agent_feats[18] and not agent_feats[17] and not agent_feats[16]))
# random_23_4 1143.42 74.47
# base_23_4 1387.0 81.82
# COT_llm_23_4 1487.41 82.04
#
# llm_rew:  state * ((agent_feats[32]) and (not agent_feats[21]))
# random_23_5 1026.32 60.56
# base_23_5 1213.72 72.58
# COT_llm_23_5 1176.95 75.66
#
# llm_rew:  state * (agent_feats[32] and agent_feats[16] or agent_feats[32] and agent_feats[17] or agent_feats[32] and agent_feats[18] or agent_feats[32] and agent_feats[19] or agent_feats[32] and agent_feats[20])
# random_23_6 961.43 61.38
# base_23_6 1254.36 77.54
# COT_llm_23_6 1145.38 77.65
#
# llm_rew:  state * (agent_feats[32] and (1 - agent_feats[21]) and (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20]))
# random_23_7 901.01 69.86
# base_23_7 1032.91 72.39
# COT_llm_23_7 1102.13 79.27
#
# llm_rew:  state * (agent_feats[32] and not agent_feats[21] and not agent_feats[22])
# random_23_8 999.91 79.86
# base_23_8 1183.35 91.12
# COT_llm_23_8 1218.2 85.91
#
# llm_rew:  2*state*(agent_feats[32] and (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20]))
# random_23_9 1037.24 65.24
# base_23_9 1056.17 64.67
# COT_llm_23_9 1156.11 99.19

# %%
from dataclasses import dataclass
from typing import Callable, NewType
import numpy.typing as npt
import numpy as np

RewardFun = Callable[[npt.NDArray, int], float]  # RewardFun(feature, state) -> r


@dataclass
class Task:
    command: str
    base: RewardFun
    human: RewardFun


"""
types of tasks:
1) take tail of one feature distribution
2) take lower and upper bound of one feature distribution
3) combine two feature distributions
4) use latent label that requires inference (previously impoverished, now impoverished, most at risk (mothers previously suffering from miscarriage or complications))
 
These categories can then vary  by weight: focus slightly more, focus heavily, focus solely on
 
And do this for every feature. 
 
This is already 4 x 3 = 240 tasks.
 
 We can also add negatives (slightly defocus/disadvantage/deprioritize) to get 240 * 2 = 480 tasks.
 
4) take tail of one feature distribution and combine with another feature distribution
5) take lower and upper bound of one feature distribution and combine with another feature distribution,
6) combine two feature distributions and combine with another feature distribution
7) take tail of one feature distribution and combine with another feature distribution and combine with another feature distribution
8) take lower and upper bound of one feature distribution and combine with another feature distribution and combine with another feature distribution
 
"""
# task_commands = [
#     # 1) Take tail of one feature distribution
#     "Identify the upper 10% of beneficiaries by age distribution.",
#     "Extract the highest income_bracket distribution tail, focusing on the top 5%.",
#     "Select the tail end of the 'duration' distribution to analyze the longest calls made to beneficiaries.",
#     "Find the tail of the 'g' distribution representing the most pregnancies.",
#     "Retrieve the tail distribution for 'attempt_no' to see the most frequent call attempt numbers.",
#     # " 2) Take lower and upper bound of one feature distribution",
#     "Determine the lower and upper quartile for the age feature.",
#     "Calculate the income_bracket bounds for the middle 50% of the population.",
#     "Find the boundaries of the 'duration' feature where 90% of the calls lie within.",
#     "Establish the lower and upper bounds of 'enrollment_gestation_age' for the central 80% of the data.",
#     "Set the thresholds for the 'l' feature to identify the common range of live births.",
#     # " 3) Combine two feature distributions",
#     "Combine the distributions of 'age' and 'education' to identify the correlation between the beneficiary's age and their educational attainment.",
#     "Create a joint distribution of 'income_bracket' and 'phone_owner' to explore the financial status against phone ownership.",
#     "Merge the 'slot' and 'duration' distributions to see if certain call times correlate with longer message listening durations.",
#     "Integrate the distributions of 'g' (gravidity) and 'p' (parity) to analyze pregnancy and viable gestational ages together.",
#     "Combine 'language_name' with 'Technical_success' to assess if the success of calls varies with language preferences.",
#     # " 4) Use latent label that requires inference (previously impoverished, now impoverished, most at risk)",
#     "Infer financial improvement by comparing past and present 'income_bracket' to label beneficiaries as 'previously impoverished' or 'now impoverished'.",
#     "Identify 'most at risk' mothers by selecting those with a history of 's' (stillbirths) or who had complications mentioned in 'education' notes.",
#     "Filter for beneficiaries who moved from the lowest 'income_bracket' and are not in the lowest anymore to infer economic improvement.",
#     "Apply inference rules to 'age' and 'p' to identify mothers at high risk due to age and number of past pregnancies.",
#     "Cross-reference 'Technical_success' with repeat 'attempt_no' to infer technical challenges that could indicate 'at-risk' beneficiaries due to poor connectivity or other issues.",
# ]


SLIGHTLY_MODIFIER = 10.0
HEAVILY_MODIFIER = 10.0

 
def if_(x: bool):
    return 1.0 if x else 0.0


# TODO: compare this with the diversity of the actual dataset. for each task, how many people in the dataset does this actually apply to?
# 01/24/24 removed abortion, subtract by one most indices
# 02/12/24 remove stillbirth and infer. stillbirth gets 0 reward, and infer is too hard
task_commands = [
    # 1) Take tail of one feature distribution
    Task(
        "Focus on the most elderly by age distribution.",
        lambda feature, state: state*.1 + if_(state) * SLIGHTLY_MODIFIER * feature[12-1],
        lambda feature, state: (state**2)*.1 + if_(state) * SLIGHTLY_MODIFIER * feature[12-1],
    ),
    Task(
        "The lowest income_bracket distribution tail is very important, focus heavily on the top 12.5%.",
        lambda feature, state: state + if_(state) * HEAVILY_MODIFIER * feature[37-1],
        lambda feature, state: (state**2) + if_(state) * HEAVILY_MODIFIER * feature[37-1],
    ),
    Task(  #! MULTIPLIER 2
        "Select solely those who speak Hindi to analyze how this would affect the calls made to our beneficiaries.",
        lambda feature, state: state*.1 * if_(feature[13-1]),
        lambda feature, state: (state**2)*.1 * if_(feature[13-1]),
    ),
    Task(
        "Prioritize those who have had prior pregnancies.",  # g feature
        lambda feature, state: state + if_(state) * SLIGHTLY_MODIFIER * if_(feature[2]),
        lambda feature, state: (state**2) + if_(state) * SLIGHTLY_MODIFIER * if_(feature[2]),
    ),
    Task(
        "Heavily weight those who have had low education.",  # education_1
        lambda feature, state: state*.1 + if_(state) * HEAVILY_MODIFIER * if_(feature[17-1]),
        lambda feature, state: (state**2) + if_(state) *HEAVILY_MODIFIER * if_(feature[17-1]),
    ),
    # " 2) Take lower and upper bound of one feature distribution",
    Task(
        "Focus only on both the young and elderly.",  # education_1
        lambda feature, state: state * if_(feature[12-1] or feature[8-1]),
        lambda feature, state: (state**2) * if_(feature[12-1] or feature[8-1]),
    ),
    Task(
        "Prefer the income_bracket bounds for the middle 40% of the population.",  # income_bracker 3, 4, 5
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[39-1] or feature[40-1] or feature[41-1]),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[39-1] or feature[40-1] or feature[41-1]),
    ),
    Task(
        "Favor those women who do not own their own phone",
        lambda feature, state: state
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[25-1] or feature[26-1]),
        lambda feature, state: (state**2)
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[25-1] or feature[26-1]),
    ),
    # "Establish the lower and upper bounds of 'enrollment_gestation_age' for the central 80% of the data.",
    # "Set the thresholds for the 'l' feature to identify the common range of live births.",
    # " 3) Combine two feature distributions",
    Task(
        "Combine the distributions of 'age' and 'education' to heavily give precedence to low income impoverished youth.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[8-1] and feature[17-1]),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[8-1] and feature[17-1]),
    ),
    Task(  #! MULTIPLIER 9
        "Focus on the joint distribution of 'income_bracket' and 'phone_owner' for those with high financial status but with no phone ownership.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER
        * if_((feature[40-1] or feature[41-1]) and (feature[25-1] or feature[26-1])),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER
        * if_((feature[40-1] or feature[41-1]) and (feature[25-1] or feature[26-1])),
    ),
    Task(  #! MULTIPLIER 10
        "Advantage those who prefer being called after 7PM 'slot' registered at an NGO.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[32-1] and feature[33-1]),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[32-1] and feature[33-1]),
    ),
    Task(
        "Integrate the distributions of 'g' (gravidity) and 'l' (live) to concentrate heavily on mothers who have several pregnancies but not much success with birth",
        lambda feature, state: state*.1
        + if_(state) * HEAVILY_MODIFIER * if_(feature[2] > 1 and feature[5] == 0),
        lambda feature, state: (state**2)*.1
        + if_(state) * HEAVILY_MODIFIER * if_(feature[2] > 1 and feature[5] == 0),
    ),
    Task(
        "Fixate on those Marathi-speakers with middle-aged folks.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[14-1] and (feature[10-1] or feature[11-1])),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[14-1] and (feature[10-1] or feature[11-1])),
    ),
    Task( #! MULTIPLIER 13 
        "Give more attention for beneficiaries who likely work early in the morning and late at night.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[27-1] or feature[29-1]),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[27-1] or feature[29-1]),
    ),
    Task(
        "Apply inference rules to 'age' and 'p' to identify mothers at high risk due to age and number of past pregnancies and focus heavily on them.",
        lambda feature, state: state*.1
        + if_(state) * HEAVILY_MODIFIER * if_((feature[11-1] or feature[12-1]) and feature[3]),
        lambda feature, state: (state**2)*.1
        + if_(state) * HEAVILY_MODIFIER * if_((feature[11-1] or feature[12-1]) and feature[3]),
    ),
    Task(
        "Infer technical challenges in reaching the phone that could indicate 'at-risk' beneficiaries and give preference.",  # this just means phone ownership or potentially low income, but requires inference.
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_((feature[25-1] or feature[26-1])),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_((feature[25-1] or feature[26-1]))
        + if_(state) * SLIGHTLY_MODIFIER
        * 0.2
        * if_((feature[37-1] or feature[38-1])),  # slight weighting for low income
    ),
    Task( # 16 task 4 
        "Heavily weight those who have had low education.",  # education_1
        lambda feature, state: state + if_(state) * HEAVILY_MODIFIER * if_(feature[17-1]),
        lambda feature, state: (state**2) + if_(state) * HEAVILY_MODIFIER * if_(feature[17-1]),
    ),
    Task( # NEW
        "Weigth the lowest income_bracket groups, the lowest earners in the population.",  # income_bracker 3, 4, 5
        lambda feature, state: state
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[36-1] or feature[37-1] or feature[38-1]),
        lambda feature, state: (state**2)
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[36-1] or feature[37-1] or feature[38-1]),
    ),
    Task( # 18
        "Prefer the income_bracket bounds for the middle 40% of the population.",  # income_bracker 3, 4, 5
        lambda feature, state: state
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[39-1] or feature[40-1] or feature[41-1]),
        lambda feature, state: (state**2)
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[39-1] or feature[40-1] or feature[41-1]),
    ),
    Task( #NEW
        "Advantage those who prefer being called before the 10:30am 'slot' and are registered at an NGO.",
        lambda feature, state: state
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[27-1] and feature[33-1]),
        lambda feature, state: (state**2)
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[27-1] and feature[33-1]),
    ),
    Task( #NEW #20
        "Advantage those who prefer being called after the 7:30pm 'slot' and are registered as ARMMAN.",
        lambda feature, state: state
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[32-1] and feature[34-1]),
        lambda feature, state: (state**2)
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[32-1] and feature[34-1]),
    ),
    Task( #NEW
        "Advantage those who prefer being called between 10:30am-12:30pm and are registered at an NGO.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[28-1] and feature[33-1]),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[28-1] and feature[33-1]),
    ),
    Task( #NEW
        "Advantage those who prefer being called between 12:30pm-3:30pm and are registered at an NGO.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[29-1] and feature[33-1]),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[29-1] and feature[33-1]),
    ),
    Task( #NEW 
        "Advantage those who are registered at an NGO and have LESS than graduate education.",
        lambda feature, state: state*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[33-1] and (feature[21-1] or feature[20-1] or feature[19-1] or feature[18-1] or feature[17-1])),
        lambda feature, state: (state**2)*.1
        + if_(state) * SLIGHTLY_MODIFIER * if_(feature[33-1] and (feature[21-1] or feature[20-1] or feature[19-1] or feature[18-1] or feature[17-1])),
    ),
]


# TODO: rerunstate**2 == state since state \in {0, 1}? potential answer: squaring the full output of the reward for shaped reward
# now we wrap the shap
def shaped_wrapper(reward_fun: RewardFun) -> RewardFun:
    def shaped_reward(feature: npt.NDArray, state: int) -> float:
        return reward_fun(feature, state) ** 2

    return shaped_reward


TASKS = []
for command in task_commands:
    command.human = shaped_wrapper(command.human)
    TASKS.append(command)

# TASKS = [TASKS[3], TASKS[6], TASKS[8], TASKS[12]]
# for t in TASKS:
#     print(t.command)

# %%
import re
import numpy as np
import inspect
def calc_num_feats(fun):
    feat_indices = re.findall(r'agent_feats\[(\d+)\]', fun)
    num_Feats = len(set(feat_indices))
    return num_Feats

print(len(rls.keys()), 'found!')
# calc avg num feats:
# for task in rls:    
#     k = np.array([calc_num_feats(k) for k in rls[task]])
#     print(task, k.mean(), k.std())
    
# TODO calc focus group arms:    
# for task in sorted(rls.keys()):
for task in [0, 1, 2, 5, 17, 8, 22, 6, 12, 13, 15]:
    print(task, TASKS[task].command)
    # print(inspect.getsource(TASKS[task].base))
    print(">>>>>>>")
    [print(f"{i}:{rls[task][k]}") for i, k in enumerate(rls[task])]
    print()
# Out:
# 24 found!
# 0 Focus on the most elderly by age distribution.
# >>>>>>>
# 0:(state * (agent_feats[10] or agent_feats[11])) * (agent_feats[1] or (agent_feats[1] and (agent_feats[6] >= 7 and agent_feats[6] <= 14)))
# 1: state * (agent_feats[10] or agent_feats[11])
# 2: state * agent_feats[10] * 0.5 + state * agent_feats[11]
# 3: state * 0.75**agent_feats[11]
# 4: state * agent_feats[11]
# 5: ((agent_feats[11] or agent_feats[10]) and state) * (1 - agent_feats[5]) + 1
# 6: 5*state + (agent_feats[10] and agent_feats[11]) * 10*state
# 7: state * (agent_feats[11])
# 8: state * (agent_feats[10] and (agent_feats[11] or agent_feats[12]))
# 9: state * (agent_feats[11])
#
# 1 The lowest income_bracket distribution tail is very important, focus heavily on the top 12.5%.
# >>>>>>>
# 0: state * agent_feats[42] * agent_feats[37] * agent_feats[38] * agent_feats[39] * agent_feats[40] * agent_feats[41]
# 1: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# 2:state * max(0, agent_feats[-1] - 0.875) * (agent_feats[35] or agent_feats[36] or agent_feats[37]) * (agent_feats[42] or agent_feats[41])
# 3: (state * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])) + (state * (agent_feats[41] or agent_feats[42]) * 100)
# 4: 1000 * state * agent_feats[36] * agent_feats[37] * agent_feats[38] * agent_feats[39] * agent_feats[40] * agent_feats[41] * agent_feats[42]
# 5: 2 * state * agent_feats[42] - state * agent_feats[35]
# 6: state*(1+(agent_feats[42]*(agent_feats[36]or agent_feats[37]or agent_feats[38]or agent_feats[39]or agent_feats[40]or agent_feats[41]))-(1+(agent_feats[42]*(agent_feats[35]))))
# 7: 100000 * state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# 8: state * (100 * agent_feats[42]**2 - 100 * agent_feats[35])
# 9: state * (agent_feats[37] and agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
#
# 2 Select solely those who speak Hindi to analyze how this would affect the calls made to our beneficiaries.
# >>>>>>>
# 0:state * agent_feats[12]
# 1: state * agent_feats[12]
# 2: (state + agent_feats[12]) + (state and agent_feats[12])
# 3: state * (agent_feats[12])
# 4: state * agent_feats[12]
# 5: 25*state*(agent_feats[6]*agent_feats[12])
# 6: state * agent_feats[12]
# 7: 40 * state * agent_feats[12] + 1
# 8:(state * agent_feats[12])
# 9: 2 * state * agent_feats[12]
#
# 5 Focus only on both the young and elderly.
# >>>>>>>
# 0: 10 * (state and (agent_feats[7] or agent_feats[11])) + state * (agent_feats[9] and agent_feats[10])
# 1: state * (agent_feats[7] or agent_feats[11])
# 2: state * (agent_feats[7] or agent_feats[11])
# 3: state * (agent_feats[7] or agent_feats[11])
# 4: state * (agent_feats[7] or agent_feats[11])
# 5: state * (agent_feats[7] or agent_feats[11])
# 6: state * (agent_feats[7] or agent_feats[10])
# 7: state*(agent_feats[7] or agent_feats[11])
# 8: (state * (agent_feats[7] or agent_feats[10])) * (state)
# 9: (state * (agent_feats[11] or agent_feats[7])) and not state * (agent_feats[8] or agent_feats[9] or agent_feats[10])
#
# 17 Weigth the lowest income_bracket groups, the lowest earners in the population.
# >>>>>>>
# 0: (agent_feats[37] or agent_feats[38]) * state
# 1: state * (1-agent_feats[35])
# 2: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# 3: state * (agent_feats[35] and agent_feats[36]) + state * (agent_feats[36] and agent_feats[37])
# 4: (3 * state * agent_feats[35]) + (2 * state * agent_feats[36]) + state
# 5: 25 + state * agent_feats[35]
# 6: state * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 7: state * (1/agent_feats[35])
# 8: (5 - agent_feats[35] - agent_feats[36]) * state
# 9:state*(1.1 if agent_feats[35] or agent_feats[36] else agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
#
# 8 Combine the distributions of 'age' and 'education' to heavily give precedence to low income impoverished youth.
# >>>>>>>
# 0: state * (agent_feats[35] and ((agent_feats[7] or agent_feats[8]) and agent_feats[16]))
# 1: 10 + (agent_feats[41] and (agent_feats[21] or agent_feats[22])) + (agent_feats[21] or agent_feats[22]) + (agent_feats[16] and agent_feats[35]) + (agent_feats[17] and agent_feats[35]) + (agent_feats[18] and agent_feats[35]) + (agent_feats[19] and agent_feats[35]) + (agent_feats[20] and agent_feats[35]) + (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22]) + (agent_feats[7] or agent_feats[8]) * 0.75
# 2: (state * (agent_feats[10] and agent_feats[16] and agent_feats[35])) + (state * (agent_feats[10] and agent_feats[17] and agent_feats[36])) + (state * (agent_feats[10] and agent_feats[18] and agent_feats[37]))
# 3: state * (agent_feats[35] or (agent_feats[37] or agent_feats[21]) and (agent_feats[7] or agent_feats[8]))
# 4: 1.25 * ( 5.0 * agent_feats[16] + 0.5 * agent_feats[17] + (agent_feats[21] and (agent_feats[35] or agent_feats[36])) )
# 5: state * ( agent_feats[2] * ( agent_feats[11] or agent_feats[12] or agent_feats[13] or agent_feats[14] or agent_feats[15] ) and agent_feats[35] )
# 6: 100 * state * (agent_feats[7] and ((agent_feats[16] or agent_feats[18] or agent_feats[20]) and agent_feats[35]))
# 7: 2*state*((agent_feats[9] or agent_feats[10]) and agent_feats[35] and (agent_feats[17] or agent_feats[18]))
# 8: state * (agent_feats[35] and agent_feats[16])
# 9: state * (agent_feats[35] and (agent_feats[9] or agent_feats[10] or agent_feats[11] or (agent_feats[16] or agent_feats[17] or agent_feats[18])))
#
# 22 Advantage those who prefer being called between 12:30pm-3:30pm and are registered at an NGO.
# >>>>>>>
# 0: state * (agent_feats[32] and agent_feats[28])
# 1: state * 2 * agent_feats[32] * agent_feats[28]
# 2: state * (agent_feats[32] and agent_feats[28])
# 3: state * (agent_feats[28] or (agent_feats[32] and agent_feats[28]))
# 4: state*(agent_feats[32] and (agent_feats[28] or agent_feats[29] or agent_feats[30] or agent_feats[31]))
# 5: state * ((agent_feats[28] or (agent_feats[32] and agent_feats[28])) or (not agent_feats[32]))
# 6:state * (agent_feats[32] and agent_feats[28])
# 7: state * (agent_feats[32] and agent_feats[28] and (agent_feats[7] or agent_feats[8] or agent_feats[9] or agent_feats[10]))
# 8: state * (agent_feats[32] and agent_feats[28])
# 9:state * (agent_feats[32] and agent_feats[28] and agent_feats[10]) * (1 + agent_feats[0] + agent_feats[1])
#
# 6 Prefer the income_bracket bounds for the middle 40% of the population.
# >>>>>>>
# 0: 5 * state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 1: state * (agent_feats[37] or agent_feats[38] or agent_feats[39])
# 2: state * (agent_feats[37] or agent_feats[38] or agent_feats[39])
# 3: state * ((agent_feats[37] or agent_feats[38]) and not (agent_feats[36] or agent_feats[42]))
# 4: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 5: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 6: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 7: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 8: state * ((agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39]) and not(agent_feats[35]))
# 9: state * ((agent_feats[38] or agent_feats[39] or agent_feats[40]) and not(agent_feats[35] or agent_feats[36] or agent_feats[41] or agent_feats[42]))
#
# 12 Fixate on those Marathi-speakers with middle-aged folks.
# >>>>>>>
# 0: state * ((agent_feats[13] and agent_feats[9]))
# 1: state * (agent_feats[13] and agent_feats[9])
# 2: state * (agent_feats[13] and agent_feats[9])
# 3:(state and (16 and 18 and 30 and 32 and 42) and (agent_feats[13] and agent_feats[9]))
# 4: state * (agent_feats[13] and agent_feats[9])
# 5: state * (agent_feats[13] and agent_feats[8] and agent_feats[9])
# 6: 2*state*agent_feats[13]*agent_feats[9]
# 7: state * agent_feats[13] * (agent_feats[9] or agent_feats[10])
# 8: 1 + 10*state + 20*(state and agent_feats[13] and (agent_feats[8] or agent_feats[9]))
# 9: state * (agent_feats[13] and agent_feats[12] and (agent_feats[9] or agent_feats[10]))
#
# 13 Give more attention for beneficiaries who likely work early in the morning and late at night.
# >>>>>>>
# 0: 5*(state + (agent_feats[26] or agent_feats[31]))
# 1: state * (agent_feats[26] or agent_feats[31])
# 2: state * (agent_feats[26] or agent_feats[31])
# 3: 10 * state * agent_feats[26] + 10 * state * agent_feats[31]
# 4:state * (agent_feats[26] or agent_feats[31])
# 5: state * (agent_feats[26] or agent_feats[31])
# 6: state + 0.01 * (agent_feats[26] or agent_feats[31])
# 7: state * ((agent_feats[26] or agent_feats[31]) and agent_feats[12])
# 8: state * ((agent_feats[26] and agent_feats[31]) or (agent_feats[27] and agent_feats[30]) or (agent_feats[28] and agent_feats[29]))
# 9: state*agent_feats[26] + state*agent_feats[31]
#
# 15 Infer technical challenges in reaching the phone that could indicate 'at-risk' beneficiaries and give preference.
# >>>>>>>
# 0: state * (agent_feats[21] and (agent_feats[5] or agent_feats[13]))
# 1: 3 * state * ((agent_feats[33] or agent_feats[34]) and (agent_feats[1] or agent_feats[2] or (agent_feats[4] and agent_feats[5])))
# 2: state * (agent_feats[31] and agent_feats[32] or agent_feats[34] or agent_feats[35])
# 3: state * ((not agent_feats[7]) or (agent_feats[12] and agent_feats[13]))
# 4:-state + ((state+agent_feats[33]+agent_feats[34]) * ((agent_feats[6] > 15) + (agent_feats[27] and agent_feats[13]) + (agent_feats[1] and not agent_feats[8]) + agent_feats[42]))
# 5:2 + state + agent_feats[7] - 2*agent_feats[12]
# 6: state*(agent_feats[7] and agent_feats[16])
# 7: state * ((agent_feats[8] or agent_feats[7]) and (agent_feats[11] or agent_feats[36]))
# 8: state * (1.5*agent_feats[11] + (agent_feats[5] == 0))
# 9: state * ((agent_feats[0] <= 34) and (agent_feats[6] >= 10) and (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39]) and (not agent_feats[23]))

# %%
keys = list(results.keys())

[print(i, k) for i, k in enumerate(keys[0].split('_'))]
# Out:
# 0 reward
# 1 1708553830.1268108
# 2 rfdefault
# 3 cotTrue
# 4 seed2
# 5 nepochs2
# 6 task
# 7 index=11
# 8 stage=0
# 9 iteration=0//logs/results/REWARDS
# 10 TASK11
# 11 REWdefault
# 12 N48
# 13 B16
# 14 OPT0.9::
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
llm_reflection = []
for key in keys:
    skey = key.split('_')
    if skey[11] == 'REWllm' and skey[8] == 'stage=1' and skey[9] == 'iteration=1//logs/results/REWARDS':
        llm_reflection.append(key)
len(llm_reflection)
# Out:
# 477

# %%
from dataclasses import dataclass
from typing import Callable, NewType
import numpy.typing as npt
import numpy as np

RewardFun = Callable[[npt.NDArray, int], float]  # RewardFun(feature, state) -> r


@dataclass
class Task:
    command: str
    base: RewardFun
    human: RewardFun


"""
types of tasks:
1) take tail of one feature distribution
2) take lower and upper bound of one feature distribution
3) combine two feature distributions
4) use latent label that requires inference (previously impoverished, now impoverished, most at risk (mothers previously suffering from miscarriage or complications))
 
These categories can then vary  by weight: focus slightly more, focus heavily, focus solely on
 
And do this for every feature. 
 
This is already 4 x 3 = 240 tasks.
 
 We can also add negatives (slightly defocus/disadvantage/deprioritize) to get 240 * 2 = 480 tasks.
 
4) take tail of one feature distribution and combine with another feature distribution
5) take lower and upper bound of one feature distribution and combine with another feature distribution,
6) combine two feature distributions and combine with another feature distribution
7) take tail of one feature distribution and combine with another feature distribution and combine with another feature distribution
8) take lower and upper bound of one feature distribution and combine with another feature distribution and combine with another feature distribution
 
"""
# task_commands = [
#     # 1) Take tail of one feature distribution
#     "Identify the upper 10% of beneficiaries by age distribution.",
#     "Extract the highest income_bracket distribution tail, focusing on the top 5%.",
#     "Select the tail end of the 'duration' distribution to analyze the longest calls made to beneficiaries.",
#     "Find the tail of the 'g' distribution representing the most pregnancies.",
#     "Retrieve the tail distribution for 'attempt_no' to see the most frequent call attempt numbers.",
#     # " 2) Take lower and upper bound of one feature distribution",
#     "Determine the lower and upper quartile for the age feature.",
#     "Calculate the income_bracket bounds for the middle 50% of the population.",
#     "Find the boundaries of the 'duration' feature where 90% of the calls lie within.",
#     "Establish the lower and upper bounds of 'enrollment_gestation_age' for the central 80% of the data.",
#     "Set the thresholds for the 'l' feature to identify the common range of live births.",
#     # " 3) Combine two feature distributions",
#     "Combine the distributions of 'age' and 'education' to identify the correlation between the beneficiary's age and their educational attainment.",
#     "Create a joint distribution of 'income_bracket' and 'phone_owner' to explore the financial status against phone ownership.",
#     "Merge the 'slot' and 'duration' distributions to see if certain call times correlate with longer message listening durations.",
#     "Integrate the distributions of 'g' (gravidity) and 'p' (parity) to analyze pregnancy and viable gestational ages together.",
#     "Combine 'language_name' with 'Technical_success' to assess if the success of calls varies with language preferences.",
#     # " 4) Use latent label that requires inference (previously impoverished, now impoverished, most at risk)",
#     "Infer financial improvement by comparing past and present 'income_bracket' to label beneficiaries as 'previously impoverished' or 'now impoverished'.",
#     "Identify 'most at risk' mothers by selecting those with a history of 's' (stillbirths) or who had complications mentioned in 'education' notes.",
#     "Filter for beneficiaries who moved from the lowest 'income_bracket' and are not in the lowest anymore to infer economic improvement.",
#     "Apply inference rules to 'age' and 'p' to identify mothers at high risk due to age and number of past pregnancies.",
#     "Cross-reference 'Technical_success' with repeat 'attempt_no' to infer technical challenges that could indicate 'at-risk' beneficiaries due to poor connectivity or other issues.",
# ]


SLIGHTLY_MODIFIER = 0.5
HEAVILY_MODIFIER = 1


def if_(x: bool):
    return 1.0 if x else 0.0


# TODO: compare this with the diversity of the actual dataset. for each task, how many people in the dataset does this actually apply to?
# 01/24/24 removed abortion, subtract by one most indices
# 02/12/24 remove stillbirth and infer. stillbirth gets 0 reward, and infer is too hard
task_commands = [
    # 1) Take tail of one feature distribution
    Task(
        "Focus slightly on the most elderly by age distribution.",
        lambda feature, state: state + SLIGHTLY_MODIFIER * feature[12 - 1],
        lambda feature, state: state**2 + SLIGHTLY_MODIFIER * feature[12 - 1],
    ),
    Task(
        "The lowest income_bracket distribution tail is very important, focus heavily on the top 12.5%.",
        lambda feature, state: state + HEAVILY_MODIFIER * feature[37 - 1],
        lambda feature, state: state**2 + HEAVILY_MODIFIER * feature[37 - 1],
    ),
    Task(
        "Select solely those who speak Hindi to analyze how this would affect the calls made to our beneficiaries.",
        lambda feature, state: state * if_(feature[13 - 1]),
        lambda feature, state: state**2 * if_(feature[13 - 1]),
    ),
    Task(
        "Priortize slightly those who have had prior pregnancies.",  # g feature
        lambda feature, state: state + SLIGHTLY_MODIFIER * if_(feature[2]),
        lambda feature, state: state**2 + SLIGHTLY_MODIFIER * if_(feature[2]),
    ),
    Task(
        "Heavily weight those who have had low education.",  # education_1
        lambda feature, state: state + HEAVILY_MODIFIER * if_(feature[17 - 1]),
        lambda feature, state: state**2 + HEAVILY_MODIFIER * if_(feature[17 - 1]),
    ),
    # " 2) Take lower and upper bound of one feature distribution",
    Task(
        "Focus only on both the young and elderly.",  # education_1
        lambda feature, state: state * if_(feature[12 - 1] or feature[8 - 1]),
        lambda feature, state: state**2 * if_(feature[12 - 1] or feature[8 - 1]),
    ),
    Task(
        "Prefer slightly on the income_bracket bounds for the middle 40% of the population.",  # income_bracker 3, 4, 5
        lambda feature, state: state
        + SLIGHTLY_MODIFIER
        * if_(feature[39 - 1] or feature[40 - 1] or feature[41 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER
        * if_(feature[39 - 1] or feature[40 - 1] or feature[41 - 1]),
    ),
    Task(
        "Slightly favor those women who do not own their own phone",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[25 - 1] or feature[26 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER * if_(feature[25 - 1] or feature[26 - 1]),
    ),
    # "Establish the lower and upper bounds of 'enrollment_gestation_age' for the central 80% of the data.",
    # "Set the thresholds for the 'l' feature to identify the common range of live births.",
    # " 3) Combine two feature distributions",
    Task(
        "Combine the distributions of 'age' and 'education' to heavily give precedence to low income impoverished youth.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[8 - 1] and feature[17 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER * if_(feature[8 - 1] and feature[17 - 1]),
    ),
    Task(
        "Focus slightly on the joint distribution of 'income_bracket' and 'phone_owner' for those with high financial status but with no phone ownership.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER
        * if_(
            (feature[40 - 1] or feature[41 - 1])
            and (feature[25 - 1] or feature[26 - 1])
        ),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER
        * if_(
            (feature[40 - 1] or feature[41 - 1])
            and (feature[25 - 1] or feature[26 - 1])
        ),
    ),
    Task(
        "Advantage slightly those who prefer being called after 7PM 'slot' registered at an NGO.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[32 - 1] and feature[33 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER * if_(feature[32 - 1] and feature[33 - 1]),
    ),
    Task(
        "Integrate the distributions of 'g' (gravidity) and 'l' (live) to concentrate heavily on mothers who have several pregnancies but not much success with birth",
        lambda feature, state: state
        + HEAVILY_MODIFIER * if_(feature[2] > 1 and feature[5] == 0),
        lambda feature, state: state**2
        + HEAVILY_MODIFIER * if_(feature[2] > 1 and feature[5] == 0),
    ),
    Task(
        "Slightly fixate on those Marathi-speakers with middle-aged folks.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER
        * if_(feature[14 - 1] and (feature[10 - 1] or feature[11 - 1])),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER
        * if_(feature[14 - 1] and (feature[10 - 1] or feature[11 - 1])),
    ),
    # " 4) Use latent label that requires inference (previously impoverished, now impoverished, most at risk)",
    # Task(
    #     "Infer disempowered mothers with little opportunity and focus heavily on them.",  # mothers with low education, low income, and no phone ownership
    #     lambda feature, state: state
    #     + HEAVILY_MODIFIER
    #     * if_(
    #         feature[14-1]
    #         and (feature[25-1] or feature[26-1])
    #         and (feature[37-1] or feature[38-1]),
    #         lambda feature, state: state**2
    #         + SLIGHTLY_MODIFIER * if_(feature[14-1] and (feature[25-1] or feature[26-1])),
    #     ),
    #     lambda feature, state: state**2
    #     + HEAVILY_MODIFIER
    #     * if_(
    #         feature[14-1]
    #         and (feature[25-1] or feature[26-1])
    #         and (feature[37-1] or feature[38-1]),
    #         lambda feature, state: state**2
    #         + SLIGHTLY_MODIFIER * if_(feature[14-1] and (feature[25-1] or feature[26-1])),
    #     ),
    # ),
    # Task(
    #     "Identify 'most at risk' mothers by selecting those with a history of 's' (stillbirths) and have had little education and prefer them solely.",
    #     lambda feature, state: state * if_(feature[4] and (feature[17-1] or feature[18-1])),
    #     lambda feature, state: (state**2)
    #     * if_(feature[4] and (feature[17-1] or feature[18-1])),
    # ),
    Task(
        "Give slightly more attention for beneficiaries who likely work early in the morning and late at night.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[27 - 1] or feature[29 - 1]),
        lambda feature, state: (state**2)
        + SLIGHTLY_MODIFIER * if_(feature[27 - 1] or feature[29 - 1]),
    ),
    Task(
        "Apply inference rules to 'age' and 'p' to identify mothers at high risk due to age and number of past pregnancies and focus heavily on them.",
        lambda feature, state: state
        + HEAVILY_MODIFIER * if_((feature[11 - 1] or feature[12 - 1]) and feature[3]),
        lambda feature, state: (state**2)
        + HEAVILY_MODIFIER * if_((feature[11 - 1] or feature[12 - 1]) and feature[3]),
    ),
    Task(
        "Infer technical challenges in reaching the phone that could indicate 'at-risk' beneficiaries and give preference slightly.",  # this just means phone ownership or potentially low income, but requires inference.
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_((feature[25 - 1] or feature[26 - 1]))
        and feature[3],
        lambda feature, state: (state**2)
        + SLIGHTLY_MODIFIER * if_((feature[25 - 1] or feature[26 - 1]))
        + SLIGHTLY_MODIFIER
        * 0.2
        * if_((feature[37 - 1] or feature[38 - 1])),  # slight weighting for low income
    ),
]


# TODO: state**2 == state since state \in {0, 1}? potential answer: squaring the full output of the reward for shaped reward
# now we wrap the shap
def shaped_wrapper(reward_fun: RewardFun) -> RewardFun:
    def shaped_reward(feature: npt.NDArray, state: int) -> float:
        return reward_fun(feature, state) ** 2

    return shaped_reward


TASKS = []
for command in task_commands:
    command.human = shaped_wrapper(command.human)
    TASKS.append(command)

# %%
from itertools import product

def get_user_defined_attrs(cls) -> list:
    return [
        attr
        for attr in dir(cls)
        if not callable(getattr(cls, attr)) and not attr.startswith("__")
    ]


class BaseHyperParameters:
    @classmethod
    def get_product(cls):
        return list(
            product(*[getattr(cls, attr) for attr in get_user_defined_attrs(cls)])
        )



class HyperParameters(BaseHyperParameters):
    # TODO figure out better way to sort attrs without having to add number in beginning, and tie this so there's never a bug with reading the variables below    
    _1_arm_budget = [(48, 16), (21, 7)]
    # _2_arm_budget = [(48, 16)]
    _2_cot = [True, False]    
    _3_seeds = list(range(17)) + [12, 13, 42]
    _4_task_indices = range(len(TASKS))
    _5_n_train_epochs = [1, 3, 5]
    _6_llm_reward = [True, False]



og_hparams = HyperParameters.get_product()

# %%
from dataclasses import dataclass

@dataclass
class HyperParameters:
    # alphabetical
    _1_llm_reward: str
    _2_arm_budget: int
    _3_cot: bool
    _4_seeds: int
    _5_task_indices: int
    # _6_zero_shot: bool    
    _stage: int
    _iteration: int


def get_vars(key):
    try:
        _, time, _, cot, seed, _, task, stage, iteration, _, reward_type, arms, budget, optin = key.split('_')
    except ValueError as e:
        print(key.split('_'))
        raise e
    cot = eval(cot[3:])
    budget = int(budget[1:])
    arms = int(arms[1:])
    seed = int(seed[4:])
    stage = int(stage.split('=')[1])
    task = int(task.split('=')[1])
    iteration = int(iteration.split('=')[1].split('//')[0])

    return HyperParameters(reward_type, arms, cot, seed, task, stage, iteration)


hparams = [get_vars(k) for k in keys]
# Out:
# ['reward', '1708553830.1268108', 'rfdefault', 'cotTrue', 'seed2', 'nepochs2', 'task', 'index=11', 'stage=0', 'iteration=0//logs/results/REWARDS', 'TASK11', 'REWdefault', 'N48', 'B16', 'OPT0.9::']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 33
#      28     iteration = int(iteration.split('=')[1].split('//')[0])
#      30     return HyperParameters(reward_type, arms, cot, seed, task, stage, iteration)
# ---> 33 hparams = [get_vars(k) for k in keys]
#
# Cell In[83], line 33, in <listcomp>(.0)
#      28     iteration = int(iteration.split('=')[1].split('//')[0])
#      30     return HyperParameters(reward_type, arms, cot, seed, task, stage, iteration)
# ---> 33 hparams = [get_vars(k) for k in keys]
#
# Cell In[83], line 21, in get_vars(key)
#      19 except ValueError as e:
#      20     print(key.split('_'))
# ---> 21     raise e
#      22 cot = eval(cot[3:])
#      23 budget = int(budget[1:])
#
# Cell In[83], line 18, in get_vars(key)
#      16 def get_vars(key):
#      17     try:
# ---> 18         _, time, _, cot, seed, _, task, stage, iteration, _, reward_type, arms, budget, optin = key.split('_')
#      19     except ValueError as e:
#      20         print(key.split('_'))
#
# ValueError: too many values to unpack (expected 14)

# %%
print(192 * 4 + 192 + 192)
len(hparams)
# Out:
# 1152
# 3819

# %%
# 48 budget results
from collections import defaultdict
res = defaultdict(list)
for hparam, key in zip(hparams, keys):
    if hparam._2_arm_budget == 48:
        # print(key)
        res[f"nocall_{hparam._5_task_indices}"].append(results[key]["No Calls"]["val"])
        res[f"random_{hparam._5_task_indices}"].append(results[key]["RandomDS"]["val"])

        ret = results[key]['PreFeRMAB']
        k = f"{hparam._1_llm_reward[3:]}_{hparam._5_task_indices}"
        # if k == 'REWbase_9':
        # print(hparam)
        if hparam._1_llm_reward != "REWllm" and hparam._3_cot:        
            res[k].append(ret['val'])
            continue

        # ignore zero shot for now
        if hparam._stage == 0 and hparam._iteration == 0:
            if hparam._3_cot:
                res['zeroshot_'+k].append(ret['val'])
            else:
                res['COT_zeroshot_'+k].append(ret['val'])
        if hparam._stage == 1 and hparam._iteration == 1:
            if hparam._3_cot:
                res['COT_'+k].append(ret['val'])
            else:
                res[k].append(ret['val'])

# %%
len(res['COT_llm_12'])
# Out:
# 10

# %%
import math

results_matrix = [[] for i in range(16)]
std_matrix = [[] for i in range(16)]
for i in range(16):
    for rew in ['nocall', 'random', 'base', 'human', 'llm', 'zeroshot_llm', 'COT_zeroshot_llm', 'COT_llm']:
        k = f"{rew}_{i}"
        print(k, round(np.mean(res[k]), 2), round(np.std(res[k]), 2))
        results_matrix[i].append(np.mean(res[k]))
        std_matrix[i].append(np.std(res[k]))
    print()
# Out:
# nocall_0 140.1 4.69
# random_0 155.91 3.72
# base_0 181.04 17.31
# human_0 183.89 20.51
# llm_0 173.38 23.14
# zeroshot_llm_0 171.97 16.54
# COT_zeroshot_llm_0 168.45 24.13
# COT_llm_0 176.89 21.23
#
# nocall_1 199.39 15.49
# random_1 215.2 14.78
# base_1 243.51 13.32
# human_1 253.46 9.76
# llm_1 225.52 31.5
# zeroshot_llm_1 230.22 27.87
# COT_zeroshot_llm_1 241.19 22.97
# COT_llm_1 235.11 23.84
#
# nocall_2 77.0 11.79
# random_2 85.75 12.95
# base_2 101.78 20.09
# human_2 102.51 18.39
# llm_2 101.88 18.62
# zeroshot_llm_2 101.27 19.01
# COT_zeroshot_llm_2 95.97 16.04
# COT_llm_2 95.69 20.34
#
# nocall_3 331.27 3.58
# random_3 347.11 2.09
# base_3 373.45 18.41
# human_3 370.27 16.4
# llm_3 372.09 19.2
# zeroshot_llm_3 369.24 17.65
# COT_zeroshot_llm_3 373.45 21.9
# COT_llm_3 367.61 18.38
#
# nocall_4 157.35 16.18
# random_4 173.25 15.85
# base_4 196.64 18.0
# human_4 195.38 25.12
# llm_4 194.18 30.42
# zeroshot_llm_4 187.97 31.17
# COT_zeroshot_llm_4 202.43 15.95
# COT_llm_4 188.55 21.31
#
# nocall_5 23.21 6.27
# random_5 25.67 6.47
# base_5 30.82 9.37
# human_5 30.38 8.01
# llm_5 27.2 8.27
# zeroshot_llm_5 27.45 6.58
# COT_zeroshot_llm_5 26.93 8.16
# COT_llm_5 26.48 7.64
#
# nocall_6 217.39 10.16
# random_6 233.21 10.74
# base_6 254.38 23.06
# human_6 261.92 20.25
# llm_6 259.47 22.84
# zeroshot_llm_6 265.01 20.95
# COT_zeroshot_llm_6 246.33 24.07
# COT_llm_6 262.16 24.08
#
# nocall_7 165.14 11.02
# random_7 181.01 11.15
# base_7 204.81 17.94
# human_7 205.7 19.15
# llm_7 212.8 14.62
# zeroshot_llm_7 210.5 23.43
# COT_zeroshot_llm_7 202.37 23.27
# COT_llm_7 198.98 20.36
#
# nocall_8 138.5 3.27
# random_8 154.39 2.34
# base_8 176.65 17.25
# human_8 178.83 18.98
# llm_8 168.69 21.09
# zeroshot_llm_8 168.15 19.86
# COT_zeroshot_llm_8 173.52 17.49
# COT_llm_8 166.3 22.39
#
# nocall_9 140.62 5.63
# random_9 156.39 4.16
# base_9 181.19 21.16
# human_9 183.53 22.83
# llm_9 180.16 16.3
# zeroshot_llm_9 175.01 24.16
# COT_zeroshot_llm_9 179.72 22.87
# COT_llm_9 169.49 21.45
#
# nocall_10 164.0 7.98
# random_10 179.76 7.32
# base_10 200.48 23.62
# human_10 205.47 23.91
# llm_10 204.05 15.71
# zeroshot_llm_10 206.31 22.7
# COT_zeroshot_llm_10 208.05 16.87
# COT_llm_10 189.6 17.57
#
# nocall_11 152.58 11.47
# random_11 168.53 10.76
# base_11 192.54 21.12
# human_11 195.46 24.07
# llm_11 188.28 33.49
# zeroshot_llm_11 193.43 14.8
# COT_zeroshot_llm_11 173.31 25.96
# COT_llm_11 191.84 24.31
#
# nocall_12 163.21 8.66
# random_12 179.01 8.58
# base_12 201.62 14.6
# human_12 201.93 14.87
# llm_12 187.54 21.97
# zeroshot_llm_12 199.13 21.03
# COT_zeroshot_llm_12 190.3 18.2
# COT_llm_12 203.73 17.62
#
# nocall_13 237.51 13.6
# random_13 253.28 12.92
# base_13 282.75 20.71
# human_13 281.34 17.44
# llm_13 273.95 20.97
# zeroshot_llm_13 276.21 31.44
# COT_zeroshot_llm_13 276.42 19.55
# COT_llm_13 271.51 26.61
#
# nocall_14 152.83 11.3
# random_14 168.64 9.61
# base_14 194.0 22.8
# human_14 196.78 20.0
# llm_14 182.29 14.43
# zeroshot_llm_14 191.48 17.39
# COT_zeroshot_llm_14 183.74 21.04
# COT_llm_14 190.62 20.2
#
# nocall_15 118.87 18.41
# random_15 126.32 19.4
# base_15 139.24 19.9
# human_15 135.03 20.7
# llm_15 138.63 24.48
# zeroshot_llm_15 130.62 19.47
# COT_zeroshot_llm_15 138.13 22.19
# COT_llm_15 142.95 23.26

# %%
import numpy as np

np.set_printoptions(precision=1)
mu, std = np.array(results_matrix).mean(axis=0), np.array(std_matrix).mean(axis=0)
print(np.vstack((mu, std)))
# Out:
# [[161.2 175.2 197.2 198.9 193.1 194.  192.5 192.3]
#  [ 10.    9.6  18.7  18.8  21.1  20.9  20.   20.7]]
