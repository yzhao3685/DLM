# %%
import requests
import datetime
import pytz


url = "https://logs.betterstack.com/api/v1/query"
headers = {
    "Authorization": "Bearer 2oqgnLmr2d6QaNyEzS4FCv96",
}

def get_data(params):
    i = 2
    params = {**params, "batch": 1000}
    response = requests.get(url, headers=headers, params=params).json()
    # add pagination
    ret = response['data']
    while response['pagination']['next'] and response['data']:
        next_url = response['pagination']['next']
        print('Getting page', i)
        response = requests.get(next_url, headers=headers).json()
        ret.extend(response['data'])
        i += 1
    return ret

# 2024-02-14T11:49:58.747138+00:00
# data = get_data({"from": "2022-07-19T13:32:56+00:00", "to": "2025-07-19T13:32:56+00:00"})


# data = get_data({"from": datetime.datetime(2024, 2, 19, 10, 00, 0, tzinfo=pytz.timezone('EST')).isoformat(),
#                  "to": datetime.datetime(2024, 2, 19, 12, 00, 0, tzinfo=pytz.timezone('EST')).isoformat()})

# reward state 
# https://github.com/teamcore-harvard/dlm/tree/305117ba347326b04e5137f331c915f7520c4fd9
data = get_data({"from": datetime.datetime(2024, 2, 19, 15, 34, 0, tzinfo=pytz.timezone('EST')).isoformat(),
                 "to": datetime.datetime(2024, 2, 19, 22, 18, 0, tzinfo=pytz.timezone('EST')).isoformat()})

# data = get_data({"from": datetime.datetime(2024, 2, 20, 6, 49, 0, tzinfo=pytz.timezone('EST')).isoformat(), 
#                  "to": datetime.datetime(2024, 2, 20, 11, 59, 0, tzinfo=pytz.timezone('EST')).isoformat()})

print(len(data))
# Out:
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# 9166

# %%
finished = []
for d in data:
    if 'Finished' in d['message'] and 'job!' in d['message']:
        finished.append(int(d['message'].split(' ')[1]))

# %%
len(finished)
# Out:
# 1842

# %%
data[-1]
# Out:
# {'dt': '2024-02-19 20:35:17.274130',
#  '_dt': '1708374917274130',
#  '_insert_index': 149000018,
#  'json': '{"context":{"runtime":{"file":"gemini.py","function":"main","line":326,"logger_name":"__main__","thread_id":140513026265472,"thread_name":"MainThread"},"system":{"pid":83,"process_name":"MainProcess"}},"dt":"2024-02-19T20:35:17.274130+00:00","extra":{},"filename":"gemini.py","level":"info","message":"START:1200, END:1320","severity":2}',
#  '_app': 'reward_learning',
#  '_source_id': '682629',
#  'level': 'info',
#  'message': 'START:1200, END:1320'}

# %%
len(data)
# Out:
# 9166

# %%
from collections import defaultdict
import json

fin = []
failed = []
results = {}
rls = defaultdict(list)

for i in data:
    if 'Finished' in i['message']:
        try:
            fin.append(int(i['message'].split(' ')[1]))
        except ValueError:
            # print(i['message'])
            continue
    elif 'Failed' in i['message']:
        try:
            failed.append(int(i["message"].split(" ")[1]))
        except ValueError:
            print(i["message"])
    elif 'Config' in i['message']:
        # reward_from='llm'
        msg =(i['message'].split('Rewards: '))
        reward_list = eval(msg[1])
        idx = int(msg[0].split('index=')[1][0])
        rls[idx].append(reward_list[1])
    elif len([rm for rm in ['START', 'Config', 'Upload folder did not work'] if rm in i['message']]):
        continue
    else:
        try:
            results[i['message']] = json.loads(i['json'])['message_json']
        except KeyError:
            continue
            # print(i['message'])
print('Failed: ', failed)
print('Number Results: ', len(results))
print('Finished:', len(fin))
# Out:
# Failed:  [98, 190, 1022]
# Number Results:  6368
# Finished: 1842

# %%
import re
import numpy as np
def calc_num_feats(fun):
    feat_indices = re.findall(r'agent_feats\[(\d+)\]', fun)
    num_Feats = len(set(feat_indices))
    return num_Feats

# calc avg feats:
for task in rls:
    k = np.array([calc_num_feats(k) for k in rls[task]])
    print(task)
    print(">>>>>>>")
    [print(f"{i}:{k}") for i, k in enumerate(rls[task])]
    print(task, k.mean(), k.std())
# Out:
# 2
# >>>>>>>
# 0: state * ((agent_feats[37] or agent_feats[38] or agent_feats[39]) and not (agent_feats[35] or agent_feats[41] or agent_feats[42]))
# 1: state * ((agent_feats[7] or agent_feats[11]) or (agent_feats[21] or agent_feats[22]))
# 2: state * (not agent_feats[16] or not agent_feats[17] or not agent_feats[18] or not agent_feats[19] or not agent_feats[20] or not agent_feats[21] or not agent_feats[22])
# 3: state * (1 + agent_feats[2] > 1)
# 4: state * agent_feats[12]
# 5: state * (agent_feats[37] or (agent_feats[35] and agent_feats[42]))
# 6: state * (agent_feats[11] or agent_feats[10])
# 7: state * (agent_feats[32] and not agent_feats[20])
# 8: state * max(1 , agent_feats[28] * agent_feats[32] )
# 9:(state*5 + 1) * (agent_feats[32] and agent_feats[27])
# 10: state * (agent_feats[31] and agent_feats[33])
# 11: state * ((agent_feats[26] or agent_feats[27]) and agent_feats[32])
# 12: state * (agent_feats[23] and (agent_feats[37] or (agent_feats[38] and agent_feats[39]) or agent_feats[40]))
# 13:state * ( (agent_feats[35] or agent_feats[36]) and agent_feats[10] )
# 14: state * (1000-agent_feats[16])
# 15: state * ((state == 0) or ((state == 1) and agent_feats[39]))
# 16: state * ((agent_feats[11] or (agent_feats[9] or agent_feats[10])) or (agent_feats[2] >= 5))
# 17: state * (agent_feats[26] or agent_feats[31])
# 18:state * (agent_feats[13] and (agent_feats[8] or agent_feats[9])) + 5 * agent_feats[13] * agent_feats[8]
# 19: state * (agent_feats[2] - agent_feats[5])
# 20: (state + (agent_feats[3] and agent_feats[34])) * (1 + agent_feats[31])
# 21: state * (agent_feats[35] and not agent_feats[23] and agent_feats[24])
# 22: state * (agent_feats[16] and (agent_feats[7] or agent_feats[8] or agent_feats[9]) and agent_feats[35]) * 100
# 23: state * (0.5 + (1 - (agent_feats[23] or agent_feats[24] or agent_feats[25])) / 2)
# 24: 2 * state * ((agent_feats[37] and agent_feats[38]) or agent_feats[39])
# 25: state * (agent_feats[7] or agent_feats[11])
# 26: state * (1 + 5 * ((agent_feats[4] - 2) > 0) * (agent_feats[16] or agent_feats[17]))
# 27:state * (agent_feats[2] + 1)
# 28: state * (agent_feats[12])
# 29: state * agent_feats[42] * (agent_feats[35] or agent_feats[36] or agent_feats[37])
# 30: state * (agent_feats[10] or (agent_feats[11] and agent_feats[4]))
# 31: 2.0 * state * (agent_feats[32] and (not agent_feats[21]))
# 32: state * (agent_feats[28] and agent_feats[32] or agent_feats[28] and agent_feats[29])
# 33: state * (agent_feats[32] and agent_feats[27] and (agent_feats[6] <= 0))
# 34: state * (agent_feats[33] and (agent_feats[30] or agent_feats[31]))
# 35: state * (agent_feats[32] and (agent_feats[26] or agent_feats[27]))
# 36: 0.1 + (state - 1) * ((agent_feats[35] and agent_feats[36]) or (agent_feats[37] and agent_feats[38]) or (agent_feats[38] and agent_feats[39]) or (agent_feats[39] and agent_feats[40]))
# 37: state*(agent_feats[35] or agent_feats[36])
# 38:state * (1+ agent_feats[16])
# 39: state * ((agent_feats[7] or agent_feats[8]) and (agent_feats[16] or agent_feats[17] or agent_feats[40]))
# 40: state * (state * (agent_feats[9] and (agent_feats[2] > 4 or agent_feats[3] > 4) ) + (state * 0.1)) * (1. + 0.1*(agent_feats[9]-3))
# 41: state * (agent_feats[26] or agent_feats[30])
# 42: state * (16 * (agent_feats[9] and agent_feats[13]))
# 43: state * (agent_feats[2] - agent_feats[5]) * (agent_feats[2] > 2) * (agent_feats[5] < 2)
# 44:(1.5 * state * (agent_feats[31] and agent_feats[32])) + (state * agent_feats[31]) + (state * agent_feats[5] * agent_feats[11]) + (state * agent_feats[5] * agent_feats[34] * agent_feats[11])
# 45: state + state * (agent_feats[42] and (not agent_feats[23]) and (not agent_feats[24]) and (not agent_feats[25]))
# 46: state * agent_feats[35] * (agent_feats[7] and agent_feats[22])
# 47: state * (1 - agent_feats[23])
# 48: state * agent_feats[38] * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])
# 49:(state * (agent_feats[7] or agent_feats[11])) + (state*0.25)
# 50: state * (1 - (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22]))
# 51:(state + agent_feats[2] + 2)/3
# 52: state * (agent_feats[12] > 0)
# 53: state * (agent_feats[41] or agent_feats[42])
# 54: state * (agent_feats[11] and ((not agent_feats[10]) and agent_feats[9] and (agent_feats[8] and (agent_feats[7] and agent_feats[6]))))
# 2 2.963636363636364 1.6510452486903986
# 1
# >>>>>>>
# 0: state * ((agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40]) and not agent_feats[35] and not agent_feats[41])
# 1: state * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])
# 2: state * (1 - agent_feats[16])
# 3: state*(agent_feats[0] and ((agent_feats[1] and not agent_feats[4] and agent_feats[5] and agent_feats[6] < 10) or (agent_feats[1] and agent_feats[4] and agent_feats[5])))
# 4: 1 + 1 * (state and agent_feats[7] and agent_feats[2] > 3) + 2 * (state and (agent_feats[3] == 0) and (agent_feats[8] or agent_feats[9] or agent_feats[10])) + 3 * (state and (agent_feats[8] or agent_feats[9] or agent_feats[10])) + 4 * (state and agent_feats[11])
# 5: state * (agent_feats[26] and agent_feats[31]) * (agent_feats[27] and agent_feats[30])
# 6: state * ((agent_feats[13] and (agent_feats[8] or agent_feats[9])) and agent_feats[19])
# 7: 15 * state * agent_feats[2] / (agent_feats[5] + 1)**2
# 8: 1 + 0.1 * state * (agent_feats[31] * (agent_feats[32] + agent_feats[33]))
# 9:state * (5*agent_feats[35] and not agent_feats[23]) + state * (0.2 * agent_feats[35] and agent_feats[23])
# 10: state * (agent_feats[35] and ( (agent_feats[7] and agent_feats[16]) or (agent_feats[8] and agent_feats[17]) or (agent_feats[9] and agent_feats[18]) ))
# 11: state * (1 + 0.2 * (not agent_feats[23]))
# 12: state * ( 0.1*(agent_feats[37] or agent_feats[38]) + 0.3*(agent_feats[39] or agent_feats[40]) + 0.6*(agent_feats[41] or agent_feats[42]))
# 13:state * (agent_feats[7] and agent_feats[11])
# 14: state * (not agent_feats[16] and (agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22]))
# 15: state * (agent_feats[2] + 1)
# 16: state * agent_feats[12]
# 17: state * (agent_feats[35] or (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39]))
# 18: 15 * state * (agent_feats[11] and not (agent_feats[9] and agent_feats[10]))
# 19: state * (agent_feats[32] and agent_feats[28] + (agent_feats[28] and not(agent_feats[32])))
# 20: 1 + 10 * state * ((2 * agent_feats[2] - agent_feats[5]) + (agent_feats[2] - agent_feats[5])**2)
# 21: state * (agent_feats[32] and ((agent_feats[30] or agent_feats[31]) * 1.5))
# 22:state * (agent_feats[27] and agent_feats[32])
# 23: state * (agent_feats[32] and (not (agent_feats[20] or agent_feats[21] or agent_feats[22])))
# 24:  state*(agent_feats[42] and (not agent_feats[23]) and agent_feats[37] )
# 25: state * (agent_feats[28] and agent_feats[32])
# 26: state * (agent_feats[32] and agent_feats[16] or agent_feats[32] and agent_feats[17] or agent_feats[32] and agent_feats[18] or agent_feats[32] and agent_feats[19] or agent_feats[32] and agent_feats[20])
# 27: state * ((agent_feats[35] and (agent_feats[7] or agent_feats[8])) or ((agent_feats[35] and agent_feats[9]) and (agent_feats[18] or agent_feats[19])))
# 28: state * (agent_feats[31] and agent_feats[33])
# 29: 5 * state + (agent_feats[2] - agent_feats[5]) * 8
# 30: state * ( 1.1 * max(agent_feats[2] - 2 * agent_feats[5], 0) / 4 + agent_feats[5])
# 31: state * (agent_feats[28] or agent_feats[33])
# 32: state * (agent_feats[32] and agent_feats[27]) + state*3
# 33: state * (agent_feats[32] and not agent_feats[21])
# 34:(state * ((not agent_feats[23]) or (not agent_feats[24]) or (not agent_feats[25])))
# 35: state * (1 + (agent_feats[31] and agent_feats[32]))
# 36: state * (agent_feats[32] and (agent_feats[30] or agent_feats[31])) + (state == 0)
# 37: state * (agent_feats[33] and agent_feats[31] and not agent_feats[32])
# 38: state * (agent_feats[32] and agent_feats[27])
# 39: state * (agent_feats[28] or (agent_feats[32] and agent_feats[33]))
# 40: state * (agent_feats[26] and agent_feats[32] > 0)
# 41: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 42: state * (agent_feats[42] and not(agent_feats[23]) or (agent_feats[11] and agent_feats[42]))
# 43: state * ( (agent_feats[42] or agent_feats[41]) and (not agent_feats[23]) and (agent_feats[24] or agent_feats[25]) )
# 44: max(1, state) + state * (agent_feats[26]+1) * agent_feats[32]
# 45: state * (agent_feats[33] and (agent_feats[31] or ((agent_feats[32] and agent_feats[26]) or agent_feats[32])))
# 46: state * (agent_feats[27] or (agent_feats[32] and agent_feats[27]))
# 47: state * (agent_feats[11] or agent_feats[7])
# 48: state * (agent_feats[7] and agent_feats[16] and agent_feats[35])
# 49: state * ((agent_feats[11] and agent_feats[42]) and (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22]))
# 50: state * (agent_feats[26] and agent_feats[32])
# 51: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 52: state * ((agent_feats[31] or agent_feats[32]) and agent_feats[33])
# 53: state * (0.7 * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41]) + 0.3 * (agent_feats[38] or agent_feats[39]))
# 54: state + (1 if (not agent_feats[23]) else 0)
# 55: state * ( (1 - agent_feats[17]) and (1 - agent_feats[18]) and (1 - agent_feats[19]) and (1 - agent_feats[20]) and (1 - agent_feats[21]) and (1 - agent_feats[22]))
# 56: state * (1 + 0.25 * (1 - agent_feats[23]))
# 57: state * (agent_feats[19] or agent_feats[20] or agent_feats[21]) and ((agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39]) and (agent_feats[40] or agent_feats[41]))
# 58:(state + 1) * (agent_feats[26] or agent_feats[32])
# 59: state * (agent_feats[35] and agent_feats[36] and state == 1)
# 60: state * ( agent_feats[36] and (agent_feats[37] or agent_feats[38] or agent_feats[39]) or agent_feats[40] or agent_feats[41] or agent_feats[42] )
# 61: state * (agent_feats[1]*(agent_feats[37] or agent_feats[38] or agent_feats[39]))
# 62:12*state*(agent_feats[2]>0)
# 63: state * (1 - agent_feats[16]) + state * (1 - agent_feats[17]) + state * (1 - agent_feats[18]) + state * (1 - agent_feats[19]) + state * (1 - agent_feats[20]) + state * (1 - agent_feats[21])
# 64: state * (1 + agent_feats[35] or agent_feats[36]) * (1 + agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# 65: 25 + state * (20 <= sum(agent_feats[35:42]) <= 30)
# 66: state * sum(agent_feats[35:38])
# 67: state * (agent_feats[10] and agent_feats[7])
# 68: state * (agent_feats[7] or agent_feats[11])
# 69: state*(state + 0.01*(agent_feats[7] or agent_feats[8] or agent_feats[9] or agent_feats[10] or agent_feats[11]))
# 70: state * agent_feats[12]
# 71: 10*state * (1 - agent_feats[16] or 1 - agent_feats[17] or 1 - agent_feats[18] or 1 - agent_feats[19] or 1 - agent_feats[20] or 1 - agent_feats[21] or 1 - agent_feats[22])
# 72:state * ((0.5 * (not agent_feats[35])) and (0.5 * (not agent_feats[36])))
# 73: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21])
# 74: 5 * state + 7 * (1 - agent_feats[16]) + 5 * (1 - agent_feats[17]) + 3 * (1 - agent_feats[18]) + (1 - agent_feats[19]) + (1 - agent_feats[20]) + (1 - agent_feats[21]) + (1 - agent_feats[22])
# 75: state * (1 + (agent_feats[16] + agent_feats[17] + agent_feats[18] + agent_feats[19] + agent_feats[20] + agent_feats[21] + agent_feats[22]))
# 76:(state + 0.01) * (((agent_feats[11] and agent_feats[2] > 5) or (agent_feats[10] and agent_feats[2] > 4)) + (agent_feats[2] > 8 or agent_feats[11]))
# 77: state * (not agent_feats[16] or not agent_feats[17] or not agent_feats[18] or not agent_feats[19])
# 78: 20 * (agent_feats[42] and (state))
# 79: state * (agent_feats[34] or (agent_feats[35] and agent_feats[39]))
# 80: 1 + (state * (agent_feats[2] > 0 and agent_feats[3] > 0))
# 81: state * (1.5 * (agent_feats[2] > 0))
# 82: 10 * state *  (agent_feats[6] > 5 and (agent_feats[32] or agent_feats[33] or agent_feats[34]))
# 83: state * (agent_feats[26] or agent_feats[31] or (agent_feats[27] and agent_feats[30]))
# 84: (state + 1) * ((agent_feats[11] or agent_feats[10]) and (agent_feats[2] >= 3 or agent_feats[2] >= 4))
# 85: state * (8 * agent_feats[10] + 7 * agent_feats[11])
# 86: state * agent_feats[12]
# 87: state + (agent_feats[15] or agent_feats[22])
# 88: state * agent_feats[12]
# 89: state * (2 * (agent_feats[13] and agent_feats[9]) + 1 * (agent_feats[13] or agent_feats[9]))
# 90: state * (agent_feats[9] or (agent_feats[2] >= 5 and agent_feats[3] >= 3))
# 91: 10*state + 5*(agent_feats[26] or agent_feats[31])
# 92: state * (agent_feats[32] and (not(agent_feats[21] or agent_feats[22])))
# 93: state * ( 12.5 / 100 * agent_feats[39] or 12.5 / 100 * agent_feats[40] or 12.5 / 100 * agent_feats[41] or 12.5 / 100 * agent_feats[42] )
# 94: state * ((agent_feats[36] and agent_feats[37] and agent_feats[38] and agent_feats[39] and agent_feats[40] and agent_feats[41] and agent_feats[42]) or agent_feats[35])
# 95: state * ((agent_feats[26] or agent_feats[31]) and not(agent_feats[27] or agent_feats[28] or agent_feats[30]))
# 96: 10 * state * (agent_feats[2] - agent_feats[5]) * agent_feats[2]
# 97: state * (agent_feats[13] and (agent_feats[9] or agent_feats[10]))
# 98: state * (agent_feats[33] and agent_feats[28] and agent_feats[32])
# 99: state * (agent_feats[2] >= 3 and agent_feats[7] or agent_feats[2] >= 4 and agent_feats[8] or agent_feats[2] >= 5 and agent_feats[9])
# 100: state * (agent_feats[11] or agent_feats[9] or agent_feats[7])
# 101: state + (agent_feats[11] and agent_feats[9] or agent_feats[10])
# 102: 4 + (state * (agent_feats[13] and ((agent_feats[8] or agent_feats[9]))))
# 103: 5 * (1 * state and (agent_feats[2] + 1 - agent_feats[5] >= 3))
# 104: state * max(0, agent_feats[31]-0.7) * (agent_feats[32] or agent_feats[33])
# 105: state * (agent_feats[32] and (agent_feats[26] or agent_feats[28]))
# 106: state * agent_feats[32] * (not agent_feats[21])
# 107: state * (agent_feats[32] and (not agent_feats[21] and not agent_feats[22]))
# 108: state * ((agent_feats[2] - agent_feats[5]) * agent_feats[4])
# 109: state * ((agent_feats[32] and agent_feats[31]) or (agent_feats[32] and not agent_feats[31]))
# 110: state * (agent_feats[42] and (not agent_feats[23] and not agent_feats[24] and not agent_feats[25]))
# 111: state * (agent_feats[33] and agent_feats[31])
# 112: state * (agent_feats[26] or state * 2 and agent_feats[31])
# 113:  state * (agent_feats[28] and agent_feats[32])  + 2**5
# 114: state * ( agent_feats[28] and agent_feats[32] )
# 115: (state + 1) * (agent_feats[33] and agent_feats[31])
# 116: (agent_feats[23] and not agent_feats[42]) and (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]) * (state * 50)
# 117: (state and agent_feats[35]) * max(((agent_feats[7] or agent_feats[8]) and (agent_feats[16] or agent_feats[17])), 0)
# 118: state * (agent_feats[32] and agent_feats[26]) + 2*state*agent_feats[26]
# 119: state * (agent_feats[27] and agent_feats[32])
# 120: state * (agent_feats[27] and agent_feats[32]) + 1
# 121: state * (agent_feats[42] and not agent_feats[23])
# 122: state * agent_feats[35] * (agent_feats[3] < 3 and (agent_feats[16] or agent_feats[17]))
# 123: (1.0 + 0.3 * int(not agent_feats[23])) * state
# 124: state * ((agent_feats[13] and agent_feats[9]) or agent_feats[13])
# 125: state * (0.45 * (agent_feats[39] or agent_feats[38] or agent_feats[37]) + 0.55 * agent_feats[36])
# 126: state * (agent_feats[33] and agent_feats[31])
# 127: state * (agent_feats[33] and (agent_feats[31] or agent_feats[32])) * ( agent_feats[33] and agent_feats[31])
# 128: state * (agent_feats[7] and any(agent_feats[16:23]) and agent_feats[35])
# 129: state * (1+(not agent_feats[23]))
# 130: state * (agent_feats[37] or agent_feats[38] or agent_feats[39])
# 131: state * (1 - agent_feats[35])
# 132:  state + 0.4 * (agent_feats[32] & agent_feats[26] )
# 133: state * (agent_feats[26] and agent_feats[32])
# 134: state + agent_feats[23] * 0.2
# 135: (state + 15) * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39])
# 136:(state + 1) * (agent_feats[7] or agent_feats[10] or agent_feats[8] or agent_feats[9])
# 137: 10 + state * (6 * agent_feats[2] - 5 * agent_feats[5])
# 138: 10 * state * (1 - (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22]))
# 139: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 140: 1 + state * (agent_feats[35] and agent_feats[36] and agent_feats[37] and agent_feats[38] or agent_feats[36] and agent_feats[37] and agent_feats[38] and agent_feats[39] or agent_feats[37] and agent_feats[38] and agent_feats[39] and agent_feats[40])
# 141: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 142: state * (agent_feats[7] or agent_feats[11])
# 143:-(state *(agent_feats[16] and agent_feats[17] and agent_feats[18]))
# 144: state * (agent_feats[35] and agent_feats[36])
# 145: state * (((agent_feats[16] or agent_feats[17] or agent_feats[18]) and agent_feats[10]) or (not agent_feats[11]))
# 146: state*(1/43*agent_feats[35] + 1/43*agent_feats[36] + 1/43*agent_feats[37] + 1/43*agent_feats[38]
# + 1/43*agent_feats[39] + 1/43*agent_feats[40] + 1/43*agent_feats[41] + 1/43*agent_feats[42])
# 147: state * (agent_feats[7] and agent_feats[11])
# 148: state * (1 + (agent_feats[32] and agent_feats[31]))
# 149: state * (2**(7 - agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22]))
# 150: 2 * (agent_feats[2] + 1) * state
# 151: 100 * state * (1 - agent_feats[16])
# 152: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19])
# 153: state * (agent_feats[7] or (agent_feats[2] >= 5 and agent_feats[3] >= 2))
# 154: state**((not agent_feats[17]) and (not agent_feats[18]) and (not agent_feats[19]) and (not agent_feats[20]) and (not agent_feats[21]) and (not agent_feats[22]))
# 155: state * (agent_feats[2] + 1)
# 156: state * agent_feats[12]
# 157: (state + agent_feats[8] + 2*agent_feats[10])* (1 + agent_feats[42])
# 158: state * (agent_feats[23] and (agent_feats[10 or not agent_feats[15]] or agent_feats[29] or agent_feats[0 < 20 or 0 > 19]))
# 159: state*( agent_feats[23] and (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]) )*0.25+state*(not agent_feats[23] and agent_feats[36] and agent_feats[37] and agent_feats[38] and agent_feats[39] and agent_feats[40] and agent_feats[41] and agent_feats[42] )*0.5+state*0.1
# 160: state * (agent_feats[26] and agent_feats[31]) * (1 + 0.1)
# 161: state * (agent_feats[2] + 1)
# 162:state * agent_feats[12]
# 163: state * (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# 164: state * (agent_feats[7] or ((agent_feats[8] or agent_feats[9]) and agent_feats[3] > 4))
# 165:  state * (agent_feats[11] and (agent_feats[2] + agent_feats[3] > 5) and agent_feats[10] or agent_feats[7])
# 166: state * agent_feats[13] * (agent_feats[8] or agent_feats[9])
# 167: state * agent_feats[12]
# 168: 2*state * (agent_feats[42] and not(agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41]))
# 169: state * (1 + (agent_feats[10] or agent_feats[11]))
# 170: 1.1*(state + agent_feats[26] + agent_feats[31])*(1+state) * (1+agent_feats[7])
# 171: state * (agent_feats[11] and ((agent_feats[35]) + (agent_feats[36]) and (agent_feats[17] and agent_feats[18])))
# 172: 10 * state + (1-state) * (agent_feats[26] or agent_feats[31])
# 173: state * (1 + agent_feats[2] - agent_feats[5])
# 174: 1000*state + 100*agent_feats[0] + 10*agent_feats[36] + 1*agent_feats[42]
# 175:state + 1 and agent_feats[11]
# 176: state * ((agent_feats[32]) and (agent_feats[21]==0) and (-agent_feats[26]))
# 177: state * (agent_feats[13] and (agent_feats[9] or agent_feats[10]))
# 178: state * (agent_feats[13] and  agent_feats[9] or  agent_feats[10])
# 179: state * agent_feats[11]
# 180: state * (agent_feats[31] + agent_feats[32])
# 181: state * agent_feats[32] * (not agent_feats[21])
# 182: state * (agent_feats[28] and agent_feats[32])
# 183: (state + 1)* 0.1* (not agent_feats[23])
# 184: state * (((1+(agent_feats[2]-agent_feats[5])/(agent_feats[2]+0.1)**0.5)**2 +1))/(2*agent_feats[3])
# 185: (state+1)*(3*agent_feats[2]-agent_feats[5])*(agent_feats[2]+1)/(agent_feats[2]-agent_feats[5]+1)
# 186: state * (agent_feats[32] and (not agent_feats[21] or not agent_feats[22]))
# 187: state * (1.0 + 0.1*(not(agent_feats[23] or agent_feats[24] or agent_feats[25])) and (agent_feats[35] or agent_feats[42]))
# 188: state * (agent_feats[28] and agent_feats[32])
# 189: state * agent_feats[31] * agent_feats[32]
# 190: state * (agent_feats[27] and agent_feats[32])
# 191:state + 0.2 * (agent_feats[31] and agent_feats[32])
# 192: state * (agent_feats[28] or (agent_feats[32] and agent_feats[28]))
# 193: state * (agent_feats[36] and ((agent_feats[7] or agent_feats[8]) and (agent_feats[17] or agent_feats[18])))
# 194: state + 4 * (agent_feats[27] and agent_feats[32])
# 195:state * ((agent_feats[35] or agent_feats[36]) and agent_feats[38] and agent_feats[39])
# 196: state * (agent_feats[42] == 1 and agent_feats[23] == 0 or agent_feats[42] > 2)
# 197:state * (agent_feats[33] and state * agent_feats[31])
# 198: state * (agent_feats[42] and (agent_feats[35] and not agent_feats[23] and not any(agent_feats[24:27])))
# 199:state * (agent_feats[27] or (agent_feats[32] and agent_feats[27]))
# 200: 1 + (10*state) + ((not agent_feats[23]) * 1)
# 201: state * (agent_feats[33] and (not agent_feats[29] and not agent_feats[30] and agent_feats[31]))
# 202: state * (agent_feats[35] and (agent_feats[7] or agent_feats[8] or agent_feats[9] or agent_feats[10] or agent_feats[11]) and (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20]))
# 203:state * (agent_feats[32] and agent_feats[26] and (not agent_feats[27]))
# 204: state * ((agent_feats[7] or agent_feats[8]) and agent_feats[35] and agent_feats[16])
# 205: state * (((agent_feats[31] and agent_feats[33]) or (agent_feats[32] and agent_feats[33])) and agent_feats[33])
# 206: state * (agent_feats[35] or (agent_feats[36] and not agent_feats[37]) or (agent_feats[37] and not agent_feats[38]) or (agent_feats[38] and not agent_feats[39]) or (agent_feats[39] and not agent_feats[40]))
# 207: (state or (agent_feats[7] or agent_feats[11])) and state
# 208: state * (agent_feats[26] or (agent_feats[32] and agent_feats[26]))
# 209: state * (agent_feats[23] == 0 or agent_feats[23] == 1)
# 210: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])
# 211: (state * 2.5) + (agent_feats[23] and not agent_feats[24] and not agent_feats[25])
# 212: state * ((agent_feats[26] or agent_feats[32]) and agent_feats[32])
# 213: state * (agent_feats[7] or agent_feats[11])
# 214: state + 0.1 * ((agent_feats[39] and not agent_feats[42]) or (agent_feats[40] and not agent_feats[42]))
# 215:state * (agent_feats[10] and (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[41]))
# 216:state * (2*agent_feats[35] or 2*agent_feats[36])
# 217:  state * ((agent_feats[36] or agent_feats[37] or agent_feats[38]) and (agent_feats[39] or agent_feats[40] or agent_feats[41]))
# 218: state * (agent_feats[36] or agent_feats[37] or (agent_feats[38] and not agent_feats[35]) or agent_feats[39])
# 219: state * (22 not in agent_feats)**5
# 220:(state*1.1 + 5*agent_feats[16])/(state + 1)
# 221:(state + 1) * (agent_feats[42] or (agent_feats[35] and agent_feats[36]))* 100
# 222: state * (agent_feats[7] or agent_feats[11])
# 223: (state+1) * (agent_feats[7] or agent_feats[11])
# 224: state * ((not agent_feats[16]) or (not agent_feats[17]) or (not agent_feats[18]) or (not agent_feats[19]) or (not agent_feats[20]) or (not agent_feats[21]) or (not agent_feats[22]))
# 225: state * (1 + 5*agent_feats[35] + 5*agent_feats[36] + 5*agent_feats[37])
# 226:(state) + 0.1 * (agent_feats[2] > 0) * state
# 227: state * ( (agent_feats[16] or agent_feats[17] or agent_feats[18]) * 1.5)
# 228: state * ((not agent_feats[18]) + (not agent_feats[17]) + (not agent_feats[16]))
# 229: state * (1 + (not agent_feats[16] or not agent_feats[17] or not agent_feats[18] or not agent_feats[19] or not agent_feats[20] or not agent_feats[21] or not agent_feats[22]))
# 230: state * ((agent_feats[0] + agent_feats[1] + agent_feats[4]) * 2 + 3)
# 231:state * (not agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22])
# 232: state*(1 + agent_feats[2])
# 233: state * (agent_feats[12])
# 234: state * (agent_feats[16] or not agent_feats[12] or not agent_feats[26])
# 235:state * (1 + 0.1 * agent_feats[2])
# 236: state * (max(agent_feats[2], 1))
# 237: state * (agent_feats[9] or (agent_feats[7] and agent_feats[2] >= 4))
# 238: state * (agent_feats[15] or agent_feats[28])
# 239: state * max(0, (agent_feats[42] - 1.0) * (0.125)**(-1) )
# 240: state * ((agent_feats[9] or agent_feats[11]) and (agent_feats[2] > agent_feats[3] and agent_feats[2] > 4))
# 241: (state + agent_feats[12]) * 10
# 242: 2.5*state*(agent_feats[12])
# 243: state * (12 & agent_feats[12])
# 244: (agent_feats[9] or agent_feats[10]) or (agent_feats[2] > 3 and state)
# 245: state * (sum(agent_feats[26:32]) >= 1)
# 246: state * pow(agent_feats[10] or agent_feats[11], 2)
# 247: state * (agent_feats[26] or agent_feats[31]) + state * (agent_feats[16] or agent_feats[19])
# 248: state * (agent_feats[0]+(15*agent_feats[-1]) + (30*agent_feats[-2]) + (60*agent_feats[-3]) + (120*agent_feats[-4]) + (240*agent_feats[-5]) + (500*agent_feats[-6]))
# 249: state * (agent_feats[42] and agent_feats[41]) * (agent_feats[41] and agent_feats[40]) * (agent_feats[40] and agent_feats[39]) * (agent_feats[39] and agent_feats[38]) * (agent_feats[38] and agent_feats[37]) * (agent_feats[37] and agent_feats[36])
# 250: state * (agent_feats[13] and (agent_feats[8] or agent_feats[9]))
# 251: 2 * state + (agent_feats[26] or agent_feats[31])
# 252: 10 * ((state == 1) and (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]))
# 253: state * (agent_feats[32] and (not agent_feats[21]))
# 254: state * (agent_feats[13] and agent_feats[9] or agent_feats[10])
# 255: state * (agent_feats[11] and (not state and agent_feats[10]))
# 256: state * (agent_feats[11] and agent_feats[11] or (agent_feats[10] or agent_feats[9]) and agent_feats[11])
# 257: state * ((agent_feats[13] and (agent_feats[8] or agent_feats[9])) or (agent_feats[13] and not(agent_feats[8] or agent_feats[9])))
# 258:(state * (1.5 * agent_feats[2]) + agent_feats[4] * agent_feats[5]) * (state and agent_feats[2] > 2 and agent_feats[5] < 3)
# 259:state * ((agent_feats[28] or agent_feats[32]) + agent_feats[28])
# 260: (agent_feats[2] - agent_feats[5] - 2) ** 2 + 5 * state
# 261: state * (agent_feats[32] and not any(agent_feats[20:22]))
# 262: state * (agent_feats[32] and (not agent_feats[21]))
# 263: state * (agent_feats[31] * agent_feats[32] or (agent_feats[26] and not agent_feats[31]))
# 264: state * (1 + abs((agent_feats[2] - agent_feats[5]) / agent_feats[2]))
# 265: state * (agent_feats[11] + 0.1 * agent_feats[10])
# 266: state * (agent_feats[27] and agent_feats[32])
# 267: state * (agent_feats[32] and (agent_feats[30] or agent_feats[31]) )  +  1
# 268: state * (agent_feats[32] and agent_feats[28])
# 269: state * (agent_feats[28] and agent_feats[32]) + (not state)
# 270: state * (agent_feats[31] or (agent_feats[32] and agent_feats[31] or agent_feats[31]))
# 271: state * (agent_feats[42] and not(agent_feats[23] or agent_feats[24] or agent_feats[25])) + 0.5 * (agent_feats[42] and (agent_feats[23] or agent_feats[24] or agent_feats[25])) * state
# 272: state * (agent_feats[42] and (not agent_feats[23] and not agent_feats[24] and not agent_feats[25]) or (agent_feats[35] or agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]))
# 273: state * (agent_feats[33] and (agent_feats[31] or agent_feats[32]))
# 274: state * ((agent_feats[27] or agent_feats[28]) and agent_feats[32])
# 275:-1 + 10 * state * agent_feats[27] * agent_feats[32]
# 276:  state + ((agent_feats[42] >= 5) and agent_feats[23] == 0)
# 277:(state * agent_feats[35]) * (agent_feats[7] or (agent_feats[8] and (agent_feats[18] or agent_feats[20])))
# 278: state * (agent_feats[32] or (agent_feats[33] and agent_feats[34]) and not(agent_feats[21] or agent_feats[22]))
# 279: state * ( (agent_feats[7] or agent_feats[8]) and (agent_feats[16] or agent_feats[17]) and agent_feats[35] )
# 280: state * (agent_feats[33] and agent_feats[31])
# 281: state * (agent_feats[26] and agent_feats[32])
# 282: state * (agent_feats[31] and agent_feats[33])
# 283: state * ( ( agent_feats[35] or (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20]) ) and agent_feats[36] )
# 284: state * (0.1 * (1.0 - agent_feats[23]) + 0.9)
# 285: state * (1. - agent_feats[23]) * 1.1
# 286: state * (agent_feats[26] and agent_feats[32])
# 287: state * (agent_feats[37] or agent_feats[38]) and agent_feats[39] and (not agent_feats[40]) and (not agent_feats[41])
# 288: state * (agent_feats[26] or (agent_feats[32] and agent_feats[26]))
# 289: state * ((agent_feats[23] or (not agent_feats[23] and agent_feats[42])))
# 290:  state *  (agent_feats[32] and (agent_feats[28] or agent_feats[29]))
# 291: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 292: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 293: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39])
# 294: 10.0 * state * ((agent_feats[37] or agent_feats[38]) or (agent_feats[39] or agent_feats[40]))
# 295: state * agent_feats[35] * (1 + agent_feats[36])
# 296: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39])
# 297: state * (agent_feats[7] or agent_feats[11])
# 298: state * (agent_feats[35] or agent_feats[36] or agent_feats[37])
# 299: state * (agent_feats[7] or agent_feats[11])
# 300: state * agent_feats[35]
# 301: state * (20 + 100 * (agent_feats[16] or agent_feats[17]))
# 302: state * (agent_feats[27] or (agent_feats[27] and agent_feats[32]))
# 303: (state + 1) * (agent_feats[7] or agent_feats[11])
# 304: state * (agent_feats[16] * 10 + agent_feats[17] * 9 + agent_feats[18] * 8 + agent_feats[19] * 7 + agent_feats[20] * 6 + agent_feats[21] * 5 + agent_feats[22] * 4)
# 305:state * (not agent_feats[16] and not agent_feats[17])
# 306: state * (1 + 0.2 * ( 1 - agent_feats[16] + 1 - agent_feats[17] + 1 - agent_feats[18] + 1 - agent_feats[19] + 1 - agent_feats[20] + 1 - agent_feats[21] + 1 - agent_feats[22] ))
# 307: 5 * (state) + (-1/agent_feats[17]) + (-1/agent_feats[18])
# 308: state * (agent_feats[0] == 1 or agent_feats[1] == 1) and (agent_feats[2] == 0 or agent_feats[3] == 0) and (agent_feats[26] and agent_feats[31])
# 309: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19])
# 310: state * (1 + agent_feats[2]) * ( ( agent_feats[2] >= 1 ) or ( agent_feats[3] >= 1 ) )
# 311: state*(agent_feats[5]+agent_feats[0]+agent_feats[9]+agent_feats[42])
# 312: state * ((agent_feats[33] and agent_feats[31]) or (agent_feats[33] and (not agent_feats[30] and not agent_feats[29] and not agent_feats[28] and not agent_feats[27] and not agent_feats[26])))
# 313: state * (1 + (agent_feats[2] > 0))
# 314: 1.1*state + (agent_feats[4] or agent_feats[5]) + (agent_feats[6]<14 or agent_feats[6]>28)
# 315: state * (agent_feats[2] > 0)
# 316: state * ((agent_feats[9] and agent_feats[10]) and (agent_feats[2] > 4 and agent_feats[2] < 12))
# 317: state * agent_feats[12]
# 318: (state + 5) * (agent_feats[11] or (agent_feats[10] and agent_feats[3] >= 4))
# 319: agent_feats[12]
# 320: state * (agent_feats[10] or (agent_feats[9] and (agent_feats[2] >= 3 or agent_feats[3] > 0)))
# 321: state * agent_feats[12]
# 322: 2.5 * state * ((agent_feats[26] or agent_feats[31]) and not (agent_feats[27] or agent_feats[28]) )
# 323:state * 12 * ((agent_feats[35] or agent_feats[36]) and (agent_feats[37] and agent_feats[38] and agent_feats[39] and agent_feats[40] and agent_feats[41] and agent_feats[42]))
# 324: state * ((not agent_feats[26]) and agent_feats[32])
# 325: -state + (1.005*agent_feats[26] and agent_feats[31])
# 326: state * (agent_feats[35] or (agent_feats[36] and agent_feats[42]))
# 327: state*(agent_feats[26] or agent_feats[31] or (agent_feats[32] and agent_feats[34]))
# 328: state * (agent_feats[35] or (agent_feats[39] and agent_feats[40] and agent_feats[41] and agent_feats[42]))
# 329: state * (agent_feats[13] and (agent_feats[8] or agent_feats[9]))
# 330: state + ((agent_feats[11] or agent_feats[12]) * state)
# 331: 1.2 * state * agent_feats[13] * (agent_feats[8] or agent_feats[9])
# 332: state * (agent_feats[11] or agent_feats[41])
# 333: state * (agent_feats[13] and (agent_feats[9] or agent_feats[10]) and agent_feats[11])
# 334: state * (1 + 0.1*agent_feats[11])
# 335: state * (100 + 10 * agent_feats[2] + agent_feats[5])
# 336:(state * (-1 * agent_feats[32]) + state) * (agent_feats[21] and agent_feats[22])
# 337: state * (2 + (agent_feats[37] and ((agent_feats[40]) or (agent_feats[41]))))
# 338: state * (1+ (agent_feats[2]-agent_feats[5])/10 )
# 339: state * (agent_feats[32] and agent_feats[20] and not agent_feats[21])
# 340: state * (agent_feats[32] and ((not agent_feats[16]) or (not agent_feats[17]) or (not agent_feats[18]) or (not agent_feats[19]) or (not agent_feats[20])))
# 341: state * (agent_feats[2] - agent_feats[5])^2
# 342:3 + 0.1 * (state and agent_feats[32] and agent_feats[31]) + 0.02 * (state and agent_feats[32]) + 0.01 * (state and (not agent_feats[32]))
# 343: 3 * (state and (agent_feats[32] and agent_feats[28]))
# 344: state * (agent_feats[32] or (agent_feats[31] and agent_feats[33]))
# 345:(state + agent_feats[28] * agent_feats[32]) * 2.
# 346: state * (agent_feats[32] or (agent_feats[31] and (agent_feats[30] or (agent_feats[29] or agent_feats[28] or agent_feats[27] or agent_feats[26]))))
# 347:(state * agent_feats[28] + state * agent_feats[32]) / 2
# 348: state * (agent_feats[42] and not agent_feats[23] and (agent_feats[42] == agent_feats[41]))
# 349:"state * (pow(3 , agent_feats[35] or agent_feats[36] or agent_feats[37]) - 1)"
# 350: state * ((agent_feats[27] and agent_feats[32]))
# 351: (state + 1) * (agent_feats[42] and not agent_feats[23])
# 352: state * (agent_feats[32] and (agent_feats[27] or agent_feats[28]))
# 353: state * (agent_feats[23] and agent_feats[42]) + (agent_feats[23] and (not agent_feats[42]) and agent_feats[39])**2
# 354: state * (agent_feats[27] and agent_feats[32])
# 355: state * (agent_feats[5] and not agent_feats[35] and (agent_feats[16] and (agent_feats[21] or agent_feats[22])))
# 356: state * (state > 0) * (agent_feats[33] and agent_feats[31])
# 357: (12 * agent_feats[7]) + (agent_feats[7] and agent_feats[35]) * (agent_feats[17] + agent_feats[22] + agent_feats[21] + agent_feats[20])
# 358: state * (agent_feats[33] and agent_feats[31]) + 1
# 359: state * (agent_feats[35] and (agent_feats[11] or (agent_feats[16] and agent_feats[8])))
# 360: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22])
# 361: state * (2**agent_feats[31]*agent_feats[33])
# 362: state * (1 + (1 if not agent_feats[23] and not agent_feats[24] and not agent_feats[25] else 0) * 0.1)
# 363: 15 * state * (agent_feats[32] and agent_feats[26 or agent_feats[27]])
# 364:state * (agent_feats[26] and agent_feats[32]) + agent_feats[31]
# 365: state * (agent_feats[23] and not agent_feats[23])
# 366: state + (not agent_feats[23])
# 367: state * (agent_feats[26] or (agent_feats[32] and (agent_feats[6] > 180)))
# 368: state * (      (agent_feats[36] or agent_feats[37]) or (agent_feats[38] and agent_feats[39]) or (agent_feats[40] or agent_feats[41]) )
# 369: 2 * state * (agent_feats[37] and agent_feats[38] and agent_feats[39] and agent_feats[40] and agent_feats[41]) + 1 * state * (agent_feats[36] or agent_feats[42])
# 370: state * (agent_feats[13] or agent_feats[27] or agent_feats[11]) * (agent_feats[9] and agent_feats[10])
# 371: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 372:state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])
# 373: state * (3 + ((agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40]) and not (agent_feats[35] or agent_feats[42])))
# 374: state * (agent_feats[38] and agent_feats[39] and agent_feats[40])
# 375: state * (agent_feats[7] or agent_feats[11])
# 376: state *  (agent_feats[35] + agent_feats[42])
# 377: state * (agent_feats[7] or agent_feats[11])
# 378: (state + 1) * (agent_feats[36] or agent_feats[35])
# 379: state * ( ( ( ~ agent_feats[7] ) & ( ~ agent_feats[8] ) & ( ~ agent_feats[9] ) & ( ~ agent_feats[10] ) ) | ( ( ~ agent_feats[11] ) & ( ~ agent_feats[12] ) & ( ~ agent_feats[13] ) ) )
# 380: 5 * state * agent_feats[35] + 3 * state * agent_feats[36]
# 381: state * agent_feats[16]
# 382: state * (1*(agent_feats[10] or agent_feats[11]) and (agent_feats[2] > 3 or agent_feats[2] == 3 and agent_feats[4] > 1))
# 383: state * (1 - agent_feats[16] + 5 * agent_feats[17] + 10 * agent_feats[18] + 15 * agent_feats[19] + 20 * agent_feats[20] + 25 * agent_feats[21] + 30 * agent_feats[22])
# 384: state * (1 + (1 - agent_feats[16]))
# 385: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22])
# 386: state * (1-agent_feats[16]) * 2
# 387: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22])
# 388: state * ((agent_feats[2] > 0) + 1)
# 389: state * (1.5) ** (agent_feats[13] and agent_feats[31]) + (1.25) ** (agent_feats[13] and agent_feats[27]) + (1.2) ** (agent_feats[13] or agent_feats[31]) + (1.15) ** (agent_feats[31] or agent_feats[27]) + (1.1) ** (agent_feats[27] or agent_feats[13])
# 390: 0.05 * state + 0.03 * (2 * agent_feats[2]) + 0.95
# 391: state * (agent_feats[2] > 1 or agent_feats[3] > 1)
# 392: state * (agent_feats[29] or agent_feats[30] or agent_feats[31] or (agent_feats[35] and not agent_feats[36]))
# 393: state * (agent_feats[0] and agent_feats[6] or agent_feats[30] or agent_feats[32] or agent_feats[21])
# 394: state * agent_feats[3] * ((agent_feats[26] or agent_feats[31]) and not (agent_feats[27] or agent_feats[28] or agent_feats[29] or agent_feats[30]))
# 395: state * agent_feats[12]
# 396: state * agent_feats[12]
# 397: state * agent_feats[12]
# 398: state * (agent_feats[2] == 0 and agent_feats[9] and agent_feats[10])
# 399: (state)**2** + max(agent_feats[2]*agent_feats[10]*10, agent_feats[2]*10, state)
# 400: state * (agent_feats[10] | agent_feats[3])
# 401: state * (agent_feats[42] if agent_feats[36] or agent_feats[37] else 0)
# 402: state * (agent_feats[35] or (agent_feats[36] and agent_feats[37]) or (agent_feats[38] and (agent_feats[39] or agent_feats[40])))
# 403: state * (max(agent_feats[35:43]) or max(agent_feats[36:42]))
# 404: (state) * (10 + (2 * (agent_feats[26] or agent_feats[31]) + 1 * (agent_feats[25] or agent_feats[30]) + (agent_feats[24] or agent_feats[29])))
# 405: state + (agent_feats[26] or agent_feats[31] or agent_feats[32] or agent_feats[33])
# 406: state * ( (agent_feats[26] and agent_feats[31]) or (agent_feats[27] and agent_feats[30]) )
# 407: state * ((agent_feats[13] and state) and (agent_feats[8] or agent_feats[9]))
# 408: state * (0.1*agent_feats[11] + agent_feats[10])
# 409: state * (agent_feats[13] and (agent_feats[9] or agent_feats[10]))
# 410: state + (agent_feats[11] - 0.5)
# 411: state * (agent_feats[8] and agent_feats[9] and agent_feats[13])
# 412: state * (agent_feats[11] or agent_feats[38])
# 413: state * (agent_feats[13] and (agent_feats[9] or agent_feats[10]))
# 1 3.1449275362318843 1.9556090195284637
# 6
# >>>>>>>
# 0: state * ( agent_feats[42] and not agent_feats[23] or agent_feats[42] and agent_feats[23] and not agent_feats[26] )
# 1: state * (agent_feats[16] and agent_feats[35])
# 2: state * (not agent_feats[23])
# 3: state * ((agent_feats[36] or agent_feats[37]) and not(agent_feats[35] and agent_feats[42]) and (agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]))
# 4: state * (agent_feats[7] or agent_feats[11])
# 5: state * (agent_feats[16]+agent_feats[17]+agent_feats[18]+agent_feats[19]+agent_feats[20]+agent_feats[21])
# 6: state * (1.02**agent_feats[2])
# 7: state * agent_feats[12]
# 8: max(15, min(60, (state+1) * pow(agent_feats[42],0.4)))
# 9: state * (agent_feats[11] or agent_feats[10])
# 10: state * (agent_feats[32] * (not agent_feats[21]))
# 11: state * agent_feats[32] * agent_feats[28]
# 12: state * (agent_feats[27] or (agent_feats[32] and agent_feats[27]))
# 13: state + (agent_feats[33] and agent_feats[31])*2
# 14: state * (agent_feats[26] and agent_feats[32]) + 1
# 15: state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 16: state + 1 + (4 * int(agent_feats[35])) + (2 * int(agent_feats[36]))
# 17: (state + (1 - agent_feats[15])) * 10
# 18: state * (20 * (agent_feats[11] == 1) + 20 * (agent_feats[6] >= 15) and agent_feats[6] < 30)
# 19: state * (agent_feats[2] >= 5 and (agent_feats[9] or agent_feats[10] or agent_feats[11]))
# 20: state * (agent_feats[26] and agent_feats[31] and 1.005 or 1.0)
# 21: state * (agent_feats[13] and (agent_feats[9] or agent_feats[10]))
# 22: 100 * state + 10 * agent_feats[2] * (1 - agent_feats[5] / 3) + 5*(agent_feats[2] - agent_feats[5])*(agent_feats[2] - agent_feats[5])
# 23: state * ( ( agent_feats[31] or agent_feats[30] ) and agent_feats[32] )
# 24: state * ((agent_feats[42] and (not agent_feats[23])) or (agent_feats[41] and (not agent_feats[23]) and agent_feats[25]))
# 25: state * ( (agent_feats[11] and agent_feats[42]) or ((agent_feats[7] or agent_feats[8]) and (agent_feats[16] or agent_feats[17]) and agent_feats[42]) )
# 26: state * (1 + (not agent_feats[23]))
# 27: state * ((agent_feats[37] or agent_feats[38]) and (agent_feats[38] or agent_feats[39]))
# 28: state * (agent_feats[7] or agent_feats[11])
# 29: state * (not agent_feats[16] or not agent_feats[17] or not agent_feats[18])
# 30: state * (agent_feats[11] or (agent_feats[2] >= 2 and agent_feats[3] >= 2))
# 31: agent_feats[12]
# 32:state * (100*agent_feats[42] or agent_feats[41])
# 33: state * (agent_feats[10] or agent_feats[11])
# 34: state * (agent_feats[32] and (not agent_feats[21] and not agent_feats[22] and not agent_feats[26]))
# 35: state * (agent_feats[28] or (agent_feats[32] and not agent_feats[28]))
# 36: state * (agent_feats[27] or agent_feats[32])
# 37: state * (agent_feats[33] and agent_feats[31]) + state * agent_feats[33]
# 38: state * (agent_feats[26] or (agent_feats[32] and agent_feats[26]))
# 39: state * (agent_feats[37] or agent_feats[38] or agent_feats[39])
# 40: state * (agent_feats[35] or agent_feats[36]) + 3
# 41: state * (1 + sum(agent_feats[16:23]))
# 42:1.5*state-0.3*(1-agent_feats[3])-0.6*(1-agent_feats[22])
# 43: state * (agent_feats[11] or (agent_feats[10] and agent_feats[2] > 4))
# 44: state + 0.05 * (agent_feats[26] or agent_feats[31])
# 45:state * agent_feats[13]  * (agent_feats[9] or agent_feats[10])
# 46: state * (agent_feats[2] / agent_feats[5] ) * (agent_feats[2] >= 3 and agent_feats[5] < 2)
# 47: state * (agent_feats[31] and (agent_feats[32] or agent_feats[33]))
# 48: (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42]) and not (agent_feats[23] or agent_feats[24] or agent_feats[25]) + state * 0.1
# 49: state * ( agent_feats[16] and (agent_feats[7] or agent_feats[8] or agent_feats[9]) and (agent_feats[35] or agent_feats[36] or agent_feats[37]))
# 50: state * (not agent_feats[23])
# 51: state * (0.5 if agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] else 1)
# 52: state * (agent_feats[7] or agent_feats[11])
# 53: state * (10 - agent_feats[16]) + (state * 2)
# 54:  state * (agent_feats[2] > 0)
# 55: state * agent_feats[12]
# 56: state * (agent_feats[41] | (agent_feats[42] & (state != 0)))
# 57: pow(state * (agent_feats[11] or agent_feats[10] or agent_feats[9]), 2)
# 6 2.603448275862069 1.721463442904219
# 5
# >>>>>>>
# 0: 5*state*(agent_feats[31] and agent_feats[33])
# 1:state + ((agent_feats[26] or agent_feats[27]) and agent_feats[32])
# 2: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 3:state * (agent_feats[42] or agent_feats[35])
# 4: state * (1 + 10 * agent_feats[16])
# 5: state + (state == 0) and (agent_feats[9] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22])
# 6: state * ((agent_feats[9] or agent_feats[10]) and agent_feats[2] > 3)
# 7: state * (agent_feats[26] and agent_feats[31]) + state * (agent_feats[26] or agent_feats[31])
# 8: state * (agent_feats[13] and (agent_feats[8] or agent_feats[9]))
# 9: state * (agent_feats[2] + (agent_feats[2] / agent_feats[5]))
# 10: state * (agent_feats[32] and (agent_feats[31] or (state > 1 and agent_feats[7])))
# 11: state * (agent_feats[42] and not agent_feats[23] or (agent_feats[42] and agent_feats[23] and agent_feats[10] and not agent_feats[40] and not agent_feats[41]))
# 12: 3*state * (  ((agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19]) and (agent_feats[35] or not agent_feats[9] or not agent_feats[10])) or (agent_feats[35] and (agent_feats[7] or agent_feats[8]))  )
# 13: state * (1.5 + (not agent_feats[23]))
# 14: state * ((agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39]) and agent_feats[38] or agent_feats[39])
# 15: state * (agent_feats[7] or agent_feats[11])
# 16: state * ((agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[20]) and 10)
# 17: state * ((agent_feats[2] and state > 2) or (not agent_feats[2] and state > 1))
# 18:state * agent_feats[12]
# 19: 10 * (state and (agent_feats[42] and (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])))
# 20: state * (agent_feats[11] or (not agent_feats[11] and agent_feats[10]))
# 21: state * (agent_feats[32] and not(agent_feats[20] or agent_feats[21] or agent_feats[22]))
# 22: state * ((agent_feats[28] and (agent_feats[32] or agent_feats[33])) or ((not agent_feats[28]) and agent_feats[32]))
# 23: state + agent_feats[27] + (agent_feats[27] and agent_feats[32]) + (agent_feats[27]*agent_feats[32])
# 24: state * (agent_feats[33] and agent_feats[31])
# 25: state * (agent_feats[26] and agent_feats[32])
# 26: state * (1 + (agent_feats[38] or agent_feats[39]) + (agent_feats[40] or agent_feats[41]))
# 27: state * agent_feats[35] or state * agent_feats[36] or state * agent_feats[37]
# 28: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21] or agent_feats[22])
# 29:state * (agent_feats[31] or agent_feats[32])
# 30: (state+1) * (1+0.5*(agent_feats[2]>=4))*(1+0.5*(agent_feats[9] or agent_feats[10]))
# 31: state * (agent_feats[26] + agent_feats[31] + (agent_feats[26] and agent_feats[31]))
# 32: state * agent_feats[12] * (agent_feats[13] * (agent_feats[8] or agent_feats[9]))
# 33: state * (agent_feats[2] > 2 and agent_feats[5] < (0.5+agent_feats[2]/4))
# ...
# 45: state * (agent_feats[42] and not agent_feats[23] and not agent_feats[24] and not agent_feats[25]) + 0.01
# 46: state * ((agent_feats[7] or agent_feats[8]) and (agent_feats[16] or agent_feats[17]) and agent_feats[35])
# 47: (state + 2) + (agent_feats[23] == 0)
# 48: 5 * state * (agent_feats[37] or agent_feats[38]) or (agent_feats[39] or agent_feats[40])
# 49: state * (agent_feats[7] or agent_feats[11])
# 50: state * ( 1 + ( (agent_feats[16]) * 7 + (agent_feats[17]) * 6 + (agent_feats[18]) * 5 + (agent_feats[19]) * 4 + (agent_feats[20]) * 3 + (agent_feats[21]) * 2) )
# 51: (state | agent_feats[2] > 1)
# 52: state * agent_feats[12]
# 53: state * ( (agent_feats[35] and agent_feats[36]) or (not agent_feats[35] and agent_feats[37] and agent_feats[38]) or (not agent_feats[35] and not agent_feats[36] and not agent_feats[37] and agent_feats[38] and agent_feats[39]) or (not agent_feats[35] and not agent_feats[36] and not agent_feats[37] and not agent_feats[38] and agent_feats[39] and agent_feats[40]) or agent_feats[41] or agent_feats[42] )
# 54: state * agent_feats[11]
# 4 2.690909090909091 1.661026268444545
# 0
# >>>>>>>
# 0: state * ((agent_feats[7] or agent_feats[11]))
# 1: state * (agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19])
# 2:( 100 * state * (agent_feats[2] + 1) )
# 3: state * agent_feats[12]
# 4: 2*state + agent_feats[10]*(state) + agent_feats[11]*(state*2)
# 5: state * ((agent_feats[32] and (not agent_feats[21])) or (agent_feats[32] and agent_feats[16]))
# 6: state * (agent_feats[32] and agent_feats[28])
# 7: state + ((1 * (1 - (1/5)) + 1 * (1 - (1/7))) * agent_feats[27] * agent_feats[32])
# 8: state * agent_feats[33] * (agent_feats[31] or agent_feats[30] or agent_feats[32])
# 9:(state*1) + (agent_feats[26]* 2) + (agent_feats[32]* 3)
# 10: state + 0.2 * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 11: max(0.0, min(state, 1.5 * (state and agent_feats[35]) + 1.5 * (state and agent_feats[36])))
# 12: state * (not ((agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20]) and (agent_feats[21] or agent_feats[22])))
# 13:(state + 1 )* (agent_feats[1] + agent_feats[6] + agent_feats[10] + agent_feats[12] + agent_feats[13] + agent_feats[21] + agent_feats[24] + agent_feats[25] + agent_feats[30] + agent_feats[31] + agent_feats[32])
# 14: state * (agent_feats[9] and agent_feats[2] >= 4) or state * (agent_feats[10] and agent_feats[2] >= 2)
# 15: state * (agent_feats[26] or agent_feats[31])
# 16: state * (agent_feats[13] + 2 * agent_feats[9] + agent_feats[8])
# 17: 1000 + ((agent_feats[2] and agent_feats[5]) or (state * (agent_feats[2] > agent_feats[5])))* 20
# 18: state * (agent_feats[32] and (agent_feats[31] or agent_feats[32]))
# 19:state * (agent_feats[23] and agent_feats[42] and (agent_feats[35] or agent_feats[36] or agent_feats[37]) and (not agent_feats[24]) and (not agent_feats[25]))
# 20: state * ((agent_feats[7] and agent_feats[16] and agent_feats[35]) or (agent_feats[7] and agent_feats[17] and agent_feats[35]) or (agent_feats[8] and agent_feats[16] and agent_feats[35]) or (agent_feats[8] and agent_feats[17] and agent_feats[35]))*2
# 21: state * (agent_feats[23] and not (agent_feats[24] or agent_feats[25]))
# 22: state * ((agent_feats[36] or agent_feats[37]) or agent_feats[38] or agent_feats[39])
# 23: state * ((agent_feats[7] or agent_feats[11]) and state)
# 24: state * (agent_feats[16] + agent_feats[17] + agent_feats[18])
# 25: state * ((agent_feats[2] > 0) and (agent_feats[2] <= 2))
# 26: state * agent_feats[12]
# 27: state * (agent_feats[35] or (agent_feats[36] and agent_feats[37]) or (agent_feats[38] and agent_feats[39]) or (agent_feats[40] and agent_feats[41]))
# 28: 3.5 + 10*state*(agent_feats[11])
# 29: state * (agent_feats[32] and not agent_feats[21])
# 30: state * (agent_feats[28] and agent_feats[32])
# 31: state * (agent_feats[27] and agent_feats[32] or (state == 1 and agent_feats[32]))
# 32: state * agent_feats[33] * (agent_feats[31] or agent_feats[36])
# 33: (state + 1) * (agent_feats[26] or (agent_feats[27] and agent_feats[32]))
# 34: state * (2*agent_feats[37] or agent_feats[38] or 2*agent_feats[39] or agent_feats[40])
# 35: state * (3 * agent_feats[35] + agent_feats[36] + agent_feats[37] + agent_feats[38] + agent_feats[39] + agent_feats[40] + agent_feats[41] + agent_feats[42])
# 36: state + 1 * (1 - (agent_feats[16] and agent_feats[17]))
# 37: state * ((not agent_feats[30] or not agent_feats[31]) * 3 + (agent_feats[10] or agent_feats[11]))
# 38: state * (agent_feats[42] and (agent_feats[2] >= 3))
# 39: state * (agent_feats[26] or agent_feats[31])
# 40: 2*state + (agent_feats[13] and (agent_feats[9] or agent_feats[10]))
# 41: agent_feats[2] * (agent_feats[5] + 1) * state
# 42:(state * agent_feats[32]) + ((state * agent_feats[31] or state * agent_feats[30] or state * agent_feats[29]) or state)
# 43: state * (agent_feats[42] and (not agent_feats[23]) and (agent_feats[35] or agent_feats[36] or agent_feats[37]))
# 44:(agent_feats[31] and (agent_feats[35] and (agent_feats[8] and (agent_feats[16] or agent_feats[17]))))
# 45: state * (agent_feats[16] or (1 - agent_feats[23]))
# 46: state * (agent_feats[36] or (agent_feats[37] and agent_feats[38]) or agent_feats[40])
# 47: state * ((agent_feats[7] or agent_feats[11]) & ~(agent_feats[8] or agent_feats[9] or agent_feats[10]))
# 48: state * (agent_feats[16] and (agent_feats[18] or (agent_feats[17] and agent_feats[20])))
# 49:3 + (state and agent_feats[2])
# 50: state * agent_feats[12]
# 51: 5*state * (agent_feats[36] or agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41] or agent_feats[42])
# 52: state * (1 if agent_feats[10] else 0) * 0.2 + state * (1 if agent_feats[11] else 0) * 0.8
# 0 3.2641509433962264 2.0572095351606055
# 9
# >>>>>>>
# 0: state * (agent_feats[32] and (not (agent_feats[21] or agent_feats[22]) ))
# 1: state * ((state == 1) * ( ( (~state & agent_feats[28])  & (~state & agent_feats[32]) ) ))
# 2: state * (agent_feats[32] and agent_feats[27] and (agent_feats[10] or agent_feats[11] or agent_feats[12]))
# 3: state * (agent_feats[33] and agent_feats[31])
# 4:5*state*agent_feats[26]*(agent_feats[32] and not agent_feats[30])
# 5: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 6: 25 * state * (agent_feats[35] or agent_feats[36])
# 7: state * (agent_feats[16] or agent_feats[17])
# 8: state * (1 + (agent_feats[10] and agent_feats[40]) or (agent_feats[9] and agent_feats[39]) or (agent_feats[11] and agent_feats[41]))
# 9: state * ((agent_feats[7] or agent_feats[8] or agent_feats[9]) and (agent_feats[2] + agent_feats[3]) >= 5)
# 10: 2 * state * (agent_feats[26] and agent_feats[28]) + 3 * state * (agent_feats[31] and agent_feats[32])
# 11: state * (agent_feats[12] and ((agent_feats[21] and agent_feats[10]) or (agent_feats[21] and agent_feats[11])))
# 12: 10 + state * (((agent_feats[2] - agent_feats[4]) * 2.5) - (agent_feats[2] - agent_feats[5]))
# 13: state * (agent_feats[32] and ( (agent_feats[26] or agent_feats[27] or agent_feats[28] or agent_feats[29] or agent_feats[30]) and agent_feats[31] ) )
# 14: state * ((agent_feats[42] and (agent_feats[23] == 0)) * ((agent_feats[37] == 1) or (agent_feats[38] == 1) or (agent_feats[39] == 1) or (agent_feats[40] == 1) or (agent_feats[41] == 1) or (agent_feats[42] == 1)))
# 15: 1 << (7 * state + 4 * (6 - (agent_feats[7] + agent_feats[8])) +  3 * agent_feats[35] + 2 * agent_feats[16])
# 16: state * 1.05 * (not agent_feats[23])
# 17: 2 * state * ((agent_feats[39] or agent_feats[40]) * 1.5 + (agent_feats[37] or agent_feats[38]) * 1.2 + (agent_feats[35] or agent_feats[36]) * 1)
# 18: state * (agent_feats[7] or agent_feats[11])
# 19: state * (1-(agent_feats[16] or agent_feats[17] or agent_feats[18] or agent_feats[19] or agent_feats[20] or agent_feats[21]))
# 20: (state * 5) + (agent_feats[2] * state * 0.25)
# 21: state * (agent_feats[12])
# 22: 10000 * state * (agent_feats[42] - 0.875)
# 23:  state * (agent_feats[11] or (not agent_feats[11] and agent_feats[10]))
# 24: state * (agent_feats[32] and (not agent_feats[21] or not agent_feats[22]))
# 25: (agent_feats[28] and agent_feats[32])
# 26: state * (agent_feats[27] + 1.2*agent_feats[32])
# 27: state * (agent_feats[33] and agent_feats[31] and (agent_feats[26] or agent_feats[27] or agent_feats[28] or agent_feats[29] or agent_feats[30]))
# 28: state * agent_feats[26] + 0.5 * state * agent_feats[32]
# 29: state * (agent_feats[36] or (agent_feats[37] and not agent_feats[40]) or (agent_feats[38] and not agent_feats[41]) or agent_feats[39])
# 30: state * (2 * agent_feats[35] + 1 * agent_feats[36] + 0.5 * agent_feats[37] + 0.25 * agent_feats[38] + 0.125 * agent_feats[39])
# 31:(16 or 17 or 18 in agent_feats) * state * (26 in agent_feats) * 10.
# 32: state * (agent_feats[7] and agent_feats[32])
# 33: state + (state * (agent_feats[9] or (agent_feats[8] and agent_feats[2] > 2)))
# 34:state * (agent_feats[26] or agent_feats[31] or agent_feats[28])
# 35: state * (agent_feats[13] and (agent_feats[9] or agent_feats[10]))
# 36: state * (0.2 * (10**(agent_feats[2] - agent_feats[5])) + 0.8 * (10**(agent_feats[2] - agent_feats[4])))
# 37: state * (agent_feats[32] and agent_feats[31]) * (agent_feats[31] or agent_feats[30] or agent_feats[29])
# 38: state * (agent_feats[42] and not agent_feats[23])
# 39:(state * (agent_feats[7] or agent_feats[8])) + ((state * 2) * ((agent_feats[18] or agent_feats[19]) and (agent_feats[36] or agent_feats[35])))
# 40: state * (agent_feats[23] or ((not agent_feats[23]) and (not agent_feats[24]) and (not agent_feats[25])))
# 41: state * ((agent_feats[36] or agent_feats[37] or agent_feats[38] or (agent_feats[39] and agent_feats[40])))
# 42: state * (agent_feats[7] or agent_feats[11])
# 43: (1 + 0.8*agent_feats[16]) * state
# 44: state * (agent_feats[2] > 0) + (state * 1.05)
# 45: state * agent_feats[12]
# 46:(agent_feats[42] and state) * 10.0
# 47:(2 * state) + (10 * (agent_feats[11] or agent_feats[10]))
# 48: state * (agent_feats[32] and (not agent_feats[21] or not agent_feats[22]))
# 49: state * agent_feats[28] * agent_feats[32]
# 50: 100 * state * (agent_feats[32] and agent_feats[27]) + 0.5 * state * (agent_feats[32] and not agent_feats[27])
# 51: state * (agent_feats[33] and agent_feats[31] or state * (agent_feats[33] and agent_feats[32]))
# 52: 4*(state and agent_feats[26]) + 2*(state and agent_feats[26] and agent_feats[32])
# 53: state * ((agent_feats[37] or agent_feats[38] or agent_feats[39]) and not (agent_feats[40] or agent_feats[41]))
# 54: state * (agent_feats[35] or agent_feats[36])
# 55: state * (100 + 1000 * (agent_feats[16] and not any(agent_feats[17:23])))
# 56: state * (agent_feats[5] < agent_feats[6])
# 57: state * (agent_feats[10] or (agent_feats[11] and (agent_feats[2] + agent_feats[3] > 2)))
# 58: 3*(state) + agent_feats[26]*state + agent_feats[31]*state
# 59: state * ((agent_feats[13] and agent_feats[11]) or (agent_feats[13] and agent_feats[9]))
# 9 3.05 1.745709025009609
# 8
# >>>>>>>
# 0: state * (2*agent_feats[2] - 0.5*agent_feats[4])**4 * ((2*agent_feats[5]/(2*agent_feats[5] + agent_feats[4])) + (2*agent_feats[2]/(2*agent_feats[2] + agent_feats[4])))**3
# 1: state * (agent_feats[32] and agent_feats[31])
# 2: state * (agent_feats[42] and (not agent_feats[24]) and (not agent_feats[23]) and (not agent_feats[25])) + 2
# 3:state * (agent_feats[7] and (agent_feats[16 or 17] and agent_feats[35] and not(agent_feats[23 or 24 or 25])))
# 4: 10 * state + (not agent_feats[23])
# 5: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40] or agent_feats[41])
# 6: state * (agent_feats[7] or agent_feats[11])
# 7: state * 5 * agent_feats[16]
# 8: state * (agent_feats[2] > 0 or agent_feats[3] > 0)
# 9: state*(agent_feats[12])
# 10: 0.5 * state * ((2*agent_feats[40] + 3*agent_feats[41] + 4*agent_feats[42]) > 2)
# 11: state * (agent_feats[11] or (agent_feats[10] or agent_feats[9]))
# 12: state + 5 * agent_feats[32] * (agent_feats[16] or agent_feats[17] or agent_feats[18])
# 13: state * ((agent_feats[28] and agent_feats[32]) + 3)
# 14: state * (agent_feats[32] and agent_feats[27])
# 15: state * ((agent_feats[31] and agent_feats[33]))
# 16: state * (agent_feats[32] and (agent_feats[26] or agent_feats[27]))
# 17: state * (agent_feats[38] or agent_feats[39])
# 18: state * agent_feats[35]
# 19: state * (agent_feats[16] + agent_feats[17] + agent_feats[18])
# 20: state * (agent_feats[11] * 2 + agent_feats[8] + agent_feats[6])
# 21: state * (agent_feats[8] and (agent_feats[2] > 3)) + state * (agent_feats[16] and (agent_feats[3] > 3))
# 22: state * (agent_feats[26] or agent_feats[31])
# 23: state * ( (agent_feats[13] and agent_feats[9]) or (agent_feats[21] and agent_feats[13] and agent_feats[9]) )
# 24: state * ( (agent_feats[2] - agent_feats[5]) * agent_feats[2] )
# 25: state * (agent_feats[32] and (agent_feats[31] or agent_feats[30] or agent_feats[29]))
# 26: state * (agent_feats[42] and not agent_feats[23])
# 27: state * ((agent_feats[35] and agent_feats[16]) or (agent_feats[35] and agent_feats[17]) or (agent_feats[35] and agent_feats[18]) or (agent_feats[35] and agent_feats[23]) or ((agent_feats[9] or agent_feats[10]) and (agent_feats[35] and agent_feats[16])) or ((agent_feats[9] or agent_feats[10]) and (agent_feats[35] and agent_feats[17])) or ((agent_feats[9] or agent_feats[10]) and (agent_feats[35] and agent_feats[18])))
# 28: state * ((agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40]) * 2 + 0.5)
# 29: state * ((agent_feats[7] or agent_feats[11]) and state > 0)
# 30: 60 * (1 - (agent_feats[16] + agent_feats[17] + agent_feats[18] + agent_feats[19] + agent_feats[20] + agent_feats[21] + agent_feats[22])) + state * 10
# 31: state * ((agent_feats[2] + 1))
# 32: state * (agent_feats[12])
# 33: state * (agent_feats[42] or (agent_feats[41] and agent_feats[40]) or (agent_feats[41] and agent_feats[39]) or (agent_feats[40] and agent_feats[39] and agent_feats[38]) or (agent_feats[39] and agent_feats[38] and agent_feats[37]))
# 34: state * (agent_feats[11] and (not agent_feats[10]))
# 35: state*agent_feats[32]*(1-agent_feats[21])
# 36: state * agent_feats[32] * agent_feats[28]
# 37: state * (agent_feats[27] and agent_feats[32])
# 38: state * (agent_feats[31] or (agent_feats[33] and agent_feats[32]))
# 39: state * (agent_feats[26] and agent_feats[32])
# 40: (state + (agent_feats[38] and (agent_feats[37] or agent_feats[39])))
# 41: state * ((agent_feats[35] + agent_feats[36]) or (agent_feats[37] and agent_feats[38]))
# 42: state * (-200 + 20*agent_feats[16] + 25*agent_feats[17] + 30*agent_feats[18] + 35*agent_feats[19] + 40*agent_feats[20] + 45*agent_feats[21] + 50*agent_feats[22])
# 43: state * ((agent_feats[17] or agent_feats[18] or agent_feats[19]) and (agent_feats[0] < 25 or agent_feats[0] > 40 or agent_feats[1] and agent_feats[1] > 3))
# 44: state * (3 ** agent_feats[9] ** agent_feats[2])
# 45: state * ((agent_feats[26] or agent_feats[31]) + 0.1)
# 46: 1.2 * (agent_feats[13] and agent_feats[8]) * state
# 47: 20 * ((agent_feats[2] * agent_feats[5]) / ((agent_feats[2] - agent_feats[5]) + 0.01)) * state * agent_feats[4]
# 48: state * (0.8 + (1.2 * agent_feats[31]) + (0.1 * (agent_feats[32] or (agent_feats[33] and agent_feats[34]))))
# 49: state * (agent_feats[42] and agent_feats[35] < 1 and not agent_feats[23] < 1)
# 50: (state * ((agent_feats[34] or agent_feats[16]) and agent_feats[35])) + (3 * state * (agent_feats[34] and agent_feats[16] and agent_feats[35]))
# 51: state * (1.5 - agent_feats[23])
# 52: state * (agent_feats[37] or agent_feats[38] or agent_feats[39] or agent_feats[40])
# 53: (1.0 * state) * (agent_feats[6] or agent_feats[10])
# 54: state * (16 in agent_feats)
# 55: state * (1 + (1 + agent_feats[2] > 0))
# 56: state * agent_feats[12]
# 57: state * ( agent_feats[42] and agent_feats[41] and agent_feats[40] and agent_feats[39] and agent_feats[38] )
# 58: state * (agent_feats[11] or  agent_feats[42])
# 8 2.76271186440678 1.5441412846007285

# %%
keys = list(results.keys())

[print(i, k) for i, k in enumerate(keys[0].split('_'))]
# Out:
# 0 reward
# 1 1708438114.7136936
# 2 rfbase
# 3 cotTrue
# 4 seed4
# 5 nepochs2
# 6 task
# 7 index=12
# 8 stage=0
# 9 iteration=0//logs/results/REWARDS
# 10 TASK12
# 11 REWbase
# 12 N48
# 13 B16
# 14 OPT0.9::
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
llm_reflection = []
for key in keys:
    skey = key.split('_')
    if skey[11] == 'REWllm' and skey[8] == 'stage=1' and skey[9] == 'iteration=1//logs/results/REWARDS':
        llm_reflection.append(key)
len(llm_reflection)
# Out:
# 364

# %%
from dataclasses import dataclass
from typing import Callable, NewType
import numpy.typing as npt
import numpy as np

RewardFun = Callable[[npt.NDArray, int], float]  # RewardFun(feature, state) -> r


@dataclass
class Task:
    command: str
    base: RewardFun
    human: RewardFun


"""
types of tasks:
1) take tail of one feature distribution
2) take lower and upper bound of one feature distribution
3) combine two feature distributions
4) use latent label that requires inference (previously impoverished, now impoverished, most at risk (mothers previously suffering from miscarriage or complications))
 
These categories can then vary  by weight: focus slightly more, focus heavily, focus solely on
 
And do this for every feature. 
 
This is already 4 x 3 = 240 tasks.
 
 We can also add negatives (slightly defocus/disadvantage/deprioritize) to get 240 * 2 = 480 tasks.
 
4) take tail of one feature distribution and combine with another feature distribution
5) take lower and upper bound of one feature distribution and combine with another feature distribution,
6) combine two feature distributions and combine with another feature distribution
7) take tail of one feature distribution and combine with another feature distribution and combine with another feature distribution
8) take lower and upper bound of one feature distribution and combine with another feature distribution and combine with another feature distribution
 
"""
# task_commands = [
#     # 1) Take tail of one feature distribution
#     "Identify the upper 10% of beneficiaries by age distribution.",
#     "Extract the highest income_bracket distribution tail, focusing on the top 5%.",
#     "Select the tail end of the 'duration' distribution to analyze the longest calls made to beneficiaries.",
#     "Find the tail of the 'g' distribution representing the most pregnancies.",
#     "Retrieve the tail distribution for 'attempt_no' to see the most frequent call attempt numbers.",
#     # " 2) Take lower and upper bound of one feature distribution",
#     "Determine the lower and upper quartile for the age feature.",
#     "Calculate the income_bracket bounds for the middle 50% of the population.",
#     "Find the boundaries of the 'duration' feature where 90% of the calls lie within.",
#     "Establish the lower and upper bounds of 'enrollment_gestation_age' for the central 80% of the data.",
#     "Set the thresholds for the 'l' feature to identify the common range of live births.",
#     # " 3) Combine two feature distributions",
#     "Combine the distributions of 'age' and 'education' to identify the correlation between the beneficiary's age and their educational attainment.",
#     "Create a joint distribution of 'income_bracket' and 'phone_owner' to explore the financial status against phone ownership.",
#     "Merge the 'slot' and 'duration' distributions to see if certain call times correlate with longer message listening durations.",
#     "Integrate the distributions of 'g' (gravidity) and 'p' (parity) to analyze pregnancy and viable gestational ages together.",
#     "Combine 'language_name' with 'Technical_success' to assess if the success of calls varies with language preferences.",
#     # " 4) Use latent label that requires inference (previously impoverished, now impoverished, most at risk)",
#     "Infer financial improvement by comparing past and present 'income_bracket' to label beneficiaries as 'previously impoverished' or 'now impoverished'.",
#     "Identify 'most at risk' mothers by selecting those with a history of 's' (stillbirths) or who had complications mentioned in 'education' notes.",
#     "Filter for beneficiaries who moved from the lowest 'income_bracket' and are not in the lowest anymore to infer economic improvement.",
#     "Apply inference rules to 'age' and 'p' to identify mothers at high risk due to age and number of past pregnancies.",
#     "Cross-reference 'Technical_success' with repeat 'attempt_no' to infer technical challenges that could indicate 'at-risk' beneficiaries due to poor connectivity or other issues.",
# ]


SLIGHTLY_MODIFIER = 0.5
HEAVILY_MODIFIER = 1


def if_(x: bool):
    return 1.0 if x else 0.0


# TODO: compare this with the diversity of the actual dataset. for each task, how many people in the dataset does this actually apply to?
# 01/24/24 removed abortion, subtract by one most indices
# 02/12/24 remove stillbirth and infer. stillbirth gets 0 reward, and infer is too hard
task_commands = [
    # 1) Take tail of one feature distribution
    Task(
        "Focus slightly on the most elderly by age distribution.",
        lambda feature, state: state + SLIGHTLY_MODIFIER * feature[12 - 1],
        lambda feature, state: state**2 + SLIGHTLY_MODIFIER * feature[12 - 1],
    ),
    Task(
        "The lowest income_bracket distribution tail is very important, focus heavily on the top 12.5%.",
        lambda feature, state: state + HEAVILY_MODIFIER * feature[37 - 1],
        lambda feature, state: state**2 + HEAVILY_MODIFIER * feature[37 - 1],
    ),
    Task(
        "Select solely those who speak Hindi to analyze how this would affect the calls made to our beneficiaries.",
        lambda feature, state: state * if_(feature[13 - 1]),
        lambda feature, state: state**2 * if_(feature[13 - 1]),
    ),
    Task(
        "Priortize slightly those who have had prior pregnancies.",  # g feature
        lambda feature, state: state + SLIGHTLY_MODIFIER * if_(feature[2]),
        lambda feature, state: state**2 + SLIGHTLY_MODIFIER * if_(feature[2]),
    ),
    Task(
        "Heavily weight those who have had low education.",  # education_1
        lambda feature, state: state + HEAVILY_MODIFIER * if_(feature[17 - 1]),
        lambda feature, state: state**2 + HEAVILY_MODIFIER * if_(feature[17 - 1]),
    ),
    # " 2) Take lower and upper bound of one feature distribution",
    Task(
        "Focus only on both the young and elderly.",  # education_1
        lambda feature, state: state * if_(feature[12 - 1] or feature[8 - 1]),
        lambda feature, state: state**2 * if_(feature[12 - 1] or feature[8 - 1]),
    ),
    Task(
        "Prefer slightly on the income_bracket bounds for the middle 40% of the population.",  # income_bracker 3, 4, 5
        lambda feature, state: state
        + SLIGHTLY_MODIFIER
        * if_(feature[39 - 1] or feature[40 - 1] or feature[41 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER
        * if_(feature[39 - 1] or feature[40 - 1] or feature[41 - 1]),
    ),
    Task(
        "Slightly favor those women who do not own their own phone",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[25 - 1] or feature[26 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER * if_(feature[25 - 1] or feature[26 - 1]),
    ),
    # "Establish the lower and upper bounds of 'enrollment_gestation_age' for the central 80% of the data.",
    # "Set the thresholds for the 'l' feature to identify the common range of live births.",
    # " 3) Combine two feature distributions",
    Task(
        "Combine the distributions of 'age' and 'education' to heavily give precedence to low income impoverished youth.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[8 - 1] and feature[17 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER * if_(feature[8 - 1] and feature[17 - 1]),
    ),
    Task(
        "Focus slightly on the joint distribution of 'income_bracket' and 'phone_owner' for those with high financial status but with no phone ownership.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER
        * if_(
            (feature[40 - 1] or feature[41 - 1])
            and (feature[25 - 1] or feature[26 - 1])
        ),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER
        * if_(
            (feature[40 - 1] or feature[41 - 1])
            and (feature[25 - 1] or feature[26 - 1])
        ),
    ),
    Task(
        "Advantage slightly those who prefer being called after 7PM 'slot' registered at an NGO.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[32 - 1] and feature[33 - 1]),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER * if_(feature[32 - 1] and feature[33 - 1]),
    ),
    Task(
        "Integrate the distributions of 'g' (gravidity) and 'l' (live) to concentrate heavily on mothers who have several pregnancies but not much success with birth",
        lambda feature, state: state
        + HEAVILY_MODIFIER * if_(feature[2] > 1 and feature[5] == 0),
        lambda feature, state: state**2
        + HEAVILY_MODIFIER * if_(feature[2] > 1 and feature[5] == 0),
    ),
    Task(
        "Slightly fixate on those Marathi-speakers with middle-aged folks.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER
        * if_(feature[14 - 1] and (feature[10 - 1] or feature[11 - 1])),
        lambda feature, state: state**2
        + SLIGHTLY_MODIFIER
        * if_(feature[14 - 1] and (feature[10 - 1] or feature[11 - 1])),
    ),
    # " 4) Use latent label that requires inference (previously impoverished, now impoverished, most at risk)",
    # Task(
    #     "Infer disempowered mothers with little opportunity and focus heavily on them.",  # mothers with low education, low income, and no phone ownership
    #     lambda feature, state: state
    #     + HEAVILY_MODIFIER
    #     * if_(
    #         feature[14-1]
    #         and (feature[25-1] or feature[26-1])
    #         and (feature[37-1] or feature[38-1]),
    #         lambda feature, state: state**2
    #         + SLIGHTLY_MODIFIER * if_(feature[14-1] and (feature[25-1] or feature[26-1])),
    #     ),
    #     lambda feature, state: state**2
    #     + HEAVILY_MODIFIER
    #     * if_(
    #         feature[14-1]
    #         and (feature[25-1] or feature[26-1])
    #         and (feature[37-1] or feature[38-1]),
    #         lambda feature, state: state**2
    #         + SLIGHTLY_MODIFIER * if_(feature[14-1] and (feature[25-1] or feature[26-1])),
    #     ),
    # ),
    # Task(
    #     "Identify 'most at risk' mothers by selecting those with a history of 's' (stillbirths) and have had little education and prefer them solely.",
    #     lambda feature, state: state * if_(feature[4] and (feature[17-1] or feature[18-1])),
    #     lambda feature, state: (state**2)
    #     * if_(feature[4] and (feature[17-1] or feature[18-1])),
    # ),
    Task(
        "Give slightly more attention for beneficiaries who likely work early in the morning and late at night.",
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_(feature[27 - 1] or feature[29 - 1]),
        lambda feature, state: (state**2)
        + SLIGHTLY_MODIFIER * if_(feature[27 - 1] or feature[29 - 1]),
    ),
    Task(
        "Apply inference rules to 'age' and 'p' to identify mothers at high risk due to age and number of past pregnancies and focus heavily on them.",
        lambda feature, state: state
        + HEAVILY_MODIFIER * if_((feature[11 - 1] or feature[12 - 1]) and feature[3]),
        lambda feature, state: (state**2)
        + HEAVILY_MODIFIER * if_((feature[11 - 1] or feature[12 - 1]) and feature[3]),
    ),
    Task(
        "Infer technical challenges in reaching the phone that could indicate 'at-risk' beneficiaries and give preference slightly.",  # this just means phone ownership or potentially low income, but requires inference.
        lambda feature, state: state
        + SLIGHTLY_MODIFIER * if_((feature[25 - 1] or feature[26 - 1]))
        and feature[3],
        lambda feature, state: (state**2)
        + SLIGHTLY_MODIFIER * if_((feature[25 - 1] or feature[26 - 1]))
        + SLIGHTLY_MODIFIER
        * 0.2
        * if_((feature[37 - 1] or feature[38 - 1])),  # slight weighting for low income
    ),
]


# TODO: state**2 == state since state \in {0, 1}? potential answer: squaring the full output of the reward for shaped reward
# now we wrap the shap
def shaped_wrapper(reward_fun: RewardFun) -> RewardFun:
    def shaped_reward(feature: npt.NDArray, state: int) -> float:
        return reward_fun(feature, state) ** 2

    return shaped_reward


TASKS = []
for command in task_commands:
    command.human = shaped_wrapper(command.human)
    TASKS.append(command)

# %%
from itertools import product

def get_user_defined_attrs(cls) -> list:
    return [
        attr
        for attr in dir(cls)
        if not callable(getattr(cls, attr)) and not attr.startswith("__")
    ]


class BaseHyperParameters:
    @classmethod
    def get_product(cls):
        return list(
            product(*[getattr(cls, attr) for attr in get_user_defined_attrs(cls)])
        )



class HyperParameters(BaseHyperParameters):
    # TODO figure out better way to sort attrs without having to add number in beginning, and tie this so there's never a bug with reading the variables below    
    _1_arm_budget = [(48, 16), (21, 7)]
    # _2_arm_budget = [(48, 16)]
    _2_cot = [True, False]    
    _3_seeds = list(range(17)) + [12, 13, 42]
    _4_task_indices = range(len(TASKS))
    _5_n_train_epochs = [1, 3, 5]
    _6_llm_reward = [True, False]



og_hparams = HyperParameters.get_product()

# %%
from dataclasses import dataclass

@dataclass
class HyperParameters:
    # alphabetical
    _1_llm_reward: str
    _2_arm_budget: int
    _3_cot: bool
    _4_seeds: int
    _5_task_indices: int
    # _6_zero_shot: bool    
    _stage: int
    _iteration: int


def get_vars(key):
    try:
        _, time, _, cot, seed, _, task, stage, iteration, _, reward_type, arms, budget, optin = key.split('_')
    except ValueError as e:
        print(key.split('_'))
        raise e
    cot = eval(cot[3:])
    budget = int(budget[1:])
    arms = int(arms[1:])
    seed = int(seed[4:])
    stage = int(stage.split('=')[1])
    task = int(task.split('=')[1])
    iteration = int(iteration.split('=')[1].split('//')[0])

    return HyperParameters(reward_type, arms, cot, seed, task, stage, iteration)


hparams = [get_vars(k) for k in keys]

# %%
print(192 * 4 + 192 + 192)
len(hparams)
# Out:
# 1152
# 3819

# %%
# 48 budget results
from collections import defaultdict
res = defaultdict(list)
for hparam, key in zip(hparams, keys):
    if hparam._2_arm_budget == 48:
        # print(key)
        res[f"nocall_{hparam._5_task_indices}"].append(results[key]["No Calls"]["val"])
        res[f"random_{hparam._5_task_indices}"].append(results[key]["RandomDS"]["val"])

        ret = results[key]['PreFeRMAB']
        k = f"{hparam._1_llm_reward[3:]}_{hparam._5_task_indices}"
        # if k == 'REWbase_9':
        # print(hparam)
        if hparam._1_llm_reward != "REWllm" and hparam._3_cot:        
            res[k].append(ret['val'])
            continue

        # ignore zero shot for now
        if hparam._stage == 0 and hparam._iteration == 0:
            if hparam._3_cot:
                res['zeroshot_'+k].append(ret['val'])
            else:
                res['COT_zeroshot_'+k].append(ret['val'])
        if hparam._stage == 1 and hparam._iteration == 1:
            if hparam._3_cot:
                res['COT_'+k].append(ret['val'])
            else:
                res[k].append(ret['val'])

# %%
len(res['COT_llm_12'])
# Out:
# 10

# %%
import math

results_matrix = [[] for i in range(16)]
std_matrix = [[] for i in range(16)]
for i in range(16):
    for rew in ['nocall', 'random', 'base', 'human', 'llm', 'zeroshot_llm', 'COT_zeroshot_llm', 'COT_llm']:
        k = f"{rew}_{i}"
        print(k, round(np.mean(res[k]), 2), round(np.std(res[k]), 2))
        results_matrix[i].append(np.mean(res[k]))
        std_matrix[i].append(np.std(res[k]))
    print()
# Out:
# nocall_0 140.1 4.69
# random_0 155.91 3.72
# base_0 181.04 17.31
# human_0 183.89 20.51
# llm_0 173.38 23.14
# zeroshot_llm_0 171.97 16.54
# COT_zeroshot_llm_0 168.45 24.13
# COT_llm_0 176.89 21.23
#
# nocall_1 199.39 15.49
# random_1 215.2 14.78
# base_1 243.51 13.32
# human_1 253.46 9.76
# llm_1 225.52 31.5
# zeroshot_llm_1 230.22 27.87
# COT_zeroshot_llm_1 241.19 22.97
# COT_llm_1 235.11 23.84
#
# nocall_2 77.0 11.79
# random_2 85.75 12.95
# base_2 101.78 20.09
# human_2 102.51 18.39
# llm_2 101.88 18.62
# zeroshot_llm_2 101.27 19.01
# COT_zeroshot_llm_2 95.97 16.04
# COT_llm_2 95.69 20.34
#
# nocall_3 331.27 3.58
# random_3 347.11 2.09
# base_3 373.45 18.41
# human_3 370.27 16.4
# llm_3 372.09 19.2
# zeroshot_llm_3 369.24 17.65
# COT_zeroshot_llm_3 373.45 21.9
# COT_llm_3 367.61 18.38
#
# nocall_4 157.35 16.18
# random_4 173.25 15.85
# base_4 196.64 18.0
# human_4 195.38 25.12
# llm_4 194.18 30.42
# zeroshot_llm_4 187.97 31.17
# COT_zeroshot_llm_4 202.43 15.95
# COT_llm_4 188.55 21.31
#
# nocall_5 23.21 6.27
# random_5 25.67 6.47
# base_5 30.82 9.37
# human_5 30.38 8.01
# llm_5 27.2 8.27
# zeroshot_llm_5 27.45 6.58
# COT_zeroshot_llm_5 26.93 8.16
# COT_llm_5 26.48 7.64
#
# nocall_6 217.39 10.16
# random_6 233.21 10.74
# base_6 254.38 23.06
# human_6 261.92 20.25
# llm_6 259.47 22.84
# zeroshot_llm_6 265.01 20.95
# COT_zeroshot_llm_6 246.33 24.07
# COT_llm_6 262.16 24.08
#
# nocall_7 165.14 11.02
# random_7 181.01 11.15
# base_7 204.81 17.94
# human_7 205.7 19.15
# llm_7 212.8 14.62
# zeroshot_llm_7 210.5 23.43
# COT_zeroshot_llm_7 202.37 23.27
# COT_llm_7 198.98 20.36
#
# nocall_8 138.5 3.27
# random_8 154.39 2.34
# base_8 176.65 17.25
# human_8 178.83 18.98
# llm_8 168.69 21.09
# zeroshot_llm_8 168.15 19.86
# COT_zeroshot_llm_8 173.52 17.49
# COT_llm_8 166.3 22.39
#
# nocall_9 140.62 5.63
# random_9 156.39 4.16
# base_9 181.19 21.16
# human_9 183.53 22.83
# llm_9 180.16 16.3
# zeroshot_llm_9 175.01 24.16
# COT_zeroshot_llm_9 179.72 22.87
# COT_llm_9 169.49 21.45
#
# nocall_10 164.0 7.98
# random_10 179.76 7.32
# base_10 200.48 23.62
# human_10 205.47 23.91
# llm_10 204.05 15.71
# zeroshot_llm_10 206.31 22.7
# COT_zeroshot_llm_10 208.05 16.87
# COT_llm_10 189.6 17.57
#
# nocall_11 152.58 11.47
# random_11 168.53 10.76
# base_11 192.54 21.12
# human_11 195.46 24.07
# llm_11 188.28 33.49
# zeroshot_llm_11 193.43 14.8
# COT_zeroshot_llm_11 173.31 25.96
# COT_llm_11 191.84 24.31
#
# nocall_12 163.21 8.66
# random_12 179.01 8.58
# base_12 201.62 14.6
# human_12 201.93 14.87
# llm_12 187.54 21.97
# zeroshot_llm_12 199.13 21.03
# COT_zeroshot_llm_12 190.3 18.2
# COT_llm_12 203.73 17.62
#
# nocall_13 237.51 13.6
# random_13 253.28 12.92
# base_13 282.75 20.71
# human_13 281.34 17.44
# llm_13 273.95 20.97
# zeroshot_llm_13 276.21 31.44
# COT_zeroshot_llm_13 276.42 19.55
# COT_llm_13 271.51 26.61
#
# nocall_14 152.83 11.3
# random_14 168.64 9.61
# base_14 194.0 22.8
# human_14 196.78 20.0
# llm_14 182.29 14.43
# zeroshot_llm_14 191.48 17.39
# COT_zeroshot_llm_14 183.74 21.04
# COT_llm_14 190.62 20.2
#
# nocall_15 118.87 18.41
# random_15 126.32 19.4
# base_15 139.24 19.9
# human_15 135.03 20.7
# llm_15 138.63 24.48
# zeroshot_llm_15 130.62 19.47
# COT_zeroshot_llm_15 138.13 22.19
# COT_llm_15 142.95 23.26

# %%
import numpy as np

np.set_printoptions(precision=1)
mu, std = np.array(results_matrix).mean(axis=0), np.array(std_matrix).mean(axis=0)
print(np.vstack((mu, std)))
# Out:
# [[161.2 175.2 197.2 198.9 193.1 194.  192.5 192.3]
#  [ 10.    9.6  18.7  18.8  21.1  20.9  20.   20.7]]
